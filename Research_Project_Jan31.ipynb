# %%
#@title Importing Packages

# Utility
import math as math
import numpy as np
import pandas as pd
import random as rdm
import scipy.io as io
import scipy.stats as stats
from google.colab import drive
import networkx as nx
import time

# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as col
from matplotlib.animation import FuncAnimation
from functools import partial
import matplotlib.patches as patch

# %% [markdown]
# # Plotting functions

# %%
#@title Function to plot results

def plotResults(results, sites, length, name, y):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(name, fontsize = 20)
    fig.text(0.5, 0.08, "Time", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.08, 0.5, y, ha = 'center', va = 'center', rotation = 90, fontsize = 15)
    plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, sites)))

    plt.xlim(0, length)
    siteArray = []

    for i in range(sites):
        site, = plt.plot(range(length), results[i, :], label = f"{i + 1}")
        siteArray.append(site)
    
    legend = fig.legend(handles = siteArray, loc = 'upper center', borderpad = 0.2, facecolor = 'k', edgecolor = 'w', ncol = sites)
    for text in legend.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %% [markdown]
# ## Prior PDF/PMF

# %%
#@title Function to plot pdf of distribution for single parameter

def plotPDF(dist, mean, true, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"PDF of {name} prior", fontsize = 20)
    fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Density", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

    sample = dist.rvs(10000)
    plt.hist(sample, bins = 100, alpha = 0.5, color = 'lightblue')

    points = []

    plt.scatter(true, 10, marker = 'P', alpha = 0.8, s = 10, facecolor = 'g', edgecolor = 'w')
    plt.scatter(mean, 10, marker = 'D', alpha = 0.8, s = 10, facecolor = 'r', edgecolor = 'w')

    patch1 = plt.scatter(0, 0, facecolor = 'g', edgecolor = 'k', marker = 'D')
    patch2 = plt.scatter(0, 0, facecolor = 'r', edgecolor='k', marker = 'P')
    patches = [patch1, patch2]
    patch1.remove()
    patch2.remove()

      
    legend = fig.legend(handles = patches,
                        labels = ['True Value', 'Predicted Value'],
                        bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %%
#@title Function to plot pdf of distribution for set of parameters

def plotPDFSet(dist, mean, true, N, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"PDF of {name} prior", fontsize = 20)
    fig.text(0.5, 0.05, "Density", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)
    plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))

    sample = dist.rvs(10000)
    plt.hist(sample, alpha = 0.5, bins = 100, color = 'lightblue')

    points = []

    for i in range(N):
        plt.scatter(mean[i], 10, alpha = 0.8, s = 10, marker = 'P', edgecolor = 'k')
    for i in range(N):
        plt.scatter(true[i], 10, alpha = 0.8, s = 10, marker = 'D', edgecolor = 'k')
    for i in range(N):
        point = plt.scatter(0, 0, edgecolor = 'k', label = f"{i + 1}")
        points.append(point)
        point.remove()


    patch1 = plt.scatter(0, 0, color = 'w', marker = 'D')
    patch2 = plt.scatter(0, 0, color='w', marker = 'P')
    patches = [patch1, patch2]
    patch1.remove()
    patch2.remove()

      
    legend1 = fig.legend(handles = patches,
                        labels = ['True Value', 'Predicted Value'],
                        bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')

    legend2 = fig.legend(handles = points, loc = 'upper center', ncol = N, borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend1.get_texts():
        plt.setp(text, color = 'w')

    for text in legend2.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %%
#@title Function to plot pmf of distribution for set of parameters

def plotPMFSet(dist, mean, true, N, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"PMF of {name} prior", fontsize = 20)
    fig.text(0.5, 0.05, "Density", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)
    plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))

    sample = dist.rvs(10000)
    plt.hist(sample, alpha = 0.5, color = 'tab:blue')

    points = []

    for i in range(N):
        plt.scatter(mean[i], 10, alpha = 0.8, s = 10, marker = 'P', edgecolor = 'k')
    for i in range(N):
        plt.scatter(true[i], 10, alpha = 0.8, s = 10, marker = 'D', edgecolor = 'k')
    for i in range(N):
        point = plt.scatter(0, 0, edgecolor = 'k', label = f"{i + 1}")
        points.append(point)
        point.remove()


    patch1 = plt.scatter(0, 0, color = 'w', marker = 'D')
    patch2 = plt.scatter(0, 0, color='w', marker = 'P')
    patches = [patch1, patch2]
    patch1.remove()
    patch2.remove()

      
    legend1 = fig.legend(handles = patches,
                        labels = ['True Value', 'Predicted Value'],
                        bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend1.get_texts():
        plt.setp(text, color = 'w')

    legend2 = fig.legend(handles = points, loc = 'upper center', ncol = N, borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend2.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %% [markdown]
# ## Walk of value

# %%
#@title function to plot walk of single parameter

def plotWalk(sample, true, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"Walk of {name}", fontsize = 20)
    fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

    plt.xlim(0, len(sample))
    plt.plot(range(len(sample)), sample, label = "Predicted Value", c = 'lightblue')
    plt.plot([0, len(sample)], [true, true], '--', label = 'True value', c = 'tab:orange')

    legend = fig.legend(handles = [plt.Line2D([0,1], [0,1], linestyle = '--', color = 'tab:orange'), 
                        plt.Line2D([0,1], [0,1], color = 'lightblue')], 
                        labels = ['True Value', 'Predicted Value'],
                        bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %%
#@title function to plot walk of set of parameters

def plotWalkSet(sample, true, N, name):
  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Walk of {name}", fontsize = 20)

  plt.xlim(0, len(sample[:, 0]))
  fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))
  trueLines = []

  for i in range(N):
    predLine, = plt.plot(range(len(sample[:, i])), sample[:, i], alpha = 0.5)
    
  for i in range(N):  
    trueLine, = plt.plot([0, len(sample[:, i])], [true[i], true[i]], '--')
    trueLines.append(trueLine)
    
  
  legend1 = fig.legend(handles = trueLines, labels = range(1, N + 1), loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend1.get_texts():
        plt.setp(text, color = 'w')

  legend2 = fig.legend(handles = [plt.Line2D([0,1], [0,1], linestyle = '--', color = 'w'), 
                      plt.Line2D([0,1], [0,1], color = 'w')], 
                      labels = ['True Value', 'Predicted Value'],
                      bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend2.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# ## Walk of likelihood

# %%
#@title function to plot likelihood walk of single parameter

def plotLikelihood(likelihood, sites, length, name):
  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Walk of Likelihood of {name}", fontsize = 20)
  
  fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Likelihood", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  likelihoodLine, = plt.plot(range(len(likelihood[:])), np.e**(likelihood[:]/(sites*length)), '--', c = 'lightblue')
  
  plt.show()

# %%
#@title function to plot likelihood walk of set of parameters

def plotLikelihoodSet(likelihood, sites, length, N, name):
  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Walk of Likelihood of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Likelihood", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))
  likelihoodLines = []

  for i in range(N):
    likelihoodLine, = plt.plot(range(len(likelihood[:, i])), np.e**(likelihood[:, i]/(sites*length)), '--', alpha = 0.5)
    likelihoodLines.append(likelihoodLine)

  legend = fig.legend(handles = likelihoodLines, labels = range(1, N + 1), loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# ## Histogram

# %%
#@title Function to plot histogram for single parameter

def plotHist(sample, true, name):

  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Histogram of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Frequency", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.hist(sample, color = 'lightblue', alpha = 0.5, bins = 100)
  patch1 = plt.scatter(np.mean(sample), 10, alpha = 0.8, s = 10, marker = 'P', c = 'g', label = 'True value')
  patch2 = plt.scatter(true, 10, alpha = 0.8, s = 10, marker = 'D', c = 'r', label = 'Predicted Value')
  patches = [patch1, patch2]

    
  legend = fig.legend(handles = patches,
                      labels = ['True Value', 'Predicted Value'],
                      bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %%
#@title Function to plot histogram for set of parameters

def plotHistSet(sample, true, N, name):

  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Histogram of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Frequency", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))

  hists = []
  rectBoxes = []

  for i in range(N):
      hist = plt.hist(sample[:, i], bins = 100, alpha = 0.5)
      hists.append(hist[2].__getitem__(1).get_facecolor())

  for i in range(N):
      plt.scatter(np.mean(sample[:, i]), 10, alpha = 0.8, s = 10, marker = 'P', edgecolor = 'k')

  for i in range(N):
      plt.scatter(true[i], 10, alpha = 0.8, s = 10, marker = 'D', edgecolor = 'k')

  for i in range(N):
      rect = patch.Patch(label = f"{i + 1}", facecolor = hists[i], edgecolor = 'k')
      rectBoxes.append(rect)

  patch1 = plt.scatter(0, 0, color = 'w', marker = 'D')
  patch2 = plt.scatter(0, 0, color='w', marker = 'P')
  patches = [patch1, patch2]
  patch1.remove()
  patch2.remove()

  legend1 = fig.legend(handles = rectBoxes, loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')

  for text in legend1.get_texts():
        plt.setp(text, color = 'w')

  legend2 = fig.legend(handles = patches,
                      labels = ['True Value', 'Predicted Value'],
                      bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend2.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# ## Scatterplot of likelihood

# %%
#@title Function to plot scatterplot of likelihood for single parameter
def plotScatterLikelihood(sample, likelihood, sites, length, true, name):

  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Scatterplot of Likelihood of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Likelihood", ha = 'center', va = 'center', rotation = 90, fontsize = 15)


  plt.scatter(sample, np.e**(likelihood/(sites*length)), alpha = 0.1, c = 'lightblue')

  point0 = plt.scatter(0, 0, edgecolor = 'w', c = 'lightblue')
  point1 = plt.scatter(true, 0, marker = 'D', s = 10, edgecolor = 'w', facecolor = 'g')
  point2 = plt.scatter(np.mean(sample), 0, s = 10, marker = 'P', edgecolor = 'w', facecolor = 'r')
  points = [point0, point1, point2]
  point0.remove()

  legend = fig.legend(handles = points,
                    labels = ['Likelihood values', 'True Value', 'Predicted Value'],
                    bbox_to_anchor = (0.875, 0.1), borderpad = 0.2, 
                    facecolor = 'k', edgecolor = 'w', ncol = 2)

  for text in legend.get_texts():
        plt.setp(text, color = 'w')

# %%
#@title Function to plot scatterplot of likelihood for set of parameters
def plotScatterLikelihoodSet(sample, likelihood, sites, length, true, N, name):

  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Scatterplot of Likelihood of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Likelihood", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))
  values = []

  for i in range(N):
      plt.scatter(sample, np.e**(likelihood/(sites*length)), alpha = 0.05)
  for i in range(N):
      plt.scatter(true[i], 0, marker = 'D', s = 10, edgecolor = 'k')
  for i in range(N):
      plt.scatter(np.mean(sample[:, i]), 0, s = 10, marker = 'P', edgecolor = 'k')
  for i in range(N):
      point = plt.scatter(0, 0, edgecolor = 'k', label = f"{i + 1}")
      values.append(point)

  point0 = plt.scatter(0, 0, edgecolor = 'w', c = 'w')
  point1 = plt.scatter(0, 0, marker = 'D', edgecolor = 'w', facecolor = 'w')
  point2 = plt.scatter(0, 0, marker = 'P', edgecolor = 'w', facecolor = 'w')
  points = [point0, point1, point2]
  point0.remove()
  point1.remove()
  point2.remove()

  legend1 = fig.legend(handles = values, loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend1.get_texts():
        plt.setp(text, color = 'w')

  legend2 = fig.legend(handles = points,
                    labels = ['Likelihood values', 'True Value', 'Predicted Value'],
                    bbox_to_anchor = (0.875, 0.1), borderpad = 0.2, 
                    facecolor = 'k', edgecolor = 'w', ncol = 2)
  
  for text in legend2.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# ## Walk of Accept ratio

# %%
#@title Function to plot Walk of Accept Ratio for single parameter

def plotAcceptRatio(sample, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"Walk of Accept Ratio for {name}", fontsize = 20)
    fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Ratio", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

    plt.xlim(0, len(sample))
    plt.plot(range(len(sample)), sample, label = "Predicted Value", c = 'lightblue')

    plt.show()

# %%
#@title Function to plot Walk of Accept Ratio for set of parameters


def plotAcceptRatioSet(sample, N, name):
  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Walk of Accept Ratio for {name}", fontsize = 20)
  plt.xlim(0, len(sample[:, 0]))
  fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)
  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))
  
  predLines = []

  for i in range(N):
    predLine, = plt.plot(range(len(sample[:, i])), sample[:, i], alpha = 0.5, label = f"{i + 1}")
    predLines.append(predLine)

  legend = fig.legend(handles = predLines, loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# # Toy example for algae bloom

# %%
#@title Importing pmat

drive.mount('drive')

pmatRaw = pd.read_csv("https://drive.google.com/uc?export=download&id=18qzQ-2TRETglAGLSXRZekyQqK7QxXUff")
pmat = pmatRaw.copy()
pmat = pmat.set_index('Unnamed: 0')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
#@title Calculates Mit based upon parameters and Mi(t - 1)

def findMNew(M, t, A, Alpha, Beta, S, pmat):

  start = S
  growth = Alpha*(A*M)
  transport = Beta*np.dot(M, pmat)

  MNew = start + growth + transport

  return MNew

# %%
#@title generates sample with randomly generated parameter
def runSimulation(sites, length, pmat):

    Alpha = stats.gamma(2, scale = 1).rvs()
    Beta = stats.beta(4, 3).rvs()

    # Forcing N = 1 for MH purposes
    # N = 1
    N =  stats.randint(1, int(length/10)).rvs()
    A = np.zeros((length, sites))
    S = np.zeros((length, sites))

    IArray = []
    TArray = []
    WArray = []
    SArray = []

    for n in range(N):
        i = stats.randint(0, sites - 1).rvs()
        #T = 30
        IArray.append(i)
        T = stats.randint(1, length - 1).rvs()
        TArray.append(T)
        W = int(stats.nbinom.rvs(6, 0.75)) + 1
        WArray.append(W)

        A[range(T, (min(T + W, length))), i] = 1
        Size = stats.gamma(1, scale = 1).rvs()
        S[T, i] = Size
        SArray.append(Size)

    M = np.zeros(sites)
    MArray = np.zeros((sites, length))

    #print(f"Alpha: {Alpha}")
    #print(f"Beta: {Beta}")
    #print(f"T: {T}")
    #print(f"W: {W}")

    pDiag = [pmat.iloc[i, i] for i in range(sites)]

    for t in range(length):

        M = findMNew(M, t, A[t, :], Alpha, Beta, S[t, :], np.array(pmat.iloc[:sites, :sites]))
        MArray[:, t] = M

    return MArray, Alpha, Beta, N, IArray, TArray, WArray, SArray

# %%
#@title Runs simulation with given parameters

def getSample(sites, length, pmat, alpha, beta, N, I, T, W, Size):

    if (len(T) != N) or (len(W) != N) or (len(Size) != N) or (len(I) != N):
        print(N)
        print(len(T), len(W), len(Size))
        print("Error: Wrong length parameter vectors")
        return

    A = np.zeros((length, sites))
    S = np.zeros((length, sites))
    
    for n in range(N):
        A[range(T[n], (min(T[n] + W[n], length))), I[n]] = 1
        S[T[n], I[n]] = Size[n]

    M = np.zeros(sites)
    MArray = np.zeros((sites, length))
    #print(f"Alpha: {alpha}")
    #print(f"Beta: {beta}")
    #print(f"T: {T}")
    #print(f"W: {W}")

    for t in range(length):

        M = findMNew(M, t, A[t, :], alpha, beta, S[t, :], np.array(pmat.iloc[:sites, :sites]))
        MArray[:, t] = M

    return MArray

# %%
#@title Function to convert mass into concentration

def convertConcentration(sites, length, M, V, delta):

    C = np.zeros((sites, length))
    for i in range(sites):
        C[i, :] = M[i, :]/V[i]
    if C.any() < 0:
        print("Negative Concentration")
    LogCArray = np.log(delta + C)

    return LogCArray

# %%
#@title Converting Concentration to Y

def convertY(C, tau):

    LogYArray = stats.norm(C, 1/np.sqrt(tau)).rvs()
    
    return LogYArray

# %% [markdown]
# Parameters known:
# - t = length of time
# - i = number of sites
# - delta = dummy parameter to ensure log(delta + Mit/Vit) works
# - V = (i x 1) vector of Volumes per site
# ---
# Parameters to be estimated:
# - Alpha = growth parameter
# - Beta = decay parameter
# - N = Number of events
# - I = (n x 1) Vector of sites per event
# - S = (i x t) Vector of Size Parameters
# - A = (i x t) Vector of activation time
# - T = (n x 1) vector of Start time parameters
# - W = (n x 1) vector of Length of time parameters
# - Epsilon = Error parameter

# %% [markdown]
# ## MH sampler with unknown T

# %%
#@title MH sampler - Not even close

sites = 10
length = 100
delta = 0.0000000001
trueTau = stats.gamma(1, scale = 1).rvs()
V = stats.nbinom(1, .1).rvs(sites) + 1
seed = stats.randint(1, 100).rvs()

sample, trueAlpha, trueBeta, trueN, trueI, trueT, trueW, trueS = runSimulation(sites, length, pmat)

CArray = convertConcentration(sites, length, sample, V, delta)
Y = convertY(CArray, trueTau)

# Prior parameters

  # Alpha
alphaA0 = 2
alphaB0 = 1
alphaPrior = stats.gamma(alphaA0, scale = 1/alphaB0)
alpha0 = alphaPrior.rvs()

  # Beta
betaA0 = 1
betaB0 = 1
betaPrior = stats.beta(betaA0, betaB0)
beta0 = betaPrior.rvs()

  # N
NA0 = 0.1
NPrior = stats.geom(NA0)
N0 = trueN
# N0 = int(NPrior.rvs())

  # I
IA0 = 0
IB0 = sites
IPrior = stats.randint(IA0, IB0)
I0 = IPrior.rvs(N0)

  # T
TA0 = 0
TB0 = length
TPrior = stats.randint(TA0, TB0)
T0 = TPrior.rvs(N0)

  # W
WA0 = 6
WB0 = 0.75
WPrior = stats.nbinom(WA0, WB0)
W0 = WPrior.rvs(N0)

  # S
SA0 = 1
SB0 = 1
SPrior = stats.gamma(SA0, scale = 1/SB0)
# S0 = [SPrior.rvs()]
S0 = SPrior.rvs(N0)

  # Tau
tauA0 = 1
tauB0 = 1
tauPrior = stats.gamma(tauA0, scale = 1/tauB0)
tau0 = tauPrior.rvs()

phi = [alpha0, beta0, N0, I0, T0, W0, S0, tau0]
S = 10000
PHI = dict.fromkeys(range(S))
PHI[0] = phi

alphaArray = np.zeros((S,))
betaArray = np.zeros((S,))
IArray = np.zeros((S, N0))
TArray = np.zeros((S, N0))
WArray = np.zeros((S, N0))
SArray = np.zeros((S, N0))
tauArray = np.zeros((S,))

alphaLikelihoodArray = np.zeros((S - 1,))
betaLikelihoodArray = np.zeros((S - 1,))
ILikelihoodArray = np.zeros((S - 1, N0))
TLikelihoodArray = np.zeros((S - 1, N0))
WLikelihoodArray = np.zeros((S - 1, N0))
SLikelihoodArray = np.zeros((S - 1, N0))
tauLikelihoodArray = np.zeros((S - 1,))

alphaLikelihoodArray = np.zeros((S,))
betaLikelihoodArray = np.zeros((S,))
ILikelihoodArray = np.zeros((S, N0))
TLikelihoodArray = np.zeros((S, N0))
WLikelihoodArray = np.zeros((S, N0))
SLikelihoodArray = np.zeros((S, N0))
tauLikelihoodArray = np.zeros((S,))

alphaRatioArray = np.zeros((S - 1,))
betaRatioArray = np.zeros((S - 1,))
IRatioArray = np.zeros((S - 1, N0))
TRatioArray = np.zeros((S - 1, N0))
WRatioArray = np.zeros((S - 1, N0))
SRatioArray = np.zeros((S - 1, N0))
tauRatioArray = np.zeros((S - 1,))

alphaArray[0] = alpha0
betaArray[0] = beta0
IArray[0, :] = I0
TArray[0, :] = T0
WArray[0, :] = W0
SArray[0, :] = S0
tauArray[0] = tau0

alphaAccept = 0
betaAccept = 0
IAccept = 0
TAccept = 0
WAccept = 0
SAccept = 0
tauAccept = 0

start = time.time()
for s in range(1, S):
  # Alpha
    # Grabbing candidate alpha
    qDistAlpha = stats.norm(phi[0], .5)
    alphaCandidate = qDistAlpha.rvs()
    qDistAlphaCandidate = stats.norm(alphaCandidate, .5)

    # Calculating mass and concentrations
    massSampleCandidate = getSample(sites, length, pmat, alphaCandidate, phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)

    massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)

    # Calculating probability
        # Prior
    priorCandidateP = alphaPrior.logpdf(alphaCandidate)
    priorCurrentP = alphaPrior.logpdf(phi[0])

        # Likelihood
    pArrayCandidate = stats.norm(concSampleCandidate, 1/np.sqrt(phi[7])).logpdf(Y)
    pArrayCurrent = stats.norm(concSampleCurrent, 1/np.sqrt(phi[7])).logpdf(Y)

    likelihoodCandidateP = pArrayCandidate.sum()
    likelihoodCurrentP = pArrayCurrent.sum()

        # Proposal
    qCandidate = qDistAlpha.logpdf(alphaCandidate)
    qCurrent = qDistAlphaCandidate.logpdf(phi[0])

    ratio = min((priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate), 1)
    alphaRatioArray[s - 1] = ratio

    # Accept/Reject Alpha
    u = np.log(stats.uniform().rvs())
    if ratio >= u:
        #print("Accepted Alpha: ", s)
        phi[0] = alphaCandidate
        alphaAccept += 1
        alphaLikelihoodArray[s - 1] = likelihoodCandidateP
    else:
        alphaLikelihoodArray[s - 1] = likelihoodCurrentP

    alphaArray[s] = phi[0]


  # Beta
    # Grabbing candidate beta
    qDistBeta = stats.beta(1, 1)
    betaCandidate = qDistBeta.rvs()
    qDistBetaCandidate = stats.beta(1, 1)

    # Calculating mass and concentrations
    massSampleCandidate = getSample(sites, length, pmat, phi[0], betaCandidate, phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)

    massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)

    # Calculating probability
        # Prior
    priorCandidateP = betaPrior.logpdf(betaCandidate)
    priorCurrentP = betaPrior.logpdf(phi[1])

        # Likelihood
    pArrayCandidate = stats.norm(concSampleCandidate, 1/np.sqrt(phi[7])).logpdf(Y)
    pArrayCurrent = stats.norm(concSampleCurrent, 1/np.sqrt(phi[7])).logpdf(Y)

    likelihoodCandidateP = pArrayCandidate.sum()
    likelihoodCurrentP = pArrayCurrent.sum()

        # Proposal
    qCandidate = qDistBeta.logpdf(betaCandidate)
    qCurrent = qDistBetaCandidate.logpdf(phi[1])

    #print(pCandidate, pPrior)
    ratio = min((priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate), 1)
    betaRatioArray[s - 1] = ratio

    # Accept/Reject Beta
    u = np.log(stats.uniform().rvs())
    if ratio >= u:
        #print("Accepted Beta: ", s)
        phi[1] = betaCandidate
        betaAccept += 1
        betaLikelihoodArray[s - 1] = likelihoodCandidateP
    else:
        betaLikelihoodArray[s - 1] = likelihoodCurrentP

    betaArray[s] = phi[1]

    # I
    for site in range(phi[2]):
        # Grabbing candidate Ii
        qDistI = stats.randint(0, sites)
        iCandidate = qDistI.rvs()
        ICandidate = phi[3].copy()
        ICandidate[site] = iCandidate

        # Calculating mass and concentrations
        massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], ICandidate, phi[4], phi[5], phi[6])
        concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)

        massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
        concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)

        # Calculating probability
            # Prior
        priorCandidateP = IPrior.logpmf(iCandidate)
        priorCurrentP = IPrior.logpmf(phi[3][site])

            # Likelihood
        pArrayCandidate = stats.norm(concSampleCandidate, 1/np.sqrt(phi[7])).logpdf(Y)
        pArrayCurrent = stats.norm(concSampleCurrent, 1/np.sqrt(phi[7])).logpdf(Y)

        likelihoodCandidateP = pArrayCandidate.sum()
        likelihoodCurrentP = pArrayCurrent.sum()

        pCandidate = priorCandidateP*likelihoodCandidateP
        pPrior = priorCurrentP*likelihoodCurrentP

            # Proposal
        qCandidate = qDistI.logpmf(iCandidate)
        qCurrent = qDistI.logpmf(phi[3][site])

        #print(pCandidate, pPrior)
        ratio = min((priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate), 1)
        IRatioArray[s - 1, site] = ratio

        # Accept/Reject I
        u = np.log(stats.uniform().rvs())
        if ratio >= u:
            #print(f"Accepted I{site}: ", s)
            phi[3] = ICandidate
            IAccept += 1/phi[2]
            ILikelihoodArray[s - 1, site] = likelihoodCandidateP
        else:
            ILikelihoodArray[s - 1, site] = likelihoodCurrentP

    IArray[s, :] = phi[3]

    # T
    for t in range(phi[2]):
        # Grabbing candidate Ti
        qDistT = stats.randint(0, length)
        tCandidate = qDistT.rvs()
        TCandidate = phi[4].copy()
        TCandidate[t] = tCandidate
        qDisttCandidate = stats.randint(0, length)

        # Calculating mass and concentrations
        massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], TCandidate, phi[5], phi[6])
        concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)

        massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
        concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)

        # Calculating probability
            # Prior
        priorCandidateP = TPrior.logpmf(tCandidate)
        priorCurrentP = TPrior.logpmf(phi[4][t])

            # Likelihood
        pArrayCandidate = stats.norm(concSampleCandidate, 1/np.sqrt(phi[7])).logpdf(Y)
        pArrayCurrent = stats.norm(concSampleCurrent, 1/np.sqrt(phi[7])).logpdf(Y)

        likelihoodCandidateP = pArrayCandidate.sum()
        likelihoodCurrentP = pArrayCurrent.sum()

        pCandidate = priorCandidateP*likelihoodCandidateP
        pCurrent = priorCurrentP*likelihoodCurrentP

            # Proposal
        qCandidate = qDistT.logpmf(tCandidate)
        qCurrent = qDisttCandidate.logpmf(phi[4][t])

        #print(pCandidate, pPrior)
        ratio = min((priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate), 1)
        TRatioArray[s - 1, t] = ratio

        # Accept/Reject T
        u = np.log(stats.uniform().rvs())

        if ratio >= u:
            #print(f"Accepted T{t}: ", s)
            phi[4] = TCandidate
            TAccept += 1/phi[2]
            TLikelihoodArray[s - 1, t] = likelihoodCandidateP
        else:
            TLikelihoodArray[s - 1, t] = likelihoodCurrentP
            
    TArray[s] = phi[4]

      # W
        # Grabbing candidate W
    for w in range(phi[2]):
        qDistW = stats.binom(length, (phi[5][w] + 1)/(length + 2))
        wCandidate = qDistW.rvs()
        WCandidate = phi[5].copy()
        WCandidate[w] = wCandidate
        qDistwCandidate = stats.binom(length, (wCandidate + 1)/(length + 2))

        # Calculating mass and concentrations
        massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], WCandidate, phi[6])
        concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)

        massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
        concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)

        # Calculating probability
            # Prior
        priorCandidateP = WPrior.logpmf(wCandidate)
        priorCurrentP = WPrior.logpmf(phi[5][w])

            # Likelihood
        pArrayCandidate = stats.norm(concSampleCandidate, 1/np.sqrt(phi[7])).logpdf(Y)
        pArrayCurrent = stats.norm(concSampleCurrent, 1/np.sqrt(phi[7])).logpdf(Y)

        likelihoodCandidateP = pArrayCandidate.sum()
        likelihoodCurrentP = pArrayCurrent.sum()

        pCandidate = priorCandidateP*likelihoodCandidateP
        pCurrent = priorCurrentP*likelihoodCurrentP

            # Proposal
        qCandidate = qDistW.logpmf(wCandidate)
        qCurrent = qDistwCandidate.logpmf(phi[5][w])

        #print(pCandidate, pPrior)
        ratio = min((priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate), 1)
        WRatioArray[s - 1, w] = ratio

        # Accept/Reject W
        u = np.log(stats.uniform().rvs())
        if ratio >= u:
            #print(f"Accepted W{w}: ", s)
            phi[5] = WCandidate
            WAccept += 1/phi[2]
            WLikelihoodArray[s - 1, w] = likelihoodCandidateP
        else:
            WLikelihoodArray[s - 1, w] = likelihoodCurrentP

    WArray[s] = phi[5]

      # S
        # Grabbing candidate S
    for size in range(phi[2]):
        qDists = stats.norm(phi[6][size], 1)
        sCandidate = qDists.rvs()
        SCandidate = phi[6].copy()
        SCandidate[size] = sCandidate
        qDistsCandidate = stats.norm(sCandidate, 1)

        # Calculating mass and concentrations
        massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], SCandidate)
        concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)

        massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
        concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)

        # Calculating probability
            # Prior
        priorCandidateP = SPrior.logpdf(sCandidate)
        priorCurrentP = SPrior.logpdf(phi[6][size])

            # Likelihood
        pArrayCandidate = stats.norm(concSampleCandidate, 1/np.sqrt(phi[7])).logpdf(Y)
        pArrayCurrent = stats.norm(concSampleCurrent, 1/np.sqrt(phi[7])).logpdf(Y)

        likelihoodCandidateP = pArrayCandidate.sum()
        likelihoodCurrentP = pArrayCurrent.sum()

            # Proposal
        qCandidate = qDists.logpdf(sCandidate)
        qCurrent = qDistsCandidate.logpdf(phi[6][size])

        #print(pCandidate, pPrior)
        ratio = min((priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate), 1)
        SRatioArray[s - 1, size] = ratio

        # Accept/Reject S
        u = np.log(stats.uniform().rvs())
        if ratio >= u:
            #print(f"Accepted S{size}: ", s)
            phi[6] = SCandidate
            SAccept += 1/phi[2]
            SLikelihoodArray[s - 1, size] = likelihoodCandidateP
        else:
            SLikelihoodArray[s - 1, size] = likelihoodCurrentP

    SArray[s] = phi[6]

  # Tau
    # Grabbing candidate Tau
    qDistTau = stats.norm(phi[7], .5)
    tauCandidate = qDistTau.rvs()
    qDistTauCandidate = stats.norm(tauCandidate, .5)

    # Calculating mass and concentrations
    massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)

    massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)

    # Calculating probability
        # Prior
    priorCandidateP = tauPrior.logpdf(tauCandidate)
    priorCurrentP = tauPrior.logpdf(phi[7])

        # Likelihood
    pArrayCandidate = stats.norm(concSampleCandidate, 1/np.sqrt(tauCandidate)).logpdf(Y)
    pArrayCurrent = stats.norm(concSampleCurrent, 1/np.sqrt(phi[7])).logpdf(Y)

    likelihoodCandidateP = pArrayCandidate.sum()
    likelihoodCurrentP = pArrayCurrent.sum()

        # Proposal
    qCandidate = qDistTau.logpdf(tauCandidate)
    qCurrent = qDistTauCandidate.logpdf(phi[7])

    #print(pCandidate, pPrior)
    ratio = min((priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate), 1)
    tauRatioArray[s - 1] = ratio

    # Accept/Reject tau
    u = np.log(stats.uniform().rvs())
    if ratio >= u:
        #print("Accepted Tau: ", s)
        phi[7] = tauCandidate
        tauAccept += 1
        tauLikelihoodArray[s - 1] = likelihoodCandidateP
    else:
        tauLikelihoodArray[s - 1] = likelihoodCurrentP

    tauArray[s] = phi[7]


    newPhi = [phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6], phi[7]]
    PHI[s] = newPhi
    print(f"Completed {s}")
    print("")

# Printing computing time
end = time.time()
timeDiff = int(end - start)
hours = int(np.floor(timeDiff/60**2))
timeDiff = timeDiff - hours*(60**2)
minutes = int(np.floor(timeDiff/60))
timeDiff = int(timeDiff - minutes*60)
print(f"Computing time was {hours} hours {minutes} minutes and {timeDiff} seconds")
# Out:
# <ipython-input-284-87bfbfdaeacc>:10: RuntimeWarning: invalid value encountered in log
#   LogCArray = np.log(delta + C)
# Completed 1
#
# Completed 2
#
# Completed 3
#
# Completed 4
#
# Completed 5
#
# Completed 6
#
# Completed 7
# <ipython-input-347-9ce4b2927e40>:431: RuntimeWarning: invalid value encountered in sqrt
#   pArrayCandidate = stats.norm(concSampleCandidate, 1/np.sqrt(tauCandidate)).logpdf(Y)
# Streaming output truncated to the last 5000 lines.
#
# Completed 7501
#
# Completed 7502
#
# Completed 7503
#
# Completed 7504
#
# Completed 7505
#
# Completed 7506
#
# Completed 7507
#
# Completed 7508
#
# Completed 7509
#
# Completed 7510
#
# Completed 7511
#
# Completed 7512
#
# Completed 7513
#
# Completed 7514
#
# Completed 7515
#
# Completed 7516
#
# Completed 7517
#
# Completed 7518
#
# Completed 7519
#
# Completed 7520
#
# Completed 7521
#
# Completed 7522
#
# Completed 7523
#
# Completed 7524
#
# Completed 7525
#
# Completed 7526
#
# Completed 7527
#
# Completed 7528
#
# Completed 7529
#
# Completed 7530
#
# Completed 7531
#
# Completed 7532
#
# Completed 7533
#
# Completed 7534
#
# Completed 7535
#
# Completed 7536
#
# Completed 7537
#
# Completed 7538
#
# Completed 7539
#
# Completed 7540
#
# Completed 7541
#
# Completed 7542
#
# Completed 7543
#
# Completed 7544
#
# Completed 7545
#
# Completed 7546
#
# Completed 7547
#
# Completed 7548
#
# Completed 7549
#
# Completed 7550
#
# Completed 7551
#
# Completed 7552
#
# Completed 7553
#
# Completed 7554
#
# Completed 7555
#
# Completed 7556
#
# Completed 7557
#
# Completed 7558
#
# Completed 7559
#
# Completed 7560
#
# Completed 7561
#
# Completed 7562
#
# Completed 7563
#
# Completed 7564
#
# Completed 7565
#
# Completed 7566
#
# Completed 7567
#
# Completed 7568
#
# Completed 7569
#
# Completed 7570
#
# Completed 7571
#
# Completed 7572
#
# Completed 7573
#
# Completed 7574
#
# Completed 7575
#
# Completed 7576
#
# Completed 7577
#
# Completed 7578
#
# Completed 7579
#
# Completed 7580
#
# Completed 7581
#
# Completed 7582
#
# Completed 7583
#
# Completed 7584
#
# Completed 7585
#
# Completed 7586
#
# Completed 7587
#
# Completed 7588
#
# Completed 7589
#
# Completed 7590
#
# Completed 7591
#
# Completed 7592
#
# Completed 7593
#
# Completed 7594
#
# Completed 7595
#
# Completed 7596
#
# Completed 7597
#
# Completed 7598
#
# Completed 7599
#
# Completed 7600
#
# Completed 7601
#
# Completed 7602
#
# Completed 7603
#
# Completed 7604
#
# Completed 7605
#
# Completed 7606
#
# Completed 7607
#
# Completed 7608
#
# Completed 7609
#
# Completed 7610
#
# Completed 7611
#
# Completed 7612
#
# Completed 7613
#
# Completed 7614
#
# Completed 7615
#
# Completed 7616
#
# Completed 7617
#
# Completed 7618
#
# Completed 7619
#
# Completed 7620
#
# Completed 7621
#
# Completed 7622
#
# Completed 7623
#
# Completed 7624
#
# Completed 7625
#
# Completed 7626
#
# Completed 7627
#
# Completed 7628
#
# Completed 7629
#
# Completed 7630
#
# Completed 7631
#
# Completed 7632
#
# Completed 7633
#
# Completed 7634
#
# Completed 7635
#
# Completed 7636
#
# Completed 7637
#
# Completed 7638
#
# Completed 7639
#
# Completed 7640
#
# Completed 7641
#
# Completed 7642
#
# Completed 7643
#
# Completed 7644
#
# Completed 7645
#
# Completed 7646
#
# Completed 7647
#
# Completed 7648
#
# Completed 7649
#
# Completed 7650
#
# Completed 7651
#
# Completed 7652
#
# Completed 7653
#
# Completed 7654
#
# Completed 7655
#
# Completed 7656
#
# Completed 7657
#
# Completed 7658
#
# Completed 7659
#
# Completed 7660
#
# Completed 7661
#
# Completed 7662
#
# Completed 7663
#
# Completed 7664
#
# Completed 7665
#
# Completed 7666
#
# Completed 7667
#
# Completed 7668
#
# Completed 7669
#
# Completed 7670
#
# Completed 7671
#
# Completed 7672
#
# Completed 7673
#
# Completed 7674
#
# Completed 7675
#
# Completed 7676
#
# Completed 7677
#
# Completed 7678
#
# Completed 7679
#
# Completed 7680
#
# Completed 7681
#
# Completed 7682
#
# Completed 7683
#
# Completed 7684
#
# Completed 7685
#
# Completed 7686
#
# Completed 7687
#
# Completed 7688
#
# Completed 7689
#
# Completed 7690
#
# Completed 7691
#
# Completed 7692
#
# Completed 7693
#
# Completed 7694
#
# Completed 7695
#
# Completed 7696
#
# Completed 7697
#
# Completed 7698
#
# Completed 7699
#
# Completed 7700
#
# Completed 7701
#
# Completed 7702
#
# Completed 7703
#
# Completed 7704
#
# Completed 7705
#
# Completed 7706
#
# Completed 7707
#
# Completed 7708
#
# Completed 7709
#
# Completed 7710
#
# Completed 7711
#
# Completed 7712
#
# Completed 7713
#
# Completed 7714
#
# Completed 7715
#
# Completed 7716
#
# Completed 7717
#
# Completed 7718
#
# Completed 7719
#
# Completed 7720
#
# Completed 7721
#
# Completed 7722
#
# Completed 7723
#
# Completed 7724
#
# Completed 7725
#
# Completed 7726
#
# Completed 7727
#
# Completed 7728
#
# Completed 7729
#
# Completed 7730
#
# Completed 7731
#
# Completed 7732
#
# Completed 7733
#
# Completed 7734
#
# Completed 7735
#
# Completed 7736
#
# Completed 7737
#
# Completed 7738
#
# Completed 7739
#
# Completed 7740
#
# Completed 7741
#
# Completed 7742
#
# Completed 7743
#
# Completed 7744
#
# Completed 7745
#
# Completed 7746
#
# Completed 7747
#
# Completed 7748
#
# Completed 7749
#
# Completed 7750
#
# Completed 7751
#
# Completed 7752
#
# Completed 7753
#
# Completed 7754
#
# Completed 7755
#
# Completed 7756
#
# Completed 7757
#
# Completed 7758
#
# Completed 7759
#
# Completed 7760
#
# Completed 7761
#
# Completed 7762
#
# Completed 7763
#
# Completed 7764
#
# Completed 7765
#
# Completed 7766
#
# Completed 7767
#
# Completed 7768
#
# Completed 7769
#
# Completed 7770
#
# Completed 7771
#
# Completed 7772
#
# Completed 7773
#
# Completed 7774
#
# Completed 7775
#
# Completed 7776
#
# Completed 7777
#
# Completed 7778
#
# Completed 7779
#
# Completed 7780
#
# Completed 7781
#
# Completed 7782
#
# Completed 7783
#
# Completed 7784
#
# Completed 7785
#
# Completed 7786
#
# Completed 7787
#
# Completed 7788
#
# Completed 7789
#
# Completed 7790
#
# Completed 7791
#
# Completed 7792
#
# Completed 7793
#
# Completed 7794
#
# Completed 7795
#
# Completed 7796
#
# Completed 7797
#
# Completed 7798
#
# Completed 7799
#
# Completed 7800
#
# Completed 7801
#
# Completed 7802
#
# Completed 7803
#
# Completed 7804
#
# Completed 7805
#
# Completed 7806
#
# Completed 7807
#
# Completed 7808
#
# Completed 7809
#
# Completed 7810
#
# Completed 7811
#
# Completed 7812
#
# Completed 7813
#
# Completed 7814
#
# Completed 7815
#
# Completed 7816
#
# Completed 7817
#
# Completed 7818
#
# Completed 7819
#
# Completed 7820
#
# Completed 7821
#
# Completed 7822
#
# Completed 7823
#
# Completed 7824
#
# Completed 7825
#
# Completed 7826
#
# Completed 7827
#
# Completed 7828
#
# Completed 7829
#
# Completed 7830
#
# Completed 7831
#
# Completed 7832
#
# Completed 7833
#
# Completed 7834
#
# Completed 7835
#
# Completed 7836
#
# Completed 7837
#
# Completed 7838
#
# Completed 7839
#
# Completed 7840
#
# Completed 7841
#
# Completed 7842
#
# Completed 7843
#
# Completed 7844
#
# Completed 7845
#
# Completed 7846
#
# Completed 7847
#
# Completed 7848
#
# Completed 7849
#
# Completed 7850
#
# Completed 7851
#
# Completed 7852
#
# Completed 7853
#
# Completed 7854
#
# Completed 7855
#
# Completed 7856
#
# Completed 7857
#
# Completed 7858
#
# Completed 7859
#
# Completed 7860
#
# Completed 7861
#
# Completed 7862
#
# Completed 7863
#
# Completed 7864
#
# Completed 7865
#
# Completed 7866
#
# Completed 7867
#
# Completed 7868
#
# Completed 7869
#
# Completed 7870
#
# Completed 7871
#
# Completed 7872
#
# Completed 7873
#
# Completed 7874
#
# Completed 7875
#
# Completed 7876
#
# Completed 7877
#
# Completed 7878
#
# Completed 7879
#
# Completed 7880
#
# Completed 7881
#
# Completed 7882
#
# Completed 7883
#
# Completed 7884
#
# Completed 7885
#
# Completed 7886
#
# Completed 7887
#
# Completed 7888
#
# Completed 7889
#
# Completed 7890
#
# Completed 7891
#
# Completed 7892
#
# Completed 7893
#
# Completed 7894
#
# Completed 7895
#
# Completed 7896
#
# Completed 7897
#
# Completed 7898
#
# Completed 7899
#
# Completed 7900
#
# Completed 7901
#
# Completed 7902
#
# Completed 7903
#
# Completed 7904
#
# Completed 7905
#
# Completed 7906
#
# Completed 7907
#
# Completed 7908
#
# Completed 7909
#
# Completed 7910
#
# Completed 7911
#
# Completed 7912
#
# Completed 7913
#
# Completed 7914
#
# Completed 7915
#
# Completed 7916
#
# Completed 7917
#
# Completed 7918
#
# Completed 7919
#
# Completed 7920
#
# Completed 7921
#
# Completed 7922
#
# Completed 7923
#
# Completed 7924
#
# Completed 7925
#
# Completed 7926
#
# Completed 7927
#
# Completed 7928
#
# Completed 7929
#
# Completed 7930
#
# Completed 7931
#
# Completed 7932
#
# Completed 7933
#
# Completed 7934
#
# Completed 7935
#
# Completed 7936
#
# Completed 7937
#
# Completed 7938
#
# Completed 7939
#
# Completed 7940
#
# Completed 7941
#
# Completed 7942
#
# Completed 7943
#
# Completed 7944
#
# Completed 7945
#
# Completed 7946
#
# Completed 7947
#
# Completed 7948
#
# Completed 7949
#
# Completed 7950
#
# Completed 7951
#
# Completed 7952
#
# Completed 7953
#
# Completed 7954
#
# Completed 7955
#
# Completed 7956
#
# Completed 7957
#
# Completed 7958
#
# Completed 7959
#
# Completed 7960
#
# Completed 7961
#
# Completed 7962
#
# Completed 7963
#
# Completed 7964
#
# Completed 7965
#
# Completed 7966
#
# Completed 7967
#
# Completed 7968
#
# Completed 7969
#
# Completed 7970
#
# Completed 7971
#
# Completed 7972
#
# Completed 7973
#
# Completed 7974
#
# Completed 7975
#
# Completed 7976
#
# Completed 7977
#
# Completed 7978
#
# Completed 7979
#
# Completed 7980
#
# Completed 7981
#
# Completed 7982
#
# Completed 7983
#
# Completed 7984
#
# Completed 7985
#
# Completed 7986
#
# Completed 7987
#
# Completed 7988
#
# Completed 7989
#
# Completed 7990
#
# Completed 7991
#
# Completed 7992
#
# Completed 7993
#
# Completed 7994
#
# Completed 7995
#
# Completed 7996
#
# Completed 7997
#
# Completed 7998
#
# Completed 7999
#
# Completed 8000
#
# Completed 8001
#
# Completed 8002
#
# Completed 8003
#
# Completed 8004
#
# Completed 8005
#
# Completed 8006
#
# Completed 8007
#
# Completed 8008
#
# Completed 8009
#
# Completed 8010
#
# Completed 8011
#
# Completed 8012
#
# Completed 8013
#
# Completed 8014
#
# Completed 8015
#
# Completed 8016
#
# Completed 8017
#
# Completed 8018
#
# Completed 8019
#
# Completed 8020
#
# Completed 8021
#
# Completed 8022
#
# Completed 8023
#
# Completed 8024
#
# Completed 8025
#
# Completed 8026
#
# Completed 8027
#
# Completed 8028
#
# Completed 8029
#
# Completed 8030
#
# Completed 8031
#
# Completed 8032
#
# Completed 8033
#
# Completed 8034
#
# Completed 8035
#
# Completed 8036
#
# Completed 8037
#
# Completed 8038
#
# Completed 8039
#
# Completed 8040
#
# Completed 8041
#
# Completed 8042
#
# Completed 8043
#
# Completed 8044
#
# Completed 8045
#
# Completed 8046
#
# Completed 8047
#
# Completed 8048
#
# Completed 8049
#
# Completed 8050
#
# Completed 8051
#
# Completed 8052
#
# Completed 8053
#
# Completed 8054
#
# Completed 8055
#
# Completed 8056
#
# Completed 8057
#
# Completed 8058
#
# Completed 8059
#
# Completed 8060
#
# Completed 8061
#
# Completed 8062
#
# Completed 8063
#
# Completed 8064
#
# Completed 8065
#
# Completed 8066
#
# Completed 8067
#
# Completed 8068
#
# Completed 8069
#
# Completed 8070
#
# Completed 8071
#
# Completed 8072
#
# Completed 8073
#
# Completed 8074
#
# Completed 8075
#
# Completed 8076
#
# Completed 8077
#
# Completed 8078
#
# Completed 8079
#
# Completed 8080
#
# Completed 8081
#
# Completed 8082
#
# Completed 8083
#
# Completed 8084
#
# Completed 8085
#
# Completed 8086
#
# Completed 8087
#
# Completed 8088
#
# Completed 8089
#
# Completed 8090
#
# Completed 8091
#
# Completed 8092
#
# Completed 8093
#
# Completed 8094
#
# Completed 8095
#
# Completed 8096
#
# Completed 8097
#
# Completed 8098
#
# Completed 8099
#
# Completed 8100
#
# Completed 8101
#
# Completed 8102
#
# Completed 8103
#
# Completed 8104
#
# Completed 8105
#
# Completed 8106
#
# Completed 8107
#
# Completed 8108
#
# Completed 8109
#
# Completed 8110
#
# Completed 8111
#
# Completed 8112
#
# Completed 8113
#
# Completed 8114
#
# Completed 8115
#
# Completed 8116
#
# Completed 8117
#
# Completed 8118
#
# Completed 8119
#
# Completed 8120
#
# Completed 8121
#
# Completed 8122
#
# Completed 8123
#
# Completed 8124
#
# Completed 8125
#
# Completed 8126
#
# Completed 8127
#
# Completed 8128
#
# Completed 8129
#
# Completed 8130
#
# Completed 8131
#
# Completed 8132
#
# Completed 8133
#
# Completed 8134
#
# Completed 8135
#
# Completed 8136
#
# Completed 8137
#
# Completed 8138
#
# Completed 8139
#
# Completed 8140
#
# Completed 8141
#
# Completed 8142
#
# Completed 8143
#
# Completed 8144
#
# Completed 8145
#
# Completed 8146
#
# Completed 8147
#
# Completed 8148
#
# Completed 8149
#
# Completed 8150
#
# Completed 8151
#
# Completed 8152
#
# Completed 8153
#
# Completed 8154
#
# Completed 8155
#
# Completed 8156
#
# Completed 8157
#
# Completed 8158
#
# Completed 8159
#
# Completed 8160
#
# Completed 8161
#
# Completed 8162
#
# Completed 8163
#
# Completed 8164
#
# Completed 8165
#
# Completed 8166
#
# Completed 8167
#
# Completed 8168
#
# Completed 8169
#
# Completed 8170
#
# Completed 8171
#
# Completed 8172
#
# Completed 8173
#
# Completed 8174
#
# Completed 8175
#
# Completed 8176
#
# Completed 8177
#
# Completed 8178
#
# Completed 8179
#
# Completed 8180
#
# Completed 8181
#
# Completed 8182
#
# Completed 8183
#
# Completed 8184
#
# Completed 8185
#
# Completed 8186
#
# Completed 8187
#
# Completed 8188
#
# Completed 8189
#
# Completed 8190
#
# Completed 8191
#
# Completed 8192
#
# Completed 8193
#
# Completed 8194
#
# Completed 8195
#
# Completed 8196
#
# Completed 8197
#
# Completed 8198
#
# Completed 8199
#
# Completed 8200
#
# Completed 8201
#
# Completed 8202
#
# Completed 8203
#
# Completed 8204
#
# Completed 8205
#
# Completed 8206
#
# Completed 8207
#
# Completed 8208
#
# Completed 8209
#
# Completed 8210
#
# Completed 8211
#
# Completed 8212
#
# Completed 8213
#
# Completed 8214
#
# Completed 8215
#
# Completed 8216
#
# Completed 8217
#
# Completed 8218
#
# Completed 8219
#
# Completed 8220
#
# Completed 8221
#
# Completed 8222
#
# Completed 8223
#
# Completed 8224
#
# Completed 8225
#
# Completed 8226
#
# Completed 8227
#
# Completed 8228
#
# Completed 8229
#
# Completed 8230
#
# Completed 8231
#
# Completed 8232
#
# Completed 8233
#
# Completed 8234
#
# Completed 8235
#
# Completed 8236
#
# Completed 8237
#
# Completed 8238
#
# Completed 8239
#
# Completed 8240
#
# Completed 8241
#
# Completed 8242
#
# Completed 8243
#
# Completed 8244
#
# Completed 8245
#
# Completed 8246
#
# Completed 8247
#
# Completed 8248
#
# Completed 8249
#
# Completed 8250
#
# Completed 8251
#
# Completed 8252
#
# Completed 8253
#
# Completed 8254
#
# Completed 8255
#
# Completed 8256
#
# Completed 8257
#
# Completed 8258
#
# Completed 8259
#
# Completed 8260
#
# Completed 8261
#
# Completed 8262
#
# Completed 8263
#
# Completed 8264
#
# Completed 8265
#
# Completed 8266
#
# Completed 8267
#
# Completed 8268
#
# Completed 8269
#
# Completed 8270
#
# Completed 8271
#
# Completed 8272
#
# Completed 8273
#
# Completed 8274
#
# Completed 8275
#
# Completed 8276
#
# Completed 8277
#
# Completed 8278
#
# Completed 8279
#
# Completed 8280
#
# Completed 8281
#
# Completed 8282
#
# Completed 8283
#
# Completed 8284
#
# Completed 8285
#
# Completed 8286
#
# Completed 8287
#
# Completed 8288
#
# Completed 8289
#
# Completed 8290
#
# Completed 8291
#
# Completed 8292
#
# Completed 8293
#
# Completed 8294
#
# Completed 8295
#
# Completed 8296
#
# Completed 8297
#
# Completed 8298
#
# Completed 8299
#
# Completed 8300
#
# Completed 8301
#
# Completed 8302
#
# Completed 8303
#
# Completed 8304
#
# Completed 8305
#
# Completed 8306
#
# Completed 8307
#
# Completed 8308
#
# Completed 8309
#
# Completed 8310
#
# Completed 8311
#
# Completed 8312
#
# Completed 8313
#
# Completed 8314
#
# Completed 8315
#
# Completed 8316
#
# Completed 8317
#
# Completed 8318
#
# Completed 8319
#
# Completed 8320
#
# Completed 8321
#
# Completed 8322
#
# Completed 8323
#
# Completed 8324
#
# Completed 8325
#
# Completed 8326
#
# Completed 8327
#
# Completed 8328
#
# Completed 8329
#
# Completed 8330
#
# Completed 8331
#
# Completed 8332
#
# Completed 8333
#
# Completed 8334
#
# Completed 8335
#
# Completed 8336
#
# Completed 8337
#
# Completed 8338
#
# Completed 8339
#
# Completed 8340
#
# Completed 8341
#
# Completed 8342
#
# Completed 8343
#
# Completed 8344
#
# Completed 8345
#
# Completed 8346
#
# Completed 8347
#
# Completed 8348
#
# Completed 8349
#
# Completed 8350
#
# Completed 8351
#
# Completed 8352
#
# Completed 8353
#
# Completed 8354
#
# Completed 8355
#
# Completed 8356
#
# Completed 8357
#
# Completed 8358
#
# Completed 8359
#
# Completed 8360
#
# Completed 8361
#
# Completed 8362
#
# Completed 8363
#
# Completed 8364
#
# Completed 8365
#
# Completed 8366
#
# Completed 8367
#
# Completed 8368
#
# Completed 8369
#
# Completed 8370
#
# Completed 8371
#
# Completed 8372
#
# Completed 8373
#
# Completed 8374
#
# Completed 8375
#
# Completed 8376
#
# Completed 8377
#
# Completed 8378
#
# Completed 8379
#
# Completed 8380
#
# Completed 8381
#
# Completed 8382
#
# Completed 8383
#
# Completed 8384
#
# Completed 8385
#
# Completed 8386
#
# Completed 8387
#
# Completed 8388
#
# Completed 8389
#
# Completed 8390
#
# Completed 8391
#
# Completed 8392
#
# Completed 8393
#
# Completed 8394
#
# Completed 8395
#
# Completed 8396
#
# Completed 8397
#
# Completed 8398
#
# Completed 8399
#
# Completed 8400
#
# Completed 8401
#
# Completed 8402
#
# Completed 8403
#
# Completed 8404
#
# Completed 8405
#
# Completed 8406
#
# Completed 8407
#
# Completed 8408
#
# Completed 8409
#
# Completed 8410
#
# Completed 8411
#
# Completed 8412
#
# Completed 8413
#
# Completed 8414
#
# Completed 8415
#
# Completed 8416
#
# Completed 8417
#
# Completed 8418
#
# Completed 8419
#
# Completed 8420
#
# Completed 8421
#
# Completed 8422
#
# Completed 8423
#
# Completed 8424
#
# Completed 8425
#
# Completed 8426
#
# Completed 8427
#
# Completed 8428
#
# Completed 8429
#
# Completed 8430
#
# Completed 8431
#
# Completed 8432
#
# Completed 8433
#
# Completed 8434
#
# Completed 8435
#
# Completed 8436
#
# Completed 8437
#
# Completed 8438
#
# Completed 8439
#
# Completed 8440
#
# Completed 8441
#
# Completed 8442
#
# Completed 8443
#
# Completed 8444
#
# Completed 8445
#
# Completed 8446
#
# Completed 8447
#
# Completed 8448
#
# Completed 8449
#
# Completed 8450
#
# Completed 8451
#
# Completed 8452
#
# Completed 8453
#
# Completed 8454
#
# Completed 8455
#
# Completed 8456
#
# Completed 8457
#
# Completed 8458
#
# Completed 8459
#
# Completed 8460
#
# Completed 8461
#
# Completed 8462
#
# Completed 8463
#
# Completed 8464
#
# Completed 8465
#
# Completed 8466
#
# Completed 8467
#
# Completed 8468
#
# Completed 8469
#
# Completed 8470
#
# Completed 8471
#
# Completed 8472
#
# Completed 8473
#
# Completed 8474
#
# Completed 8475
#
# Completed 8476
#
# Completed 8477
#
# Completed 8478
#
# Completed 8479
#
# Completed 8480
#
# Completed 8481
#
# Completed 8482
#
# Completed 8483
#
# Completed 8484
#
# Completed 8485
#
# Completed 8486
#
# Completed 8487
#
# Completed 8488
#
# Completed 8489
#
# Completed 8490
#
# Completed 8491
#
# Completed 8492
#
# Completed 8493
#
# Completed 8494
#
# Completed 8495
#
# Completed 8496
#
# Completed 8497
#
# Completed 8498
#
# Completed 8499
#
# Completed 8500
#
# Completed 8501
#
# Completed 8502
#
# Completed 8503
#
# Completed 8504
#
# Completed 8505
#
# Completed 8506
#
# Completed 8507
#
# Completed 8508
#
# Completed 8509
#
# Completed 8510
#
# Completed 8511
#
# Completed 8512
#
# Completed 8513
#
# Completed 8514
#
# Completed 8515
#
# Completed 8516
#
# Completed 8517
#
# Completed 8518
#
# Completed 8519
#
# Completed 8520
#
# Completed 8521
#
# Completed 8522
#
# Completed 8523
#
# Completed 8524
#
# Completed 8525
#
# Completed 8526
#
# Completed 8527
#
# Completed 8528
#
# Completed 8529
#
# Completed 8530
#
# Completed 8531
#
# Completed 8532
#
# Completed 8533
#
# Completed 8534
#
# Completed 8535
#
# Completed 8536
#
# Completed 8537
#
# Completed 8538
#
# Completed 8539
#
# Completed 8540
#
# Completed 8541
#
# Completed 8542
#
# Completed 8543
#
# Completed 8544
#
# Completed 8545
#
# Completed 8546
#
# Completed 8547
#
# Completed 8548
#
# Completed 8549
#
# Completed 8550
#
# Completed 8551
#
# Completed 8552
#
# Completed 8553
#
# Completed 8554
#
# Completed 8555
#
# Completed 8556
#
# Completed 8557
#
# Completed 8558
#
# Completed 8559
#
# Completed 8560
#
# Completed 8561
#
# Completed 8562
#
# Completed 8563
#
# Completed 8564
#
# Completed 8565
#
# Completed 8566
#
# Completed 8567
#
# Completed 8568
#
# Completed 8569
#
# Completed 8570
#
# Completed 8571
#
# Completed 8572
#
# Completed 8573
#
# Completed 8574
#
# Completed 8575
#
# Completed 8576
#
# Completed 8577
#
# Completed 8578
#
# Completed 8579
#
# Completed 8580
#
# Completed 8581
#
# Completed 8582
#
# Completed 8583
#
# Completed 8584
#
# Completed 8585
#
# Completed 8586
#
# Completed 8587
#
# Completed 8588
#
# Completed 8589
#
# Completed 8590
#
# Completed 8591
#
# Completed 8592
#
# Completed 8593
#
# Completed 8594
#
# Completed 8595
#
# Completed 8596
#
# Completed 8597
#
# Completed 8598
#
# Completed 8599
#
# Completed 8600
#
# Completed 8601
#
# Completed 8602
#
# Completed 8603
#
# Completed 8604
#
# Completed 8605
#
# Completed 8606
#
# Completed 8607
#
# Completed 8608
#
# Completed 8609
#
# Completed 8610
#
# Completed 8611
#
# Completed 8612
#
# Completed 8613
#
# Completed 8614
#
# Completed 8615
#
# Completed 8616
#
# Completed 8617
#
# Completed 8618
#
# Completed 8619
#
# Completed 8620
#
# Completed 8621
#
# Completed 8622
#
# Completed 8623
#
# Completed 8624
#
# Completed 8625
#
# Completed 8626
#
# Completed 8627
#
# Completed 8628
#
# Completed 8629
#
# Completed 8630
#
# Completed 8631
#
# Completed 8632
#
# Completed 8633
#
# Completed 8634
#
# Completed 8635
#
# Completed 8636
#
# Completed 8637
#
# Completed 8638
#
# Completed 8639
#
# Completed 8640
#
# Completed 8641
#
# Completed 8642
#
# Completed 8643
#
# Completed 8644
#
# Completed 8645
#
# Completed 8646
#
# Completed 8647
#
# Completed 8648
#
# Completed 8649
#
# Completed 8650
#
# Completed 8651
#
# Completed 8652
#
# Completed 8653
#
# Completed 8654
#
# Completed 8655
#
# Completed 8656
#
# Completed 8657
#
# Completed 8658
#
# Completed 8659
#
# Completed 8660
#
# Completed 8661
#
# Completed 8662
#
# Completed 8663
#
# Completed 8664
#
# Completed 8665
#
# Completed 8666
#
# Completed 8667
#
# Completed 8668
#
# Completed 8669
#
# Completed 8670
#
# Completed 8671
#
# Completed 8672
#
# Completed 8673
#
# Completed 8674
#
# Completed 8675
#
# Completed 8676
#
# Completed 8677
#
# Completed 8678
#
# Completed 8679
#
# Completed 8680
#
# Completed 8681
#
# Completed 8682
#
# Completed 8683
#
# Completed 8684
#
# Completed 8685
#
# Completed 8686
#
# Completed 8687
#
# Completed 8688
#
# Completed 8689
#
# Completed 8690
#
# Completed 8691
#
# Completed 8692
#
# Completed 8693
#
# Completed 8694
#
# Completed 8695
#
# Completed 8696
#
# Completed 8697
#
# Completed 8698
#
# Completed 8699
#
# Completed 8700
#
# Completed 8701
#
# Completed 8702
#
# Completed 8703
#
# Completed 8704
#
# Completed 8705
#
# Completed 8706
#
# Completed 8707
#
# Completed 8708
#
# Completed 8709
#
# Completed 8710
#
# Completed 8711
#
# Completed 8712
#
# Completed 8713
#
# Completed 8714
#
# Completed 8715
#
# Completed 8716
#
# Completed 8717
#
# Completed 8718
#
# Completed 8719
#
# Completed 8720
#
# Completed 8721
#
# Completed 8722
#
# Completed 8723
#
# Completed 8724
#
# Completed 8725
#
# Completed 8726
#
# Completed 8727
#
# Completed 8728
#
# Completed 8729
#
# Completed 8730
#
# Completed 8731
#
# Completed 8732
#
# Completed 8733
#
# Completed 8734
#
# Completed 8735
#
# Completed 8736
#
# Completed 8737
#
# Completed 8738
#
# Completed 8739
#
# Completed 8740
#
# Completed 8741
#
# Completed 8742
#
# Completed 8743
#
# Completed 8744
#
# Completed 8745
#
# Completed 8746
#
# Completed 8747
#
# Completed 8748
#
# Completed 8749
#
# Completed 8750
#
# Completed 8751
#
# Completed 8752
#
# Completed 8753
#
# Completed 8754
#
# Completed 8755
#
# Completed 8756
#
# Completed 8757
#
# Completed 8758
#
# Completed 8759
#
# Completed 8760
#
# Completed 8761
#
# Completed 8762
#
# Completed 8763
#
# Completed 8764
#
# Completed 8765
#
# Completed 8766
#
# Completed 8767
#
# Completed 8768
#
# Completed 8769
#
# Completed 8770
#
# Completed 8771
#
# Completed 8772
#
# Completed 8773
#
# Completed 8774
#
# Completed 8775
#
# Completed 8776
#
# Completed 8777
#
# Completed 8778
#
# Completed 8779
#
# Completed 8780
#
# Completed 8781
#
# Completed 8782
#
# Completed 8783
#
# Completed 8784
#
# Completed 8785
#
# Completed 8786
#
# Completed 8787
#
# Completed 8788
#
# Completed 8789
#
# Completed 8790
#
# Completed 8791
#
# Completed 8792
#
# Completed 8793
#
# Completed 8794
#
# Completed 8795
#
# Completed 8796
#
# Completed 8797
#
# Completed 8798
#
# Completed 8799
#
# Completed 8800
#
# Completed 8801
#
# Completed 8802
#
# Completed 8803
#
# Completed 8804
#
# Completed 8805
#
# Completed 8806
#
# Completed 8807
#
# Completed 8808
#
# Completed 8809
#
# Completed 8810
#
# Completed 8811
#
# Completed 8812
#
# Completed 8813
#
# Completed 8814
#
# Completed 8815
#
# Completed 8816
#
# Completed 8817
#
# Completed 8818
#
# Completed 8819
#
# Completed 8820
#
# Completed 8821
#
# Completed 8822
#
# Completed 8823
#
# Completed 8824
#
# Completed 8825
#
# Completed 8826
#
# Completed 8827
#
# Completed 8828
#
# Completed 8829
#
# Completed 8830
#
# Completed 8831
#
# Completed 8832
#
# Completed 8833
#
# Completed 8834
#
# Completed 8835
#
# Completed 8836
#
# Completed 8837
#
# Completed 8838
#
# Completed 8839
#
# Completed 8840
#
# Completed 8841
#
# Completed 8842
#
# Completed 8843
#
# Completed 8844
#
# Completed 8845
#
# Completed 8846
#
# Completed 8847
#
# Completed 8848
#
# Completed 8849
#
# Completed 8850
#
# Completed 8851
#
# Completed 8852
#
# Completed 8853
#
# Completed 8854
#
# Completed 8855
#
# Completed 8856
#
# Completed 8857
#
# Completed 8858
#
# Completed 8859
#
# Completed 8860
#
# Completed 8861
#
# Completed 8862
#
# Completed 8863
#
# Completed 8864
#
# Completed 8865
#
# Completed 8866
#
# Completed 8867
#
# Completed 8868
#
# Completed 8869
#
# Completed 8870
#
# Completed 8871
#
# Completed 8872
#
# Completed 8873
#
# Completed 8874
#
# Completed 8875
#
# Completed 8876
#
# Completed 8877
#
# Completed 8878
#
# Completed 8879
#
# Completed 8880
#
# Completed 8881
#
# Completed 8882
#
# Completed 8883
#
# Completed 8884
#
# Completed 8885
#
# Completed 8886
#
# Completed 8887
#
# Completed 8888
#
# Completed 8889
#
# Completed 8890
#
# Completed 8891
#
# Completed 8892
#
# Completed 8893
#
# Completed 8894
#
# Completed 8895
#
# Completed 8896
#
# Completed 8897
#
# Completed 8898
#
# Completed 8899
#
# Completed 8900
#
# Completed 8901
#
# Completed 8902
#
# Completed 8903
#
# Completed 8904
#
# Completed 8905
#
# Completed 8906
#
# Completed 8907
#
# Completed 8908
#
# Completed 8909
#
# Completed 8910
#
# Completed 8911
#
# Completed 8912
#
# Completed 8913
#
# Completed 8914
#
# Completed 8915
#
# Completed 8916
#
# Completed 8917
#
# Completed 8918
#
# Completed 8919
#
# Completed 8920
#
# Completed 8921
#
# Completed 8922
#
# Completed 8923
#
# Completed 8924
#
# Completed 8925
#
# Completed 8926
#
# Completed 8927
#
# Completed 8928
#
# Completed 8929
#
# Completed 8930
#
# Completed 8931
#
# Completed 8932
#
# Completed 8933
#
# Completed 8934
#
# Completed 8935
#
# Completed 8936
#
# Completed 8937
#
# Completed 8938
#
# Completed 8939
#
# Completed 8940
#
# Completed 8941
#
# Completed 8942
#
# Completed 8943
#
# Completed 8944
#
# Completed 8945
#
# Completed 8946
#
# Completed 8947
#
# Completed 8948
#
# Completed 8949
#
# Completed 8950
#
# Completed 8951
#
# Completed 8952
#
# Completed 8953
#
# Completed 8954
#
# Completed 8955
#
# Completed 8956
#
# Completed 8957
#
# Completed 8958
#
# Completed 8959
#
# Completed 8960
#
# Completed 8961
#
# Completed 8962
#
# Completed 8963
#
# Completed 8964
#
# Completed 8965
#
# Completed 8966
#
# Completed 8967
#
# Completed 8968
#
# Completed 8969
#
# Completed 8970
#
# Completed 8971
#
# Completed 8972
#
# Completed 8973
#
# Completed 8974
#
# Completed 8975
#
# Completed 8976
#
# Completed 8977
#
# Completed 8978
#
# Completed 8979
#
# Completed 8980
#
# Completed 8981
#
# Completed 8982
#
# Completed 8983
#
# Completed 8984
#
# Completed 8985
#
# Completed 8986
#
# Completed 8987
#
# Completed 8988
#
# Completed 8989
#
# Completed 8990
#
# Completed 8991
#
# Completed 8992
#
# Completed 8993
#
# Completed 8994
#
# Completed 8995
#
# Completed 8996
#
# Completed 8997
#
# Completed 8998
#
# Completed 8999
#
# Completed 9000
#
# Completed 9001
#
# Completed 9002
#
# Completed 9003
#
# Completed 9004
#
# Completed 9005
#
# Completed 9006
#
# Completed 9007
#
# Completed 9008
#
# Completed 9009
#
# Completed 9010
#
# Completed 9011
#
# Completed 9012
#
# Completed 9013
#
# Completed 9014
#
# Completed 9015
#
# Completed 9016
#
# Completed 9017
#
# Completed 9018
#
# Completed 9019
#
# Completed 9020
#
# Completed 9021
#
# Completed 9022
#
# Completed 9023
#
# Completed 9024
#
# Completed 9025
#
# Completed 9026
#
# Completed 9027
#
# Completed 9028
#
# Completed 9029
#
# Completed 9030
#
# Completed 9031
#
# Completed 9032
#
# Completed 9033
#
# Completed 9034
#
# Completed 9035
#
# Completed 9036
#
# Completed 9037
#
# Completed 9038
#
# Completed 9039
#
# Completed 9040
#
# Completed 9041
#
# Completed 9042
#
# Completed 9043
#
# Completed 9044
#
# Completed 9045
#
# Completed 9046
#
# Completed 9047
#
# Completed 9048
#
# Completed 9049
#
# Completed 9050
#
# Completed 9051
#
# Completed 9052
#
# Completed 9053
#
# Completed 9054
#
# Completed 9055
#
# Completed 9056
#
# Completed 9057
#
# Completed 9058
#
# Completed 9059
#
# Completed 9060
#
# Completed 9061
#
# Completed 9062
#
# Completed 9063
#
# Completed 9064
#
# Completed 9065
#
# Completed 9066
#
# Completed 9067
#
# Completed 9068
#
# Completed 9069
#
# Completed 9070
#
# Completed 9071
#
# Completed 9072
#
# Completed 9073
#
# Completed 9074
#
# Completed 9075
#
# Completed 9076
#
# Completed 9077
#
# Completed 9078
#
# Completed 9079
#
# Completed 9080
#
# Completed 9081
#
# Completed 9082
#
# Completed 9083
#
# Completed 9084
#
# Completed 9085
#
# Completed 9086
#
# Completed 9087
#
# Completed 9088
#
# Completed 9089
#
# Completed 9090
#
# Completed 9091
#
# Completed 9092
#
# Completed 9093
#
# Completed 9094
#
# Completed 9095
#
# Completed 9096
#
# Completed 9097
#
# Completed 9098
#
# Completed 9099
#
# Completed 9100
#
# Completed 9101
#
# Completed 9102
#
# Completed 9103
#
# Completed 9104
#
# Completed 9105
#
# Completed 9106
#
# Completed 9107
#
# Completed 9108
#
# Completed 9109
#
# Completed 9110
#
# Completed 9111
#
# Completed 9112
#
# Completed 9113
#
# Completed 9114
#
# Completed 9115
#
# Completed 9116
#
# Completed 9117
#
# Completed 9118
#
# Completed 9119
#
# Completed 9120
#
# Completed 9121
#
# Completed 9122
#
# Completed 9123
#
# Completed 9124
#
# Completed 9125
#
# Completed 9126
#
# Completed 9127
#
# Completed 9128
#
# Completed 9129
#
# Completed 9130
#
# Completed 9131
#
# Completed 9132
#
# Completed 9133
#
# Completed 9134
#
# Completed 9135
#
# Completed 9136
#
# Completed 9137
#
# Completed 9138
#
# Completed 9139
#
# Completed 9140
#
# Completed 9141
#
# Completed 9142
#
# Completed 9143
#
# Completed 9144
#
# Completed 9145
#
# Completed 9146
#
# Completed 9147
#
# Completed 9148
#
# Completed 9149
#
# Completed 9150
#
# Completed 9151
#
# Completed 9152
#
# Completed 9153
#
# Completed 9154
#
# Completed 9155
#
# Completed 9156
#
# Completed 9157
#
# Completed 9158
#
# Completed 9159
#
# Completed 9160
#
# Completed 9161
#
# Completed 9162
#
# Completed 9163
#
# Completed 9164
#
# Completed 9165
#
# Completed 9166
#
# Completed 9167
#
# Completed 9168
#
# Completed 9169
#
# Completed 9170
#
# Completed 9171
#
# Completed 9172
#
# Completed 9173
#
# Completed 9174
#
# Completed 9175
#
# Completed 9176
#
# Completed 9177
#
# Completed 9178
#
# Completed 9179
#
# Completed 9180
#
# Completed 9181
#
# Completed 9182
#
# Completed 9183
#
# Completed 9184
#
# Completed 9185
#
# Completed 9186
#
# Completed 9187
#
# Completed 9188
#
# Completed 9189
#
# Completed 9190
#
# Completed 9191
#
# Completed 9192
#
# Completed 9193
#
# Completed 9194
#
# Completed 9195
#
# Completed 9196
#
# Completed 9197
#
# Completed 9198
#
# Completed 9199
#
# Completed 9200
#
# Completed 9201
#
# Completed 9202
#
# Completed 9203
#
# Completed 9204
#
# Completed 9205
#
# Completed 9206
#
# Completed 9207
#
# Completed 9208
#
# Completed 9209
#
# Completed 9210
#
# Completed 9211
#
# Completed 9212
#
# Completed 9213
#
# Completed 9214
#
# Completed 9215
#
# Completed 9216
#
# Completed 9217
#
# Completed 9218
#
# Completed 9219
#
# Completed 9220
#
# Completed 9221
#
# Completed 9222
#
# Completed 9223
#
# Completed 9224
#
# Completed 9225
#
# Completed 9226
#
# Completed 9227
#
# Completed 9228
#
# Completed 9229
#
# Completed 9230
#
# Completed 9231
#
# Completed 9232
#
# Completed 9233
#
# Completed 9234
#
# Completed 9235
#
# Completed 9236
#
# Completed 9237
#
# Completed 9238
#
# Completed 9239
#
# Completed 9240
#
# Completed 9241
#
# Completed 9242
#
# Completed 9243
#
# Completed 9244
#
# Completed 9245
#
# Completed 9246
#
# Completed 9247
#
# Completed 9248
#
# Completed 9249
#
# Completed 9250
#
# Completed 9251
#
# Completed 9252
#
# Completed 9253
#
# Completed 9254
#
# Completed 9255
#
# Completed 9256
#
# Completed 9257
#
# Completed 9258
#
# Completed 9259
#
# Completed 9260
#
# Completed 9261
#
# Completed 9262
#
# Completed 9263
#
# Completed 9264
#
# Completed 9265
#
# Completed 9266
#
# Completed 9267
#
# Completed 9268
#
# Completed 9269
#
# Completed 9270
#
# Completed 9271
#
# Completed 9272
#
# Completed 9273
#
# Completed 9274
#
# Completed 9275
#
# Completed 9276
#
# Completed 9277
#
# Completed 9278
#
# Completed 9279
#
# Completed 9280
#
# Completed 9281
#
# Completed 9282
#
# Completed 9283
#
# Completed 9284
#
# Completed 9285
#
# Completed 9286
#
# Completed 9287
#
# Completed 9288
#
# Completed 9289
#
# Completed 9290
#
# Completed 9291
#
# Completed 9292
#
# Completed 9293
#
# Completed 9294
#
# Completed 9295
#
# Completed 9296
#
# Completed 9297
#
# Completed 9298
#
# Completed 9299
#
# Completed 9300
#
# Completed 9301
#
# Completed 9302
#
# Completed 9303
#
# Completed 9304
#
# Completed 9305
#
# Completed 9306
#
# Completed 9307
#
# Completed 9308
#
# Completed 9309
#
# Completed 9310
#
# Completed 9311
#
# Completed 9312
#
# Completed 9313
#
# Completed 9314
#
# Completed 9315
#
# Completed 9316
#
# Completed 9317
#
# Completed 9318
#
# Completed 9319
#
# Completed 9320
#
# Completed 9321
#
# Completed 9322
#
# Completed 9323
#
# Completed 9324
#
# Completed 9325
#
# Completed 9326
#
# Completed 9327
#
# Completed 9328
#
# Completed 9329
#
# Completed 9330
#
# Completed 9331
#
# Completed 9332
#
# Completed 9333
#
# Completed 9334
#
# Completed 9335
#
# Completed 9336
#
# Completed 9337
#
# Completed 9338
#
# Completed 9339
#
# Completed 9340
#
# Completed 9341
#
# Completed 9342
#
# Completed 9343
#
# Completed 9344
#
# Completed 9345
#
# Completed 9346
#
# Completed 9347
#
# Completed 9348
#
# Completed 9349
#
# Completed 9350
#
# Completed 9351
#
# Completed 9352
#
# Completed 9353
#
# Completed 9354
#
# Completed 9355
#
# Completed 9356
#
# Completed 9357
#
# Completed 9358
#
# Completed 9359
#
# Completed 9360
#
# Completed 9361
#
# Completed 9362
#
# Completed 9363
#
# Completed 9364
#
# Completed 9365
#
# Completed 9366
#
# Completed 9367
#
# Completed 9368
#
# Completed 9369
#
# Completed 9370
#
# Completed 9371
#
# Completed 9372
#
# Completed 9373
#
# Completed 9374
#
# Completed 9375
#
# Completed 9376
#
# Completed 9377
#
# Completed 9378
#
# Completed 9379
#
# Completed 9380
#
# Completed 9381
#
# Completed 9382
#
# Completed 9383
#
# Completed 9384
#
# Completed 9385
#
# Completed 9386
#
# Completed 9387
#
# Completed 9388
#
# Completed 9389
#
# Completed 9390
#
# Completed 9391
#
# Completed 9392
#
# Completed 9393
#
# Completed 9394
#
# Completed 9395
#
# Completed 9396
#
# Completed 9397
#
# Completed 9398
#
# Completed 9399
#
# Completed 9400
#
# Completed 9401
#
# Completed 9402
#
# Completed 9403
#
# Completed 9404
#
# Completed 9405
#
# Completed 9406
#
# Completed 9407
#
# Completed 9408
#
# Completed 9409
#
# Completed 9410
#
# Completed 9411
#
# Completed 9412
#
# Completed 9413
#
# Completed 9414
#
# Completed 9415
#
# Completed 9416
#
# Completed 9417
#
# Completed 9418
#
# Completed 9419
#
# Completed 9420
#
# Completed 9421
#
# Completed 9422
#
# Completed 9423
#
# Completed 9424
#
# Completed 9425
#
# Completed 9426
#
# Completed 9427
#
# Completed 9428
#
# Completed 9429
#
# Completed 9430
#
# Completed 9431
#
# Completed 9432
#
# Completed 9433
#
# Completed 9434
#
# Completed 9435
#
# Completed 9436
#
# Completed 9437
#
# Completed 9438
#
# Completed 9439
#
# Completed 9440
#
# Completed 9441
#
# Completed 9442
#
# Completed 9443
#
# Completed 9444
#
# Completed 9445
#
# Completed 9446
#
# Completed 9447
#
# Completed 9448
#
# Completed 9449
#
# Completed 9450
#
# Completed 9451
#
# Completed 9452
#
# Completed 9453
#
# Completed 9454
#
# Completed 9455
#
# Completed 9456
#
# Completed 9457
#
# Completed 9458
#
# Completed 9459
#
# Completed 9460
#
# Completed 9461
#
# Completed 9462
#
# Completed 9463
#
# Completed 9464
#
# Completed 9465
#
# Completed 9466
#
# Completed 9467
#
# Completed 9468
#
# Completed 9469
#
# Completed 9470
#
# Completed 9471
#
# Completed 9472
#
# Completed 9473
#
# Completed 9474
#
# Completed 9475
#
# Completed 9476
#
# Completed 9477
#
# Completed 9478
#
# Completed 9479
#
# Completed 9480
#
# Completed 9481
#
# Completed 9482
#
# Completed 9483
#
# Completed 9484
#
# Completed 9485
#
# Completed 9486
#
# Completed 9487
#
# Completed 9488
#
# Completed 9489
#
# Completed 9490
#
# Completed 9491
#
# Completed 9492
#
# Completed 9493
#
# Completed 9494
#
# Completed 9495
#
# Completed 9496
#
# Completed 9497
#
# Completed 9498
#
# Completed 9499
#
# Completed 9500
#
# Completed 9501
#
# Completed 9502
#
# Completed 9503
#
# Completed 9504
#
# Completed 9505
#
# Completed 9506
#
# Completed 9507
#
# Completed 9508
#
# Completed 9509
#
# Completed 9510
#
# Completed 9511
#
# Completed 9512
#
# Completed 9513
#
# Completed 9514
#
# Completed 9515
#
# Completed 9516
#
# Completed 9517
#
# Completed 9518
#
# Completed 9519
#
# Completed 9520
#
# Completed 9521
#
# Completed 9522
#
# Completed 9523
#
# Completed 9524
#
# Completed 9525
#
# Completed 9526
#
# Completed 9527
#
# Completed 9528
#
# Completed 9529
#
# Completed 9530
#
# Completed 9531
#
# Completed 9532
#
# Completed 9533
#
# Completed 9534
#
# Completed 9535
#
# Completed 9536
#
# Completed 9537
#
# Completed 9538
#
# Completed 9539
#
# Completed 9540
#
# Completed 9541
#
# Completed 9542
#
# Completed 9543
#
# Completed 9544
#
# Completed 9545
#
# Completed 9546
#
# Completed 9547
#
# Completed 9548
#
# Completed 9549
#
# Completed 9550
#
# Completed 9551
#
# Completed 9552
#
# Completed 9553
#
# Completed 9554
#
# Completed 9555
#
# Completed 9556
#
# Completed 9557
#
# Completed 9558
#
# Completed 9559
#
# Completed 9560
#
# Completed 9561
#
# Completed 9562
#
# Completed 9563
#
# Completed 9564
#
# Completed 9565
#
# Completed 9566
#
# Completed 9567
#
# Completed 9568
#
# Completed 9569
#
# Completed 9570
#
# Completed 9571
#
# Completed 9572
#
# Completed 9573
#
# Completed 9574
#
# Completed 9575
#
# Completed 9576
#
# Completed 9577
#
# Completed 9578
#
# Completed 9579
#
# Completed 9580
#
# Completed 9581
#
# Completed 9582
#
# Completed 9583
#
# Completed 9584
#
# Completed 9585
#
# Completed 9586
#
# Completed 9587
#
# Completed 9588
#
# Completed 9589
#
# Completed 9590
#
# Completed 9591
#
# Completed 9592
#
# Completed 9593
#
# Completed 9594
#
# Completed 9595
#
# Completed 9596
#
# Completed 9597
#
# Completed 9598
#
# Completed 9599
#
# Completed 9600
#
# Completed 9601
#
# Completed 9602
#
# Completed 9603
#
# Completed 9604
#
# Completed 9605
#
# Completed 9606
#
# Completed 9607
#
# Completed 9608
#
# Completed 9609
#
# Completed 9610
#
# Completed 9611
#
# Completed 9612
#
# Completed 9613
#
# Completed 9614
#
# Completed 9615
#
# Completed 9616
#
# Completed 9617
#
# Completed 9618
#
# Completed 9619
#
# Completed 9620
#
# Completed 9621
#
# Completed 9622
#
# Completed 9623
#
# Completed 9624
#
# Completed 9625
#
# Completed 9626
#
# Completed 9627
#
# Completed 9628
#
# Completed 9629
#
# Completed 9630
#
# Completed 9631
#
# Completed 9632
#
# Completed 9633
#
# Completed 9634
#
# Completed 9635
#
# Completed 9636
#
# Completed 9637
#
# Completed 9638
#
# Completed 9639
#
# Completed 9640
#
# Completed 9641
#
# Completed 9642
#
# Completed 9643
#
# Completed 9644
#
# Completed 9645
#
# Completed 9646
#
# Completed 9647
#
# Completed 9648
#
# Completed 9649
#
# Completed 9650
#
# Completed 9651
#
# Completed 9652
#
# Completed 9653
#
# Completed 9654
#
# Completed 9655
#
# Completed 9656
#
# Completed 9657
#
# Completed 9658
#
# Completed 9659
#
# Completed 9660
#
# Completed 9661
#
# Completed 9662
#
# Completed 9663
#
# Completed 9664
#
# Completed 9665
#
# Completed 9666
#
# Completed 9667
#
# Completed 9668
#
# Completed 9669
#
# Completed 9670
#
# Completed 9671
#
# Completed 9672
#
# Completed 9673
#
# Completed 9674
#
# Completed 9675
#
# Completed 9676
#
# Completed 9677
#
# Completed 9678
#
# Completed 9679
#
# Completed 9680
#
# Completed 9681
#
# Completed 9682
#
# Completed 9683
#
# Completed 9684
#
# Completed 9685
#
# Completed 9686
#
# Completed 9687
#
# Completed 9688
#
# Completed 9689
#
# Completed 9690
#
# Completed 9691
#
# Completed 9692
#
# Completed 9693
#
# Completed 9694
#
# Completed 9695
#
# Completed 9696
#
# Completed 9697
#
# Completed 9698
#
# Completed 9699
#
# Completed 9700
#
# Completed 9701
#
# Completed 9702
#
# Completed 9703
#
# Completed 9704
#
# Completed 9705
#
# Completed 9706
#
# Completed 9707
#
# Completed 9708
#
# Completed 9709
#
# Completed 9710
#
# Completed 9711
#
# Completed 9712
#
# Completed 9713
#
# Completed 9714
#
# Completed 9715
#
# Completed 9716
#
# Completed 9717
#
# Completed 9718
#
# Completed 9719
#
# Completed 9720
#
# Completed 9721
#
# Completed 9722
#
# Completed 9723
#
# Completed 9724
#
# Completed 9725
#
# Completed 9726
#
# Completed 9727
#
# Completed 9728
#
# Completed 9729
#
# Completed 9730
#
# Completed 9731
#
# Completed 9732
#
# Completed 9733
#
# Completed 9734
#
# Completed 9735
#
# Completed 9736
#
# Completed 9737
#
# Completed 9738
#
# Completed 9739
#
# Completed 9740
#
# Completed 9741
#
# Completed 9742
#
# Completed 9743
#
# Completed 9744
#
# Completed 9745
#
# Completed 9746
#
# Completed 9747
#
# Completed 9748
#
# Completed 9749
#
# Completed 9750
#
# Completed 9751
#
# Completed 9752
#
# Completed 9753
#
# Completed 9754
#
# Completed 9755
#
# Completed 9756
#
# Completed 9757
#
# Completed 9758
#
# Completed 9759
#
# Completed 9760
#
# Completed 9761
#
# Completed 9762
#
# Completed 9763
#
# Completed 9764
#
# Completed 9765
#
# Completed 9766
#
# Completed 9767
#
# Completed 9768
#
# Completed 9769
#
# Completed 9770
#
# Completed 9771
#
# Completed 9772
#
# Completed 9773
#
# Completed 9774
#
# Completed 9775
#
# Completed 9776
#
# Completed 9777
#
# Completed 9778
#
# Completed 9779
#
# Completed 9780
#
# Completed 9781
#
# Completed 9782
#
# Completed 9783
#
# Completed 9784
#
# Completed 9785
#
# Completed 9786
#
# Completed 9787
#
# Completed 9788
#
# Completed 9789
#
# Completed 9790
#
# Completed 9791
#
# Completed 9792
#
# Completed 9793
#
# Completed 9794
#
# Completed 9795
#
# Completed 9796
#
# Completed 9797
#
# Completed 9798
#
# Completed 9799
#
# Completed 9800
#
# Completed 9801
#
# Completed 9802
#
# Completed 9803
#
# Completed 9804
#
# Completed 9805
#
# Completed 9806
#
# Completed 9807
#
# Completed 9808
#
# Completed 9809
#
# Completed 9810
#
# Completed 9811
#
# Completed 9812
#
# Completed 9813
#
# Completed 9814
#
# Completed 9815
#
# Completed 9816
#
# Completed 9817
#
# Completed 9818
#
# Completed 9819
#
# Completed 9820
#
# Completed 9821
#
# Completed 9822
#
# Completed 9823
#
# Completed 9824
#
# Completed 9825
#
# Completed 9826
#
# Completed 9827
#
# Completed 9828
#
# Completed 9829
#
# Completed 9830
#
# Completed 9831
#
# Completed 9832
#
# Completed 9833
#
# Completed 9834
#
# Completed 9835
#
# Completed 9836
#
# Completed 9837
#
# Completed 9838
#
# Completed 9839
#
# Completed 9840
#
# Completed 9841
#
# Completed 9842
#
# Completed 9843
#
# Completed 9844
#
# Completed 9845
#
# Completed 9846
#
# Completed 9847
#
# Completed 9848
#
# Completed 9849
#
# Completed 9850
#
# Completed 9851
#
# Completed 9852
#
# Completed 9853
#
# Completed 9854
#
# Completed 9855
#
# Completed 9856
#
# Completed 9857
#
# Completed 9858
#
# Completed 9859
#
# Completed 9860
#
# Completed 9861
#
# Completed 9862
#
# Completed 9863
#
# Completed 9864
#
# Completed 9865
#
# Completed 9866
#
# Completed 9867
#
# Completed 9868
#
# Completed 9869
#
# Completed 9870
#
# Completed 9871
#
# Completed 9872
#
# Completed 9873
#
# Completed 9874
#
# Completed 9875
#
# Completed 9876
#
# Completed 9877
#
# Completed 9878
#
# Completed 9879
#
# Completed 9880
#
# Completed 9881
#
# Completed 9882
#
# Completed 9883
#
# Completed 9884
#
# Completed 9885
#
# Completed 9886
#
# Completed 9887
#
# Completed 9888
#
# Completed 9889
#
# Completed 9890
#
# Completed 9891
#
# Completed 9892
#
# Completed 9893
#
# Completed 9894
#
# Completed 9895
#
# Completed 9896
#
# Completed 9897
#
# Completed 9898
#
# Completed 9899
#
# Completed 9900
#
# Completed 9901
#
# Completed 9902
#
# Completed 9903
#
# Completed 9904
#
# Completed 9905
#
# Completed 9906
#
# Completed 9907
#
# Completed 9908
#
# Completed 9909
#
# Completed 9910
#
# Completed 9911
#
# Completed 9912
#
# Completed 9913
#
# Completed 9914
#
# Completed 9915
#
# Completed 9916
#
# Completed 9917
#
# Completed 9918
#
# Completed 9919
#
# Completed 9920
#
# Completed 9921
#
# Completed 9922
#
# Completed 9923
#
# Completed 9924
#
# Completed 9925
#
# Completed 9926
#
# Completed 9927
#
# Completed 9928
#
# Completed 9929
#
# Completed 9930
#
# Completed 9931
#
# Completed 9932
#
# Completed 9933
#
# Completed 9934
#
# Completed 9935
#
# Completed 9936
#
# Completed 9937
#
# Completed 9938
#
# Completed 9939
#
# Completed 9940
#
# Completed 9941
#
# Completed 9942
#
# Completed 9943
#
# Completed 9944
#
# Completed 9945
#
# Completed 9946
#
# Completed 9947
#
# Completed 9948
#
# Completed 9949
#
# Completed 9950
#
# Completed 9951
#
# Completed 9952
#
# Completed 9953
#
# Completed 9954
#
# Completed 9955
#
# Completed 9956
#
# Completed 9957
#
# Completed 9958
#
# Completed 9959
#
# Completed 9960
#
# Completed 9961
#
# Completed 9962
#
# Completed 9963
#
# Completed 9964
#
# Completed 9965
#
# Completed 9966
#
# Completed 9967
#
# Completed 9968
#
# Completed 9969
#
# Completed 9970
#
# Completed 9971
#
# Completed 9972
#
# Completed 9973
#
# Completed 9974
#
# Completed 9975
#
# Completed 9976
#
# Completed 9977
#
# Completed 9978
#
# Completed 9979
#
# Completed 9980
#
# Completed 9981
#
# Completed 9982
#
# Completed 9983
#
# Completed 9984
#
# Completed 9985
#
# Completed 9986
#
# Completed 9987
#
# Completed 9988
#
# Completed 9989
#
# Completed 9990
#
# Completed 9991
#
# Completed 9992
#
# Completed 9993
#
# Completed 9994
#
# Completed 9995
#
# Completed 9996
#
# Completed 9997
#
# Completed 9998
#
# Completed 9999
#
# Computing time was 2 hours 33 minutes and 26 seconds

# %% [markdown]
# # Results

# %%
#@title Printing acceptance probabilities

for (accept, name) in [(alphaAccept, 'alpha'), (betaAccept, 'beta'), (IAccept, 'I'), (TAccept, 'T'), (WAccept, 'W'), (SAccept, 'S'), (tauAccept, 'Tau')]:
    print(f"{name} Acceptance rate: {format(accept/S, '.4f')}")
# Out:
# alpha Acceptance rate: 0.0257
# beta Acceptance rate: 0.0056
# I Acceptance rate: 0.0992
# T Acceptance rate: 0.0104
# W Acceptance rate: 0.2327
# S Acceptance rate: 0.1059
# Tau Acceptance rate: 0.0903

# %%
print(f"{trueAlpha}, {np.mean(alphaArray)}")
# Out:
# 0.949706262222259, 0.7468666174358436

# %%
print(f"{trueBeta}, {np.mean(betaArray)}")
# Out:
# 0.20913646112019232, 0.18453600492673256

# %%
for i in range(trueN):  
    print(trueI[i], int(stats.mode(IArray[:, i])[0]))
# Out:
# 7 8
# 7 8
# 1 0
# 8 0
# 8 3
# 3 7
# 0 7
# 0 1
# 8 8

# %%
for i in range(trueN):  
    print(trueT[i], int(stats.mode(TArray[:, i])[0]))
# Out:
# 46 85
# 43 72
# 77 71
# 85 23
# 36 12
# 12 43
# 71 44
# 23 77
# 72 36

# %%
for i in range(trueN):  
    print(trueW[i], int(stats.mode(WArray[:, i])[0]))
# Out:
# 6 2
# 2 5
# 2 3
# 1 7
# 2 3
# 2 1
# 3 9
# 6 3
# 4 2

# %%
for i in range(trueN):  
    print(trueS[i], np.mean(SArray[:, i]))
# Out:
# 0.2986383406778054 0.3775584052375416
# 0.9351363131813081 1.7505350057051081
# 0.3663467281894117 0.039485537501801934
# 0.6987130617043981 2.119450785755634
# 0.03398706215629239 0.2076856673788969
# 0.2904580749195223 0.9486984934715421
# 0.023319144374326403 0.27656622648314916
# 1.2707756291654373 0.30633008057557115
# 1.6734979275200303 0.05132382360202141

# %%
print(f"{trueTau}, {np.mean(tauArray)}")
# Out:
# 0.8869491971228427, 0.8460945227356018

# %% [markdown]
# ## Plotting results

# %%
#@title Plotting true mass sample
plotResults(sample, sites, length, "True Mass Sample", "Mass")

# %%
#@title Plotting true C sample

plotResults(CArray, sites, length, "True Concentration Sample", "Concentration")

# %%
#@title Plotting true Y Sample

plotResults(Y, sites, length, "True Y Sample", "Y")

# %%
#@title Plotting true Y sample - Converted from log
plotResults(np.e**Y, sites, length, "True Y Sample - Converted from Log", "e^Y")

# %%
#@title Plotting Mass sample determined from parameters
massSample = getSample(sites, length, pmat, np.mean(alphaArray), np.mean(betaArray), phi[2], 
                       [int(stats.mode(IArray[:, i])[0]) for i in range(phi[2])], [int(stats.mode(TArray[:, i])[0]) for i in range(phi[2])], 
                       [int(stats.mode(WArray[:, i])[0]) for i in range(phi[2])], [np.mean(SArray[:, i]) for i in range(phi[2])])

plotResults(massSample, sites, length, "Predicted Mass Sample", "Mass")

# %%
#@title Plotting Concentration sample determined from parameters

concSample = convertConcentration(sites, length, massSample, V, delta)
ySample = convertY(concSample, 1/np.sqrt(np.mean(tauArray)))

plotResults(concSample, sites, length, "Predicted Concentration Sample", "Concentration")

# %%
plotResults(ySample, sites, length, "Predicted Y Sample", "Y")

# %%
#@title Plotting Concentration sample determined from parameters - converted from log
plotResults(np.e**ySample, sites, length, "Predicted Y Sample - Converted from Log", "e^Y")

# %% [markdown]
# ## Alpha

# %%
#@title Walk

plotWalk(alphaArray, trueAlpha, "Alpha")

# %%
#@title Walk of likelihood

plotLikelihood(alphaLikelihoodArray[:S-1], sites, length, "Alpha")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihood(alphaArray[1:S], alphaLikelihoodArray[:S-1], sites, length, trueAlpha, "Alpha")

# %%
#@title Histogram

plotHist(alphaArray, trueAlpha, "Alpha")

# %%
#@title PDF of prior

plotPDF(alphaPrior, np.mean(alphaArray), trueAlpha, "Alpha")

# %%
#@title Walk of accept ratio

plotAcceptRatio(np.e**(alphaRatioArray/(sites*length)), "Alpha")

# %% [markdown]
# ## Beta

# %%
#@title Walk

plotWalk(betaArray, trueBeta, "Beta")

# %%
#@title Walk of likelihood

plotLikelihood(betaLikelihoodArray[:S-1], sites, length, "Beta")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihood(betaArray[1:S], betaLikelihoodArray[:S-1], sites, length, trueBeta, "Beta")

# %%
#@title Histogram

plotHist(betaArray, trueBeta, "Beta")

# %%
#@title PDF of prior
plotPDF(betaPrior, np.mean(betaArray), trueBeta, "Beta")

# %%
#@title Walk of accept ratio

plotAcceptRatio(np.e**(betaRatioArray/(sites*length)), "Beta")

# %% [markdown]
# ## Tau

# %%
#@title Walk

plotWalk(tauArray, trueTau, "Tau")

# %%
#@title Walk of likelihood

plotLikelihood(tauLikelihoodArray[:S-1], sites, length, "Tau")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihood(tauArray[1:S], alphaLikelihoodArray[:S-1], sites, length, trueTau, "Tau")

# %%
#@title Histogram

#@title Histogram

plotHist(tauArray, trueTau, "Tau")

# %%
#@title PDF of prior

plotPDF(tauPrior, np.mean(tauArray[:S]), trueTau, "Tau")

# %%
#@title Walk of accept ratio

plotAcceptRatio(np.e**(tauRatioArray/(sites*length)), "Tau")

# %% [markdown]
# ## T

# %%
#@title Walk

plotWalkSet(TArray, trueT, phi[2], "T")

# %%
#@title Walk of likelihood

plotLikelihoodSet(TLikelihoodArray[:S - 1, :], sites, length, phi[2], "T")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihoodSet(TArray[1:S, :], TLikelihoodArray[:S - 1, :], sites, length, trueT, phi[2], "T")

# %%
#@title Histogram

plotHistSet(TArray, trueT, phi[2], "T")

# %%
#@title PMF of Prior

plotPMFSet(TPrior, [np.mean(TArray[:, i]) for i in range(phi[2])], trueT, phi[2], "T")

# %%
#@title Walk of accept ratio
plotAcceptRatioSet(np.e**(TRatioArray/(sites*length)), phi[2], "T")

# %% [markdown]
# ## W

# %%
#@title Walk

plotWalkSet(WArray, trueW, phi[2], "W")

# %%
#@title Walk of likelihood

plotLikelihoodSet(WLikelihoodArray[:S - 1, :], sites, length, phi[2], "W")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihoodSet(WArray[1:S, :], WLikelihoodArray[:S - 1, :], sites, length, trueW, phi[2], "W")

# %%
#@title Histogram
plotHistSet(WArray, trueW, phi[2], "W")

# %%
#@title PMF of Prior
plotPMFSet(WPrior, [np.mean(WArray[:, i]) for i in range(phi[2])], trueW, phi[2], "W")

# %%
#@title Walk of accept ratio
plotAcceptRatioSet(np.e**(WRatioArray/(sites*length)), phi[2], "W")

# %% [markdown]
# ## S

# %%
#@title Walk
plotWalkSet(SArray, trueS, phi[2], "S")

# %%
#@title Walk of likelihood

plotLikelihoodSet(SLikelihoodArray[:S - 1, :], sites, length, phi[2], "S")

# %%
#@title Scatterplot of likelihood
plotScatterLikelihoodSet(SArray[1:S, :], SLikelihoodArray[:S - 1, :], sites, length, trueS, phi[2], "S")

# %%
#@title Histogram

plotHistSet(SArray, trueS, phi[2], "S")

# %%
#@title PDF of Prior
plotPDFSet(SPrior, [np.mean(SArray[:, i]) for i in range(phi[2])], trueS, phi[2], "S")

# %%
#@title Walk of accept ratio
plotAcceptRatioSet(np.e**(SRatioArray/(sites*length)), phi[2], "S")

# %% [markdown]
# ## I

# %%
#@title Walk
plotWalkSet(IArray, trueI, phi[2], "I")

# %%
#@title Walk of likelihood

plotLikelihoodSet(ILikelihoodArray[:S - 1, :], sites, length, phi[2], "I")

# %%
#@title Scatterplot of likelihood
plotScatterLikelihoodSet(IArray[1:S, :], ILikelihoodArray[:S - 1, :], sites, length, trueI, phi[2], "I")

# %%
#@title Histogram
plotHistSet(IArray, trueI, phi[2], "I")

# %%
#@title PMF of Prior
plotPMFSet(IPrior, [np.mean(IArray[:, i]) for i in range(phi[2])], trueI, phi[2], "I")

# %%
#@title Walk of accept ratio
plotAcceptRatioSet(np.e**(IRatioArray/(sites*length)), phi[2], "I")
