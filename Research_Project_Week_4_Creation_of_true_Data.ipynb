# %%
#@title Importing Packages

# Utility
import math as math
import numpy as np
import pandas as pd
import random as rdm
import scipy.io as io
import scipy.stats as stats
from google.colab import drive
import networkx as nx
import time
from statsmodels.tsa.stattools import acf

# Plotting
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.colors as col
from matplotlib.animation import FuncAnimation
from functools import partial
import matplotlib.patches as patch

# %% [markdown]
# # Plotting functions

# %%
#@title Function to plot results

def plotResults(results, sites, length, name, y):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(name, fontsize = 20)
    fig.text(0.5, 0.08, "Time", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.08, 0.5, y, ha = 'center', va = 'center', rotation = 90, fontsize = 15)
    plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, sites)))

    plt.xlim(0, length)
    siteArray = []

    for i in range(sites):
        site, = plt.plot(range(length), results[i, :], label = f"{i + 1}")
        siteArray.append(site)
    
    legend = fig.legend(handles = siteArray, loc = 'upper center', borderpad = 0.2, facecolor = 'k', edgecolor = 'w', ncol = sites)
    for text in legend.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %% [markdown]
# ## Prior PDF/PMF

# %%
#@title Function to plot pdf of distribution for single parameter

def plotPDF(dist, mean, true, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"PDF of {name} prior", fontsize = 20)
    fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Density", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

    sample = dist.rvs(10000)
    plt.hist(sample, bins = 100, alpha = 0.5, color = 'lightblue')

    points = []

    plt.scatter(true, 10, marker = '+', alpha = 0.8, s = 10, facecolor = 'g')
    plt.scatter(mean, 10, marker = 'D', alpha = 0.8, s = 10, facecolor = 'r')

    patch1 = plt.scatter(0, 0, facecolor = 'g', marker = 'D')
    patch2 = plt.scatter(0, 0, facecolor = 'r', marker = '+')
    patches = [patch1, patch2]
    patch1.remove()
    patch2.remove()

      
    legend = fig.legend(handles = patches,
                        labels = ['True Value', 'Predicted Value'],
                        bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %%
#@title Function to plot pdf of distribution for set of parameters

def plotPDFSet(dist, mean, true, N, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"PDF of {name} prior", fontsize = 20)
    fig.text(0.5, 0.05, "Density", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)
    plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))

    sample = dist.rvs(10000)
    plt.hist(sample, alpha = 0.5, bins = 100, color = 'lightblue')

    points = []

    for i in range(N):
        plt.scatter(mean[i], 10, alpha = 0.8, s = 10, marker = '+')
    for i in range(N):
        plt.scatter(true[i], 10, alpha = 0.8, s = 10, marker = 'D')
    for i in range(N):
        point = plt.scatter(0, 0, edgecolor = 'k', label = f"{i + 1}")
        points.append(point)
        point.remove()


    patch1 = plt.scatter(0, 0, color = 'w', marker = 'D')
    patch2 = plt.scatter(0, 0, color= 'w', marker = '+')
    patches = [patch1, patch2]
    patch1.remove()
    patch2.remove()

      
    legend1 = fig.legend(handles = patches,
                        labels = ['True Value', 'Predicted Value'],
                        bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')

    legend2 = fig.legend(handles = points, loc = 'upper center', ncol = N, borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend1.get_texts():
        plt.setp(text, color = 'w')

    for text in legend2.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %%
#@title Function to plot pmf of distribution for set of parameters

def plotPMFSet(dist, mean, true, N, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"PMF of {name} prior", fontsize = 20)
    fig.text(0.5, 0.05, "Density", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)
    plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))

    sample = dist.rvs(10000)
    plt.hist(sample, alpha = 0.5, color = 'tab:blue')

    points = []

    for i in range(N):
        plt.scatter(mean[i], 10, alpha = 0.8, s = 10, marker = '+')
    for i in range(N):
        plt.scatter(true[i], 10, alpha = 0.8, s = 10, marker = 'D')
    for i in range(N):
        point = plt.scatter(0, 0, edgecolor = 'k', label = f"{i + 1}")
        points.append(point)
        point.remove()


    patch1 = plt.scatter(0, 0, color = 'w', marker = 'D')
    patch2 = plt.scatter(0, 0, color = 'w', marker = '+')
    patches = [patch1, patch2]
    patch1.remove()
    patch2.remove()

      
    legend1 = fig.legend(handles = patches,
                        labels = ['True Value', 'Predicted Value'],
                        bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend1.get_texts():
        plt.setp(text, color = 'w')

    legend2 = fig.legend(handles = points, loc = 'upper center', ncol = N, borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend2.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %% [markdown]
# ## Walk of value

# %%
#@title function to plot walk of single parameter

def plotWalk(sample, true, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"Walk of {name}", fontsize = 20)
    fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

    plt.xlim(0, len(sample))
    plt.plot(range(len(sample)), sample, label = "Predicted Value", c = 'lightblue')
    plt.plot([0, len(sample)], [true, true], '--', label = 'True value', c = 'tab:orange')

    legend = fig.legend(handles = [plt.Line2D([0,1], [0,1], linestyle = '--', color = 'tab:orange'), 
                        plt.Line2D([0,1], [0,1], color = 'lightblue')], 
                        labels = ['True Value', 'Predicted Value'],
                        bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                        facecolor = 'k', edgecolor = 'w')
    
    for text in legend.get_texts():
        plt.setp(text, color = 'w')

    plt.show()

# %%
#@title function to plot walk of set of parameters

def plotWalkSet(sample, true, N, name):
  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Walk of {name}", fontsize = 20)

  plt.xlim(0, len(sample[:, 0]))
  fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))
  trueLines = []

  for i in range(N):
    predLine, = plt.plot(range(len(sample[:, i])), sample[:, i], alpha = 0.5)
    
  for i in range(N):  
    trueLine, = plt.plot([0, len(sample[:, i])], [true[i], true[i]], '--')
    trueLines.append(trueLine)
    
  
  legend1 = fig.legend(handles = trueLines, labels = range(1, N + 1), loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend1.get_texts():
        plt.setp(text, color = 'w')

  legend2 = fig.legend(handles = [plt.Line2D([0,1], [0,1], linestyle = '--', color = 'w'), 
                      plt.Line2D([0,1], [0,1], color = 'w')], 
                      labels = ['True Value', 'Predicted Value'],
                      bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend2.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# ## Walk of likelihood

# %%
#@title function to plot likelihood walk

def plotLikelihood(likelihood, sites, length, name):
  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Walk of Likelihood of {name}", fontsize = 20)
  
  fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Likelihood", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  likelihoodLine, = plt.plot(range(len(likelihood[:])), np.e**(likelihood[:]/(sites*length)), '--', c = 'lightblue')
  
  plt.show()

# %% [markdown]
# ## Walk of DIC

# %%
#@title Function to plot walk of DIC

def plotDIC(dic, sites, length, name):
  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Walk of DIC of {name}", fontsize = 20)
  
  fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "DIC", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  likelihoodLine, = plt.plot(range(len(dic[:])), dic[:]/(sites*length), '--', c = 'lightblue')
  
  return ax

# %% [markdown]
# ## Walk of ESS

# %%
#@title Function to plot walk of ESS for single parameter

def plotESS(sample, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"Effective Sample Size of {name}", fontsize = 20)
    fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "ESS", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

    plt.xlim(0, len(sample))
    plt.plot(range(len(sample)), sample, label = "Predicted Value", c = 'lightblue')

    plt.show()

# %%
#@title Function to plot walk of ESS for set of parameters

def plotESSSet(sample, N, name):
  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Effective Sample Size of {name}", fontsize = 20)

  plt.xlim(0, len(sample[:, 0]))
  fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "ESS", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))
  predLines = []

  for i in range(N):
    predLine, = plt.plot(range(len(sample[:, i])), sample[:, i], alpha = 0.5)
    predLines.append(predLine)
    
  legend1 = fig.legend(handles = predLines, labels = range(1, N + 1), loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend1.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# ## Histogram

# %%
#@title Function to plot histogram for single parameter

def plotHist(sample, true, name):

  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Histogram of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Frequency", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.hist(sample, color = 'lightblue', alpha = 0.5, bins = 100)
  patch1 = plt.scatter(np.mean(sample), 10, alpha = 0.8, s = 10, marker = '+', c = 'g', label = 'True value')
  patch2 = plt.scatter(true, 10, alpha = 0.8, s = 10, marker = 'D', c = 'r', label = 'Predicted Value')
  patches = [patch1, patch2]

    
  legend = fig.legend(handles = patches,
                      labels = ['True Value', 'Predicted Value'],
                      bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %%
#@title Function to plot histogram for set of parameters

def plotHistSet(sample, true, N, name):

  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Histogram of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Frequency", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))

  hists = []
  rectBoxes = []

  for i in range(N):
      hist = plt.hist(sample[:, i], bins = 100, alpha = 0.5)
      hists.append(hist[2].__getitem__(1).get_facecolor())

  for i in range(N):
      plt.scatter(np.mean(sample[:, i]), 10, alpha = 0.8, s = 10, marker = '+')

  for i in range(N):
      plt.scatter(true[i], 10, alpha = 0.8, s = 10, marker = 'D')

  for i in range(N):
      rect = patch.Patch(label = f"{i + 1}", facecolor = hists[i], edgecolor = 'w')
      rectBoxes.append(rect)

  patch1 = plt.scatter(0, 0, color = 'w', marker = 'D')
  patch2 = plt.scatter(0, 0, color='w', marker = '+')
  patches = [patch1, patch2]
  patch1.remove()
  patch2.remove()

  legend1 = fig.legend(handles = rectBoxes, loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')

  for text in legend1.get_texts():
        plt.setp(text, color = 'w')

  legend2 = fig.legend(handles = patches,
                      labels = ['True Value', 'Predicted Value'],
                      bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend2.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %%
#@title Function to plot barplot for set of parameters

def plotHistSetDiscrete(sample, true, N, name):

  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Histogram of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Frequency", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))

  hists = []
  rectBoxes = []

  for i in range(N):
      barplotDF = pd.DataFrame(columns = ['Count'], index = np.unique(sample[:, i]))
      for j in barplotDF.index:
          barplotDF.loc[j]['Count'] = sum([1 for x in sample[:, i] if x == j])

      hist = plt.bar(barplotDF.index, barplotDF['Count'], alpha = 0.5)
      hists.append(hist[0].get_facecolor())

  for i in range(N):
      plt.scatter(np.mean(sample[:, i]), 10, alpha = 0.8, s = 10, marker = '+')

  for i in range(N):
      plt.scatter(true[i], 10, alpha = 0.8, s = 10, marker = 'D')

  for i in range(N):
      rect = patch.Patch(label = f"{i + 1}", facecolor = hists[i], edgecolor = 'w')
      rectBoxes.append(rect)

  patch1 = plt.scatter(0, 0, color = 'w', marker = 'D')
  patch2 = plt.scatter(0, 0, color='w', marker = '+')
  patches = [patch1, patch2]
  patch1.remove()
  patch2.remove()

  legend1 = fig.legend(handles = rectBoxes, loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')

  for text in legend1.get_texts():
        plt.setp(text, color = 'w')

  legend2 = fig.legend(handles = patches,
                      labels = ['True Value', 'Predicted Value'],
                      bbox_to_anchor = (0.825, 0.1), borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend2.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# ## Scatterplot of likelihood

# %%
#@title Function to plot scatterplot of likelihood for single parameter
def plotScatterLikelihood(sample, likelihood, sites, length, true, name):

  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Scatterplot of Likelihood of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Likelihood", ha = 'center', va = 'center', rotation = 90, fontsize = 15)


  plt.scatter(sample, np.e**(likelihood/(sites*length)), alpha = 0.1, c = 'lightblue')

  point0 = plt.scatter(0, 0, c = 'lightblue')
  point1 = plt.scatter(true, 0, marker = 'D', s = 10, facecolor = 'r')
  point2 = plt.scatter(np.median(sample), 0, s = 10, marker = '+', facecolor = 'g')
  points = [point0, point1, point2]
  point0.remove()

  legend = fig.legend(handles = points,
                    labels = ['Likelihood values', 'True Value', 'Predicted Value'],
                    bbox_to_anchor = (0.875, 0.1), borderpad = 0.2, 
                    facecolor = 'k', edgecolor = 'w', ncol = 2)

  for text in legend.get_texts():
        plt.setp(text, color = 'w')

# %%
#@title Function to plot scatterplot of likelihood for set of parameters
def plotScatterLikelihoodSet(sample, likelihood, sites, length, true, N, name):

  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Scatterplot of Likelihood of {name}", fontsize = 20)
  fig.text(0.5, 0.05, "Value", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Likelihood", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))
  values = []

  for i in range(N):
      plt.scatter(sample, np.e**(likelihood/(sites*length)), alpha = 0.05)
  for i in range(N):
      plt.scatter(true[i], 0, marker = 'D', s = 10, edgecolor = 'k')
  for i in range(N):
      plt.scatter(np.median(sample[:, i]), 0, s = 10, marker = '+', edgecolor = 'k')
  for i in range(N):
      point = plt.scatter(0, 0, edgecolor = 'k', label = f"{i + 1}")
      values.append(point)

  point0 = plt.scatter(0, 0, edgecolor = 'w', c = 'w')
  point1 = plt.scatter(0, 0, marker = 'D', edgecolor = 'w', facecolor = 'w')
  point2 = plt.scatter(0, 0, marker = '+', edgecolor = 'w', facecolor = 'w')
  points = [point0, point1, point2]
  point0.remove()
  point1.remove()
  point2.remove()

  legend1 = fig.legend(handles = values, loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend1.get_texts():
        plt.setp(text, color = 'w')

  legend2 = fig.legend(handles = points,
                    labels = ['Likelihood values', 'True Value', 'Predicted Value'],
                    bbox_to_anchor = (0.875, 0.1), borderpad = 0.2, 
                    facecolor = 'k', edgecolor = 'w', ncol = 2)
  
  for text in legend2.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# ## Walk of Accept ratio

# %%
#@title Function to plot Walk of Accept Ratio for single parameter

def plotAcceptRatio(sample, name):
    fig, ax = plt.subplots(figsize = (10, 5), facecolor = "xkcd:grey")
    ax.set_facecolor('k')
    plt.grid('on')

    plt.title(f"Walk of Accept Ratio for {name}", fontsize = 20)
    fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
    fig.text(0.05, 0.5, "Ratio", ha = 'center', va = 'center', rotation = 90, fontsize = 15)

    plt.xlim(0, len(sample))
    plt.ylim(0, 1)
    plt.plot(range(len(sample)), sample, label = "Predicted Value", c = 'lightblue')

    plt.show()

# %%
#@title Function to plot Walk of Accept Ratio for set of parameters


def plotAcceptRatioSet(sample, N, name):
  fig, ax = plt.subplots(figsize = (10, 5), facecolor = 'xkcd:grey')
  ax.set_facecolor('k')
  plt.grid('on')

  plt.title(f"Walk of Accept Ratio for {name}", fontsize = 20)
  plt.xlim(0, len(sample[:, 0]))
  fig.text(0.5, 0.05, "Iteration", ha = 'center', va = 'center', fontsize = 15)
  fig.text(0.05, 0.5, "Value", ha = 'center', va = 'center', rotation = 90, fontsize = 15)
  plt.rcParams["axes.prop_cycle"] = plt.cycler("color", plt.cm.rainbow(np.linspace(0, 1, N)))
  
  plt.xlim(0, len(sample))
  plt.ylim(0, 1)
  predLines = []

  for i in range(N):
    predLine, = plt.plot(range(len(sample[:, i])), sample[:, i], alpha = 0.5, label = f"{i + 1}")
    predLines.append(predLine)

  legend = fig.legend(handles = predLines, loc = 'upper center', ncol = N, borderpad = 0.2, 
                      facecolor = 'k', edgecolor = 'w')
  
  for text in legend.get_texts():
        plt.setp(text, color = 'w')
  
  plt.show()

# %% [markdown]
# # Toy example for algae bloom

# %%
#@title Importing pmat

drive.mount('drive')

pmatRaw = pd.read_csv("https://drive.google.com/uc?export=download&id=18qzQ-2TRETglAGLSXRZekyQqK7QxXUff")
pmat = pmatRaw.copy()
pmat = pmat.set_index('Unnamed: 0')
# Out:
# Mounted at drive

# %%
#@title Calculates Mit based upon parameters and Mi(t - 1)

def findMNew(M, t, A, Alpha, Beta, S, pmat):

  start = S
  growth = Alpha*(A*M)
  transport = Beta*np.dot(M, pmat)

  MNew = start + growth + transport

  return MNew

# %%
#@title generates sample with randomly generated parameter
def runSimulation(sites, length, pmat):

    Alpha = stats.gamma(2, scale = 1).rvs()
    Beta = stats.beta(4, 3).rvs()

    # Forcing N = 1 for MH purposes
    N = 5
    # N =  stats.randint(1, int(length/10)).rvs()
    A = np.zeros((length, sites))
    S = np.zeros((length, sites))

    IArray = []
    TArray = []
    WArray = []
    SArray = []

    for n in range(N):
        i = stats.randint(0, sites - 1).rvs()
        IArray.append(i)
        T = stats.randint(1, length - 1).rvs()
        TArray.append(T)
        W = int(stats.nbinom.rvs(6, 0.75)) + 1
        WArray.append(W)

        A[range(T, (min(T + W, length))), i] = 1
        Size = stats.gamma(1, scale = 1).rvs()
        S[T, i] = Size
        SArray.append(Size)

    M = np.zeros(sites)
    MArray = np.zeros((sites, length))

    #print(f"Alpha: {Alpha}")
    #print(f"Beta: {Beta}")
    #print(f"T: {T}")
    #print(f"W: {W}")

    pDiag = [pmat.iloc[i, i] for i in range(sites)]

    for t in range(length):

        M = findMNew(M, t, A[t, :], Alpha, Beta, S[t, :], np.array(pmat.iloc[:sites, :sites]))
        MArray[:, t] = M

    return MArray, Alpha, Beta, N, IArray, TArray, WArray, SArray

# %%
#@title Runs simulation with given parameters

def getSample(sites, length, pmat, alpha, beta, N, I, T, W, Size):

    if (len(T) != N) or (len(W) != N) or (len(Size) != N) or (len(I) != N):
        print(N)
        print(len(T), len(W), len(Size))
        print("Error: Wrong length parameter vectors")
        return

    A = np.zeros((length, sites))
    S = np.zeros((length, sites))
    
    for n in range(N):
        A[range(T[n], (min(T[n] + W[n], length))), I[n]] = 1
        S[T[n], I[n]] = Size[n]

    M = np.zeros(sites)
    MArray = np.zeros((sites, length))
    #print(f"Alpha: {alpha}")
    #print(f"Beta: {beta}")
    #print(f"T: {T}")
    #print(f"W: {W}")

    for t in range(length):

        M = findMNew(M, t, A[t, :], alpha, beta, S[t, :], np.array(pmat.iloc[:sites, :sites]))
        MArray[:, t] = M

    return MArray

# %%
#@title Function to convert mass into concentration

def convertConcentration(sites, length, M, V, delta):

    C = np.zeros((sites, length))
    for i in range(sites):
        C[i, :] = M[i, :]/V[i]
    if C.any() < 0:
        print("Negative Concentration")
    LogCArray = np.log(delta + C)

    return LogCArray

# %%
#@title Converting Concentration to Y

def convertY(C, tau):

    LogYArray = stats.norm(C, 1/np.sqrt(tau)).rvs()
    
    return LogYArray

# %% [markdown]
# Parameters known:
# - t = length of time
# - i = number of sites
# - delta = dummy parameter to ensure log(delta + Mit/Vit) works
# - V = (i x 1) vector of Volumes per site
# ---
# Parameters to be estimated:
# - Alpha = growth parameter
# - Beta = decay parameter
# - N = Number of events
# - I = (n x 1) Vector of sites per event
# - S = (i x t) Vector of Size Parameters
# - A = (i x t) Vector of activation time
# - T = (n x 1) vector of Start time parameters
# - W = (n x 1) vector of Length of time parameters
# - Epsilon = Error parameter

# %%
def generateObservationArrayRandom(sites, length, p):

    OArray = np.ones((sites, length))
    for i in range(sites):
      u = stats.uniform(0, 1).rvs(length)
      for j in range(length):
        if p > u[j]:
          OArray[i, j] = np.NaN
    
    return OArray

# %%
def generateObservationArraySites(sites, length, missingSites):

    OArray = np.ones((sites, length))
    for i in missingSites:
        OArray[i, :] = np.NaN

    return OArray

# %%
#@title Calculating effective sample size

def ESS(arr):
    n = len(arr)
    acfArr = acf(arr, nlags = n, fft = True)
    sums = 0
    for k in range(1, len(acfArr)):
        sums = sums + (n - k)*acfArr[k]/n

    return n/(1+2*sums)

# %%
#@title Generating data

sites = 10
length = 100
delta = 0.0000000001
trueTau = stats.gamma(1, scale = 1).rvs()
V = stats.nbinom(1, .1).rvs(sites) + 1
seed = stats.randint(1, 100).rvs()

sample, trueAlpha, trueBeta, trueN, trueI, trueT, trueW, trueS = runSimulation(sites, length, pmat)

CArray = convertConcentration(sites, length, sample, V, delta)
Y = convertY(CArray, trueTau)

OArray = generateObservationArrayRandom(sites, length, 0)

sampleObserved = sample*OArray
CArrayObserved = CArray*OArray
YObserved = Y*OArray

print(trueAlpha, trueBeta, trueN, trueI, trueT, trueW, trueS, trueTau)
# Out:
# 2.508623804656746 0.5927384620724628 5 [7, 2, 2, 5, 6] [36, 78, 6, 89, 23] [3, 1, 4, 2, 3] [0.11644151325927753, 0.11620379515687908, 0.19002387575460064, 4.574614130966091, 0.06887011036763341] 2.298576049444426

# %%
#@title Saving data

filepath_csv = "./drive/My Drive/VUW Work/2022/T3 2022/Summer Research Scholarship/Datasets/" 

filepath_csv = "./drive/My Drive/VUW Work/2022/T3 2022/Summer Research Scholarship/Datasets/" 
pd.DataFrame(sample).to_csv(filepath_csv + "MTrue_Full.csv")
pd.DataFrame(CArray).to_csv(filepath_csv + "CTrue_Full.csv")
pd.DataFrame(Y).to_csv(filepath_csv + "YTrue_Full.csv")
pd.DataFrame(sampleObserved).to_csv(filepath_csv + "MTrue_Observed.csv")
pd.DataFrame(CArrayObserved).to_csv(filepath_csv + "CTrue_Observed.csv")
pd.DataFrame(YObserved).to_csv(filepath_csv + "YTrue_Observed.csv")

params = pd.DataFrame(index = range(10), columns = ["Alpha", "Beta", "N", "I", "T", "W", "S", "Tau", "V"])
params.iloc[0]["Alpha"] = trueAlpha
params.iloc[0]["Beta"] = trueBeta
params.iloc[0]["N"] = trueN
for i in range(trueN):
    params.iloc[i]["I"] = trueI[i]
    params.iloc[i]["T"] = trueT[i]
    params.iloc[i]["W"] = trueW[i]
    params.iloc[i]["S"] = trueS[i]
params.iloc[0]["Tau"] = trueTau
params["V"] = V

params.to_csv(filepath_csv + "Parameters.csv")

# %% [markdown]
# ## MH sampler with unknown T

# %%
#@title MH sampler - Not even close

sites = 10
length = 100
delta = 0.0000000001

# Loading in true data
sample = np.array(pd.read_csv(filepath_csv + "MTrue_Full.csv").set_index('Unnamed: 0'))
CArray = np.array(pd.read_csv(filepath_csv + "CTrue_Full.csv").set_index('Unnamed: 0'))
Y = np.array(pd.read_csv(filepath_csv + "YTrue_Full.csv").set_index('Unnamed: 0'))
sampleObserved = np.array(pd.read_csv(filepath_csv + "MTrue_Observed.csv").set_index('Unnamed: 0'))
CArrayObserved = np.array(pd.read_csv(filepath_csv + "CTrue_Observed.csv").set_index('Unnamed: 0'))
YObserved = np.array(pd.read_csv(filepath_csv + "YTrue_Observed.csv").set_index('Unnamed: 0'))

# Loading in true parameters
params = pd.read_csv(filepath_csv + "Parameters.csv").drop('Unnamed: 0', axis = 1)
trueAlpha = params["Alpha"][0]
trueBeta = params["Beta"][0]
trueN = int(params["N"][0])
trueI = [int(i) for i in params["I"][:trueN]]
trueT = [int(i) for i in params["T"][:trueN]]
trueW = [int(i) for i in params["W"][:trueN]]
trueS = params["S"][:trueN]
trueTau = params["Tau"][0]
V = [int(i) for i in params["V"]]

# Prior parameters

  # Alpha
alphaA0 = 2
alphaB0 = 1
alphaPrior = stats.gamma(alphaA0, scale = 1/alphaB0)
alpha0 = alphaPrior.rvs()

  # Beta
betaA0 = 1
betaB0 = 1
betaPrior = stats.beta(betaA0, betaB0)
beta0 = betaPrior.rvs()

  # N
NA0 = 0.1
NPrior = stats.geom(NA0)
N0 = trueN
# N0 = int(NPrior.rvs())

  # I
IA0 = 0
IB0 = sites
IPrior = stats.randint(IA0, IB0)
I0 = IPrior.rvs(N0)

  # T
TA0 = 0
TB0 = length
TPrior = stats.randint(TA0, TB0)
T0 = TPrior.rvs(N0)

  # W
WA0 = 6
WB0 = 0.75
WPrior = stats.nbinom(WA0, WB0)
W0 = WPrior.rvs(N0)

  # S
SA0 = 1
SB0 = 1
SPrior = stats.gamma(SA0, scale = 1/SB0)
# S0 = [SPrior.rvs()]
S0 = SPrior.rvs(N0)

  # Tau
tauA0 = 1
tauB0 = 1
tauPrior = stats.gamma(tauA0, scale = 1/tauB0)
tau0 = tauPrior.rvs()

phi = [alpha0, beta0, N0, I0, T0, W0, S0, tau0]
S = 10000
PHI = dict.fromkeys(range(S))
PHI[0] = phi

alphaArray = np.zeros((S,))
betaArray = np.zeros((S,))
IArray = np.zeros((S, N0))
TArray = np.zeros((S, N0))
WArray = np.zeros((S, N0))
SArray = np.zeros((S, N0))
tauArray = np.zeros((S,))

alphaLikelihoodArray = np.zeros((S - 1,))
betaLikelihoodArray = np.zeros((S - 1,))
ILikelihoodArray = np.zeros((S - 1, N0))
TLikelihoodArray = np.zeros((S - 1, N0))
WLikelihoodArray = np.zeros((S - 1, N0))
SLikelihoodArray = np.zeros((S - 1, N0))
tauLikelihoodArray = np.zeros((S - 1,))

alphaESSArray = np.zeros((S - 1,))
betaESSArray = np.zeros((S - 1,))
IESSArray = np.zeros((S - 1, N0))
TESSArray = np.zeros((S - 1, N0))
WESSArray = np.zeros((S - 1, N0))
SESSArray = np.zeros((S - 1, N0))
tauESSArray = np.zeros((S - 1,))

likelihoodFullArray = np.zeros((S - 1,))
likelihoodObservedArray = np.zeros((S - 1,))

devianceFullArray = np.zeros((S - 1,))
DICFullArray = np.zeros((S - 1,))

devianceObservedArray = np.zeros((S - 1,))
DICObservedArray = np.zeros((S - 1,))

alphaRatioArray = np.zeros((S - 1,))
betaRatioArray = np.zeros((S - 1,))
IRatioArray = np.zeros((S - 1, N0))
TRatioArray = np.zeros((S - 1, N0))
WRatioArray = np.zeros((S - 1, N0))
SRatioArray = np.zeros((S - 1, N0))
tauRatioArray = np.zeros((S - 1,))

alphaArray[0] = alpha0
betaArray[0] = beta0
IArray[0, :] = I0
TArray[0, :] = T0
WArray[0, :] = W0
SArray[0, :] = S0
tauArray[0] = tau0

alphaAccept = 0
betaAccept = 0
IAccept = 0
TAccept = 0
WAccept = 0
SAccept = 0
tauAccept = 0

start = time.time()
for s in range(1, S):
  # Alpha
    # Grabbing candidate alpha
    qDistAlpha = stats.norm(phi[0], 2)
    alphaCandidate = qDistAlpha.rvs()
    qDistAlphaCandidate = stats.norm(alphaCandidate, 2)

    # Calculating mass and concentrations
    massSampleCandidate = getSample(sites, length, pmat, alphaCandidate, phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)
    concSampleCandidateObserved = concSampleCandidate*OArray

    massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)
    concSampleCurrentObserved = concSampleCurrent*OArray

    # Calculating probability
        # Prior
    priorCandidateP = alphaPrior.logpdf(alphaCandidate)
    priorCurrentP = alphaPrior.logpdf(phi[0])

        # Likelihood
    pArrayCandidate = stats.norm(concSampleCandidateObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)
    pArrayCurrent = stats.norm(concSampleCurrentObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)

    likelihoodCandidateP = np.nansum(pArrayCandidate)
    likelihoodCurrentP = np.nansum(pArrayCurrent)

        # Proposal
    qCandidate = qDistAlpha.logpdf(alphaCandidate)
    qCurrent = qDistAlphaCandidate.logpdf(phi[0])

    ratio = (priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate)
    alphaRatioArray[s - 1] = ratio

    # Accept/Reject Alpha
    u = np.log(stats.uniform().rvs())
    if ratio >= u:
        print("Accepted Alpha: ", s)
        phi[0] = alphaCandidate
        alphaAccept += 1
        alphaLikelihoodArray[s - 1] = likelihoodCandidateP
    else:
        alphaLikelihoodArray[s - 1] = likelihoodCurrentP
    
    alphaArray[s] = phi[0]
    alphaESSArray[s - 1] = ESS(alphaArray[:s])

  # Beta
    # Grabbing candidate beta
    qDistBeta = stats.beta(1, 1)
    betaCandidate = qDistBeta.rvs()
    qDistBetaCandidate = stats.beta(1, 1)

    # Calculating mass and concentrations
    massSampleCandidate = getSample(sites, length, pmat, phi[0], betaCandidate, phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)
    concSampleCandidateObserved = concSampleCandidate*OArray

    massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)
    concSampleCurrentObserved = concSampleCurrent*OArray

    # Calculating probability
        # Prior
    priorCandidateP = betaPrior.logpdf(betaCandidate)
    priorCurrentP = betaPrior.logpdf(phi[1])

        # Likelihood
    pArrayCandidate = stats.norm(concSampleCandidateObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)
    pArrayCurrent = stats.norm(concSampleCurrentObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)

    likelihoodCandidateP = np.nansum(pArrayCandidate)
    likelihoodCurrentP = np.nansum(pArrayCurrent)

        # Proposal
    qCandidate = qDistBeta.logpdf(betaCandidate)
    qCurrent = qDistBetaCandidate.logpdf(phi[1])

    #print(pCandidate, pPrior)
    ratio = (priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate)
    betaRatioArray[s - 1] = ratio

    # Accept/Reject Beta
    u = np.log(stats.uniform().rvs())
    if ratio >= u:
        print("Accepted Beta: ", s)
        phi[1] = betaCandidate
        betaAccept += 1
        betaLikelihoodArray[s - 1] = likelihoodCandidateP
    else:
        betaLikelihoodArray[s - 1] = likelihoodCurrentP

    betaArray[s] = phi[1]
    betaESSArray[s - 1] = ESS(betaArray[:s])

    # I
    for site in range(phi[2]):
        # Grabbing candidate Ii
        qDistI = stats.randint(0, sites)
        iCandidate = qDistI.rvs()
        ICandidate = phi[3].copy()
        ICandidate[site] = iCandidate

        # Calculating mass and concentrations
        massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], ICandidate, phi[4], phi[5], phi[6])
        concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)
        concSampleCandidateObserved = concSampleCandidate*OArray

        massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
        concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)
        concSampleCurrentObserved = concSampleCurrent*OArray

        # Calculating probability
            # Prior
        priorCandidateP = IPrior.logpmf(iCandidate)
        priorCurrentP = IPrior.logpmf(phi[3][site])

            # Likelihood
        pArrayCandidate = stats.norm(concSampleCandidateObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)
        pArrayCurrent = stats.norm(concSampleCurrentObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)

        likelihoodCandidateP = np.nansum(pArrayCandidate)
        likelihoodCurrentP = np.nansum(pArrayCurrent)

        pCandidate = priorCandidateP*likelihoodCandidateP
        pPrior = priorCurrentP*likelihoodCurrentP

            # Proposal
        qCandidate = qDistI.logpmf(iCandidate)
        qCurrent = qDistI.logpmf(phi[3][site])

        #print(pCandidate, pPrior)
        ratio = (priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate)
        IRatioArray[s - 1, site] = ratio

        # Accept/Reject I
        u = np.log(stats.uniform().rvs())
        if ratio >= u:
            print(f"Accepted I{site}: ", s)
            phi[3] = ICandidate
            IAccept += 1/phi[2]
            ILikelihoodArray[s - 1, site] = likelihoodCandidateP
        else:
            ILikelihoodArray[s - 1, site] = likelihoodCurrentP

        IArray[s, site] = phi[3][site]
        IESSArray[s - 1, site] = ESS(IArray[:s, site])

    # T
    for t in range(phi[2]):
        # Grabbing candidate Ti
        qDistT = stats.randint(0, length)
        tCandidate = qDistT.rvs()
        TCandidate = phi[4].copy()
        TCandidate[t] = tCandidate
        qDisttCandidate = stats.randint(0, length)

        # Calculating mass and concentrations
        massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], TCandidate, phi[5], phi[6])
        concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)
        concSampleCandidateObserved = concSampleCandidate*OArray

        massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
        concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)
        concSampleCurrentObserved = concSampleCurrent*OArray

        # Calculating probability
            # Prior
        priorCandidateP = TPrior.logpmf(tCandidate)
        priorCurrentP = TPrior.logpmf(phi[4][t])

            # Likelihood
        pArrayCandidate = stats.norm(concSampleCandidateObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)
        pArrayCurrent = stats.norm(concSampleCurrentObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)

        likelihoodCandidateP = np.nansum(pArrayCandidate)
        likelihoodCurrentP = np.nansum(pArrayCurrent)

        pCandidate = priorCandidateP*likelihoodCandidateP
        pCurrent = priorCurrentP*likelihoodCurrentP

            # Proposal
        qCandidate = qDistT.logpmf(tCandidate)
        qCurrent = qDisttCandidate.logpmf(phi[4][t])

        #print(pCandidate, pPrior)
        ratio = (priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate)
        TRatioArray[s - 1, t] = ratio

        # Accept/Reject T
        u = np.log(stats.uniform().rvs())

        if ratio >= u:
            print(f"Accepted T{t}: ", s)
            phi[4] = TCandidate
            TAccept += 1/phi[2]
            TLikelihoodArray[s - 1, t] = likelihoodCandidateP
        else:
            TLikelihoodArray[s - 1, t] = likelihoodCurrentP
            
        TArray[s, t] = phi[4][t]
        TESSArray[s - 1, t] = ESS(TArray[:s, t])

      # W
        # Grabbing candidate W
    for w in range(phi[2]):
        qDistW = stats.binom(length, (phi[5][w] + 1)/(length + 2))
        wCandidate = qDistW.rvs()
        WCandidate = phi[5].copy()
        WCandidate[w] = wCandidate
        qDistwCandidate = stats.binom(length, (wCandidate + 1)/(length + 2))

        # Calculating mass and concentrations
        massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], WCandidate, phi[6])
        concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)
        concSampleCandidateObserved = concSampleCandidate*OArray

        massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
        concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)
        concSampleCurrentObserved = concSampleCurrent*OArray

        # Calculating probability
            # Prior
        priorCandidateP = WPrior.logpmf(wCandidate)
        priorCurrentP = WPrior.logpmf(phi[5][w])

            # Likelihood
        pArrayCandidate = stats.norm(concSampleCandidateObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)
        pArrayCurrent = stats.norm(concSampleCurrentObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)

        likelihoodCandidateP = np.nansum(pArrayCandidate)
        likelihoodCurrentP = np.nansum(pArrayCurrent)

        pCandidate = priorCandidateP*likelihoodCandidateP
        pCurrent = priorCurrentP*likelihoodCurrentP

            # Proposal
        qCandidate = qDistW.logpmf(wCandidate)
        qCurrent = qDistwCandidate.logpmf(phi[5][w])

        #print(pCandidate, pPrior)
        ratio = (priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate)
        WRatioArray[s - 1, w] = ratio

        # Accept/Reject W
        u = np.log(stats.uniform().rvs())
        if ratio >= u:
            print(f"Accepted W{w}: ", s)
            phi[5] = WCandidate
            WAccept += 1/phi[2]
            WLikelihoodArray[s - 1, w] = likelihoodCandidateP
        else:
            WLikelihoodArray[s - 1, w] = likelihoodCurrentP

        WArray[s, w] = phi[5][w]
        WESSArray[s - 1, w] = ESS(WArray[:s, w])

      # S
        # Grabbing candidate S
    for size in range(phi[2]):
        qDists = stats.norm(phi[6][size], .1)
        sCandidate = qDists.rvs()
        SCandidate = phi[6].copy()
        SCandidate[size] = sCandidate
        qDistsCandidate = stats.norm(sCandidate, .1)

        # Calculating mass and concentrations
        massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], SCandidate)
        concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)
        concSampleCandidateObserved = concSampleCandidate*OArray

        massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
        concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)
        concSampleCurrentObserved = concSampleCurrent*OArray

        # Calculating probability
            # Prior
        priorCandidateP = SPrior.logpdf(sCandidate)
        priorCurrentP = SPrior.logpdf(phi[6][size])

            # Likelihood
        pArrayCandidate = stats.norm(concSampleCandidateObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)
        pArrayCurrent = stats.norm(concSampleCurrentObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)

        likelihoodCandidateP = np.nansum(pArrayCandidate)
        likelihoodCurrentP = np.nansum(pArrayCurrent)

            # Proposal
        qCandidate = qDists.logpdf(sCandidate)
        qCurrent = qDistsCandidate.logpdf(phi[6][size])

        #print(pCandidate, pPrior)
        ratio = (priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate)
        SRatioArray[s - 1, size] = ratio

        # Accept/Reject S
        u = np.log(stats.uniform().rvs())
        if ratio >= u:
            print(f"Accepted S{size}: ", s)
            phi[6] = SCandidate
            SAccept += 1/phi[2]
            SLikelihoodArray[s - 1, size] = likelihoodCandidateP
        else:
            SLikelihoodArray[s - 1, size] = likelihoodCurrentP

        SArray[s, size] = phi[6][size]
        SESSArray[s - 1, size] = ESS(SArray[:s, size])

  # Tau
    # Grabbing candidate Tau
    qDistTau = stats.norm(phi[7], .5)
    tauCandidate = qDistTau.rvs()
    qDistTauCandidate = stats.norm(tauCandidate, .5)

    # Calculating mass and concentrations
    massSampleCandidate = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCandidate = convertConcentration(sites, length, massSampleCandidate, V, delta)
    concSampleCandidateObserved = concSampleCandidate*OArray

    massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)
    concSampleCurrentObserved = concSampleCurrent*OArray

    # Calculating probability
        # Prior
    priorCandidateP = tauPrior.logpdf(tauCandidate)
    priorCurrentP = tauPrior.logpdf(phi[7])

        # Likelihood
    pArrayCandidate = stats.norm(concSampleCandidateObserved, 1/np.sqrt(tauCandidate)).logpdf(YObserved)
    pArrayCurrent = stats.norm(concSampleCurrentObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)

    likelihoodCandidateP = np.nansum(pArrayCandidate)
    likelihoodCurrentP = np.nansum(pArrayCurrent)

        # Proposal
    qCandidate = qDistTau.logpdf(tauCandidate)
    qCurrent = qDistTauCandidate.logpdf(phi[7])

    #print(pCandidate, pPrior)
    ratio = (priorCandidateP - priorCurrentP) + (likelihoodCandidateP - likelihoodCurrentP) + (qCurrent - qCandidate)
    tauRatioArray[s - 1] = ratio

    # Accept/Reject tau
    u = np.log(stats.uniform().rvs())
    if ratio >= u:
        print("Accepted Tau: ", s)
        phi[7] = tauCandidate
        tauAccept += 1
        tauLikelihoodArray[s - 1] = likelihoodCandidateP
    else:
        tauLikelihoodArray[s - 1] = likelihoodCurrentP

    tauArray[s] = phi[7]
    tauESSArray[s - 1] = ESS(tauArray[:s])

    # Likelihood
      # Calculating f(Y|phi) 
    massSampleCurrent = getSample(sites, length, pmat, phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6])
    concSampleCurrent = convertConcentration(sites, length, massSampleCurrent, V, delta)
    concSampleCurrentObserved = concSampleCurrent*OArray

    # Likelihood over observed
    pArrayCurrent = stats.norm(concSampleCurrentObserved, 1/np.sqrt(phi[7])).logpdf(YObserved)
    likelihoodObservedCurrent = np.nansum(pArrayCurrent)
    likelihoodObservedArray[s - 1] = likelihoodObservedCurrent

    # Likelihood over full
    pArrayCurrent = stats.norm(concSampleCurrent, 1/np.sqrt(phi[7])).logpdf(Y)
    likelihoodFullCurrent = np.nansum(pArrayCurrent)
    likelihoodFullArray[s - 1] = likelihoodFullCurrent

    # DIC
      # Calculating f(Y|Theta Hat)
    massSampleHat = getSample(sites, length, pmat, np.median(alphaArray), np.median(betaArray), phi[2], 
                       [int(np.median(IArray[:, i])) for i in range(phi[2])], [int(np.median(TArray[:, i])) for i in range(phi[2])], 
                       [int(np.median(WArray[:, i])) for i in range(phi[2])], [np.median(SArray[:, i]) for i in range(phi[2])])
    
    concSampleHat = convertConcentration(sites, length, massSampleCandidate, V, delta)
    concSampleHatObserved = concSampleHat*OArray

      # Full
    pArrayHat = stats.norm(concSampleHat, 1/np.sqrt(np.median(tauArray[:s]))).logpdf(Y)
    likelihoodFullHat = np.nansum(pArrayHat)

      # Calculating D, DBar and DHat
    devFull = -2*likelihoodFullCurrent
    devianceFullArray[s - 1] = devFull
    devFullBar = np.mean(devianceFullArray[:s])
    devFullHat = -2*likelihoodFullHat

      # Calculating DIC
    DICFull = 2*devFullBar - devFullHat 
    DICFullArray[s - 1] = DICFull

      # Observed
    pArrayHat = stats.norm(concSampleHatObserved, 1/np.sqrt(np.median(tauArray[:s]))).logpdf(YObserved)
    likelihoodObservedHat = np.nansum(pArrayHat)

      # Calculating D, DBar and DHat
    devObserved = -2*likelihoodObservedCurrent
    devianceObservedArray[s - 1] = devObserved
    devObservedBar = np.mean(devianceObservedArray[:s])
    devObservedHat = -2*likelihoodObservedHat

      # Calculating DIC
    DICObserved = 2*devObservedBar - devObservedHat 
    DICObservedArray[s - 1] = DICObserved
    

    newPhi = [phi[0], phi[1], phi[2], phi[3], phi[4], phi[5], phi[6], phi[7]]
    PHI[s] = newPhi
    print(f"Completed {s}")
    print("")

# Printing computing time
end = time.time()
timeDiff = int(end - start)
hours = int(np.floor(timeDiff/60**2))
timeDiff = timeDiff - hours*(60**2)
minutes = int(np.floor(timeDiff/60))
timeDiff = int(timeDiff - minutes*60)
print(f"Computing time was {hours} hours {minutes} minutes and {timeDiff} seconds")
# Out:
# /usr/local/lib/python3.8/dist-packages/statsmodels/tsa/stattools.py:677: RuntimeWarning: invalid value encountered in true_divide
#   acf = avf[: nlags + 1] / avf[0]
# Accepted I1:  1
# Accepted I3:  1
# Accepted I4:  1
# Accepted T0:  1
# Accepted T1:  1
# Accepted T2:  1
# Accepted W1:  1
# Accepted W2:  1
# Accepted W3:  1
# Accepted W4:  1
# Accepted S0:  1
# Accepted S1:  1
# Accepted S4:  1
# Accepted Tau:  1
# Completed 1
#
# Accepted I0:  2
# Accepted I1:  2
# Accepted I2:  2
# Accepted I4:  2
# Accepted T1:  2
# Accepted T3:  2
# Accepted W1:  2
# Accepted W2:  2
# Accepted S0:  2
# Accepted S1:  2
# Accepted S2:  2
# Accepted S4:  2
# Accepted Tau:  2
# Completed 2
#
# Accepted T1:  3
# Accepted W0:  3
# Accepted W2:  3
# Accepted W4:  3
# Accepted S0:  3
# Accepted S1:  3
# Accepted S2:  3
# Accepted S4:  3
# Completed 3
# <ipython-input-23-87bfbfdaeacc>:10: RuntimeWarning: invalid value encountered in log
#   LogCArray = np.log(delta + C)
# <ipython-input-57-ce206f421f34>:471: RuntimeWarning: invalid value encountered in sqrt
#   pArrayCandidate = stats.norm(concSampleCandidateObserved, 1/np.sqrt(tauCandidate)).logpdf(YObserved)
# Streaming output truncated to the last 5000 lines.
#
# Completed 8874
#
# Accepted I0:  8875
# Accepted I1:  8875
# Accepted W1:  8875
# Accepted S2:  8875
# Accepted S3:  8875
# Completed 8875
#
# Accepted Alpha:  8876
# Accepted S4:  8876
# Accepted Tau:  8876
# Completed 8876
#
# Accepted W2:  8877
# Accepted W4:  8877
# Accepted S4:  8877
# Completed 8877
#
# Accepted S2:  8878
# Completed 8878
#
# Accepted S2:  8879
# Completed 8879
#
# Accepted I1:  8880
# Accepted W0:  8880
# Accepted W2:  8880
# Completed 8880
#
# Accepted S2:  8881
# Accepted Tau:  8881
# Completed 8881
#
# Accepted W0:  8882
# Accepted W4:  8882
# Accepted S1:  8882
# Completed 8882
#
# Accepted I0:  8883
# Accepted W1:  8883
# Accepted S4:  8883
# Completed 8883
#
# Accepted S2:  8884
# Completed 8884
#
# Accepted Alpha:  8885
# Accepted W1:  8885
# Accepted W4:  8885
# Completed 8885
#
# Accepted S2:  8886
# Accepted S4:  8886
# Completed 8886
#
# Accepted I2:  8887
# Accepted W4:  8887
# Accepted S2:  8887
# Completed 8887
#
# Accepted I4:  8888
# Completed 8888
#
# Accepted W2:  8889
# Accepted W3:  8889
# Accepted W4:  8889
# Completed 8889
#
# Accepted W1:  8890
# Accepted Tau:  8890
# Completed 8890
#
# Accepted I3:  8891
# Accepted S2:  8891
# Completed 8891
#
# Accepted I3:  8892
# Accepted W0:  8892
# Accepted W4:  8892
# Accepted S2:  8892
# Accepted Tau:  8892
# Completed 8892
#
# Accepted S2:  8893
# Completed 8893
#
# Accepted S2:  8894
# Completed 8894
#
# Accepted W1:  8895
# Accepted W3:  8895
# Accepted S4:  8895
# Accepted Tau:  8895
# Completed 8895
#
# Accepted W0:  8896
# Accepted W4:  8896
# Accepted S2:  8896
# Accepted Tau:  8896
# Completed 8896
#
# Accepted I4:  8897
# Accepted W0:  8897
# Accepted W3:  8897
# Accepted W4:  8897
# Completed 8897
#
# Accepted W1:  8898
# Accepted W4:  8898
# Accepted S2:  8898
# Completed 8898
#
# Accepted I3:  8899
# Completed 8899
#
# Accepted Alpha:  8900
# Accepted W2:  8900
# Completed 8900
#
# Accepted I2:  8901
# Accepted S2:  8901
# Completed 8901
#
# Accepted I0:  8902
# Accepted S4:  8902
# Completed 8902
#
# Completed 8903
#
# Accepted T0:  8904
# Accepted S2:  8904
# Completed 8904
#
# Accepted W4:  8905
# Accepted S2:  8905
# Completed 8905
#
# Accepted I1:  8906
# Accepted W0:  8906
# Accepted W2:  8906
# Accepted S2:  8906
# Completed 8906
#
# Accepted W0:  8907
# Accepted S2:  8907
# Accepted S4:  8907
# Completed 8907
#
# Accepted W0:  8908
# Accepted W2:  8908
# Accepted S2:  8908
# Completed 8908
#
# Accepted I0:  8909
# Accepted I2:  8909
# Accepted I3:  8909
# Accepted S2:  8909
# Completed 8909
#
# Accepted W0:  8910
# Accepted W2:  8910
# Accepted S2:  8910
# Completed 8910
#
# Accepted I2:  8911
# Accepted S2:  8911
# Completed 8911
#
# Accepted W2:  8912
# Accepted S2:  8912
# Completed 8912
#
# Accepted W3:  8913
# Accepted S2:  8913
# Accepted S3:  8913
# Completed 8913
#
# Accepted Alpha:  8914
# Accepted W0:  8914
# Completed 8914
#
# Accepted W3:  8915
# Completed 8915
#
# Completed 8916
#
# Accepted W2:  8917
# Completed 8917
#
# Accepted Alpha:  8918
# Accepted I1:  8918
# Accepted I2:  8918
# Accepted W2:  8918
# Accepted S2:  8918
# Accepted S4:  8918
# Completed 8918
#
# Accepted W3:  8919
# Accepted S2:  8919
# Completed 8919
#
# Accepted I0:  8920
# Accepted W3:  8920
# Accepted W4:  8920
# Accepted S4:  8920
# Accepted Tau:  8920
# Completed 8920
#
# Accepted I0:  8921
# Completed 8921
#
# Accepted Alpha:  8922
# Accepted W4:  8922
# Accepted S2:  8922
# Accepted S4:  8922
# Completed 8922
#
# Accepted W3:  8923
# Accepted W4:  8923
# Completed 8923
#
# Accepted I1:  8924
# Accepted W1:  8924
# Accepted W3:  8924
# Accepted S2:  8924
# Completed 8924
#
# Accepted I1:  8925
# Accepted W2:  8925
# Accepted W4:  8925
# Accepted S2:  8925
# Accepted Tau:  8925
# Completed 8925
#
# Accepted W0:  8926
# Accepted S2:  8926
# Completed 8926
#
# Accepted W2:  8927
# Accepted W3:  8927
# Accepted S3:  8927
# Accepted Tau:  8927
# Completed 8927
#
# Accepted I2:  8928
# Accepted T3:  8928
# Accepted W1:  8928
# Accepted W4:  8928
# Completed 8928
#
# Accepted S2:  8929
# Completed 8929
#
# Accepted W4:  8930
# Completed 8930
#
# Accepted W2:  8931
# Accepted W3:  8931
# Completed 8931
#
# Accepted S2:  8932
# Completed 8932
#
# Accepted W3:  8933
# Accepted S2:  8933
# Completed 8933
#
# Accepted W0:  8934
# Completed 8934
#
# Accepted I4:  8935
# Completed 8935
#
# Accepted I0:  8936
# Accepted S2:  8936
# Completed 8936
#
# Accepted I0:  8937
# Completed 8937
#
# Accepted I4:  8938
# Accepted W1:  8938
# Accepted W3:  8938
# Completed 8938
#
# Accepted I4:  8939
# Accepted W3:  8939
# Completed 8939
#
# Accepted W0:  8940
# Accepted W4:  8940
# Completed 8940
#
# Accepted W4:  8941
# Accepted S4:  8941
# Completed 8941
#
# Accepted W0:  8942
# Accepted S2:  8942
# Completed 8942
#
# Accepted Tau:  8943
# Completed 8943
#
# Accepted I0:  8944
# Completed 8944
#
# Accepted W0:  8945
# Accepted W1:  8945
# Accepted S4:  8945
# Completed 8945
#
# Accepted W1:  8946
# Accepted W2:  8946
# Accepted Tau:  8946
# Completed 8946
#
# Accepted I0:  8947
# Accepted W1:  8947
# Accepted W3:  8947
# Accepted S4:  8947
# Completed 8947
#
# Completed 8948
#
# Accepted W2:  8949
# Accepted W4:  8949
# Completed 8949
#
# Accepted I4:  8950
# Accepted W4:  8950
# Accepted S2:  8950
# Completed 8950
#
# Accepted W2:  8951
# Accepted W4:  8951
# Accepted S2:  8951
# Completed 8951
#
# Accepted Alpha:  8952
# Accepted W4:  8952
# Accepted S2:  8952
# Accepted S4:  8952
# Accepted Tau:  8952
# Completed 8952
#
# Accepted I0:  8953
# Accepted I2:  8953
# Completed 8953
#
# Accepted W2:  8954
# Accepted W4:  8954
# Accepted S4:  8954
# Completed 8954
#
# Accepted S4:  8955
# Completed 8955
#
# Accepted S2:  8956
# Completed 8956
#
# Accepted S2:  8957
# Completed 8957
#
# Accepted W1:  8958
# Completed 8958
#
# Accepted I1:  8959
# Accepted I2:  8959
# Accepted S2:  8959
# Accepted S4:  8959
# Accepted Tau:  8959
# Completed 8959
#
# Accepted S2:  8960
# Completed 8960
#
# Accepted W0:  8961
# Accepted W4:  8961
# Completed 8961
#
# Accepted I2:  8962
# Completed 8962
#
# Accepted T1:  8963
# Accepted S2:  8963
# Accepted Tau:  8963
# Completed 8963
#
# Accepted S2:  8964
# Accepted Tau:  8964
# Completed 8964
#
# Accepted I0:  8965
# Accepted S2:  8965
# Completed 8965
#
# Accepted W0:  8966
# Accepted W2:  8966
# Accepted S2:  8966
# Completed 8966
#
# Accepted W2:  8967
# Accepted S2:  8967
# Completed 8967
#
# Accepted W1:  8968
# Accepted W3:  8968
# Accepted W4:  8968
# Completed 8968
#
# Accepted I4:  8969
# Accepted S2:  8969
# Completed 8969
#
# Accepted I2:  8970
# Accepted S2:  8970
# Completed 8970
#
# Accepted I2:  8971
# Completed 8971
#
# Accepted I0:  8972
# Accepted S2:  8972
# Completed 8972
#
# Accepted I1:  8973
# Accepted W0:  8973
# Accepted W3:  8973
# Accepted Tau:  8973
# Completed 8973
#
# Accepted Alpha:  8974
# Accepted I1:  8974
# Accepted W4:  8974
# Accepted S4:  8974
# Accepted Tau:  8974
# Completed 8974
#
# Accepted W1:  8975
# Accepted W3:  8975
# Accepted S2:  8975
# Completed 8975
#
# Accepted W1:  8976
# Completed 8976
#
# Accepted W0:  8977
# Accepted S2:  8977
# Accepted Tau:  8977
# Completed 8977
#
# Accepted Alpha:  8978
# Accepted W0:  8978
# Accepted W1:  8978
# Accepted W2:  8978
# Accepted W3:  8978
# Accepted W4:  8978
# Accepted S2:  8978
# Completed 8978
#
# Accepted W2:  8979
# Accepted W4:  8979
# Accepted S2:  8979
# Accepted Tau:  8979
# Completed 8979
#
# Accepted Alpha:  8980
# Accepted W4:  8980
# Completed 8980
#
# Accepted I2:  8981
# Accepted W4:  8981
# Completed 8981
#
# Accepted I2:  8982
# Completed 8982
#
# Accepted S2:  8983
# Completed 8983
#
# Accepted Alpha:  8984
# Completed 8984
#
# Completed 8985
#
# Completed 8986
#
# Accepted S2:  8987
# Completed 8987
#
# Accepted I0:  8988
# Accepted S2:  8988
# Completed 8988
#
# Accepted I1:  8989
# Accepted Tau:  8989
# Completed 8989
#
# Accepted Tau:  8990
# Completed 8990
#
# Accepted W0:  8991
# Completed 8991
#
# Accepted W2:  8992
# Accepted S2:  8992
# Completed 8992
#
# Accepted S2:  8993
# Completed 8993
#
# Accepted W2:  8994
# Accepted W4:  8994
# Completed 8994
#
# Accepted I3:  8995
# Accepted I4:  8995
# Accepted W4:  8995
# Accepted Tau:  8995
# Completed 8995
#
# Accepted I3:  8996
# Accepted W0:  8996
# Accepted W3:  8996
# Accepted S2:  8996
# Completed 8996
#
# Accepted W0:  8997
# Accepted W4:  8997
# Accepted S2:  8997
# Completed 8997
#
# Accepted I0:  8998
# Accepted W3:  8998
# Accepted S2:  8998
# Completed 8998
#
# Accepted W1:  8999
# Accepted S2:  8999
# Completed 8999
#
# Accepted W0:  9000
# Accepted W2:  9000
# Accepted S2:  9000
# Completed 9000
#
# Accepted W0:  9001
# Accepted S2:  9001
# Completed 9001
#
# Accepted I0:  9002
# Accepted I1:  9002
# Accepted W2:  9002
# Completed 9002
#
# Accepted I2:  9003
# Accepted S2:  9003
# Accepted S4:  9003
# Completed 9003
#
# Accepted S4:  9004
# Accepted Tau:  9004
# Completed 9004
#
# Accepted W1:  9005
# Completed 9005
#
# Completed 9006
#
# Completed 9007
#
# Accepted W0:  9008
# Accepted W3:  9008
# Accepted W4:  9008
# Accepted S2:  9008
# Completed 9008
#
# Completed 9009
#
# Accepted I3:  9010
# Accepted W0:  9010
# Accepted S2:  9010
# Completed 9010
#
# Accepted I0:  9011
# Accepted I1:  9011
# Accepted I4:  9011
# Accepted T2:  9011
# Accepted S2:  9011
# Completed 9011
#
# Accepted W3:  9012
# Completed 9012
#
# Accepted W0:  9013
# Accepted W1:  9013
# Accepted W2:  9013
# Completed 9013
#
# Accepted I1:  9014
# Accepted W1:  9014
# Accepted S2:  9014
# Completed 9014
#
# Accepted W1:  9015
# Accepted S2:  9015
# Completed 9015
#
# Accepted I1:  9016
# Accepted I3:  9016
# Accepted Tau:  9016
# Completed 9016
#
# Accepted I4:  9017
# Completed 9017
#
# Accepted S2:  9018
# Completed 9018
#
# Accepted I3:  9019
# Accepted W4:  9019
# Completed 9019
#
# Accepted W2:  9020
# Accepted W3:  9020
# Accepted S2:  9020
# Completed 9020
#
# Accepted I0:  9021
# Accepted W0:  9021
# Accepted S2:  9021
# Completed 9021
#
# Accepted W2:  9022
# Accepted W3:  9022
# Accepted S2:  9022
# Completed 9022
#
# Accepted S2:  9023
# Accepted S4:  9023
# Completed 9023
#
# Accepted I2:  9024
# Accepted W0:  9024
# Accepted S2:  9024
# Completed 9024
#
# Accepted W2:  9025
# Accepted S2:  9025
# Completed 9025
#
# Accepted I3:  9026
# Accepted W3:  9026
# Accepted S2:  9026
# Accepted Tau:  9026
# Completed 9026
#
# Accepted I1:  9027
# Accepted W2:  9027
# Accepted S4:  9027
# Accepted Tau:  9027
# Completed 9027
#
# Completed 9028
#
# Accepted I0:  9029
# Accepted W0:  9029
# Accepted S2:  9029
# Completed 9029
#
# Completed 9030
#
# Accepted W0:  9031
# Accepted S2:  9031
# Completed 9031
#
# Completed 9032
#
# Accepted S2:  9033
# Completed 9033
#
# Accepted W3:  9034
# Accepted W4:  9034
# Completed 9034
#
# Accepted I4:  9035
# Accepted W0:  9035
# Accepted W1:  9035
# Accepted S2:  9035
# Accepted Tau:  9035
# Completed 9035
#
# Accepted I4:  9036
# Completed 9036
#
# Accepted I0:  9037
# Accepted S2:  9037
# Accepted Tau:  9037
# Completed 9037
#
# Completed 9038
#
# Accepted I4:  9039
# Accepted S2:  9039
# Completed 9039
#
# Accepted I1:  9040
# Accepted W4:  9040
# Accepted S2:  9040
# Completed 9040
#
# Accepted W0:  9041
# Accepted W1:  9041
# Accepted S2:  9041
# Completed 9041
#
# Accepted S2:  9042
# Completed 9042
#
# Accepted I3:  9043
# Accepted W4:  9043
# Completed 9043
#
# Accepted T1:  9044
# Accepted S2:  9044
# Accepted Tau:  9044
# Completed 9044
#
# Accepted W0:  9045
# Accepted W1:  9045
# Accepted S2:  9045
# Completed 9045
#
# Accepted I4:  9046
# Accepted W2:  9046
# Completed 9046
#
# Accepted W2:  9047
# Accepted S2:  9047
# Completed 9047
#
# Accepted Tau:  9048
# Completed 9048
#
# Accepted I3:  9049
# Accepted T2:  9049
# Accepted W0:  9049
# Accepted W2:  9049
# Accepted Tau:  9049
# Completed 9049
#
# Accepted S2:  9050
# Completed 9050
#
# Accepted W0:  9051
# Accepted W3:  9051
# Completed 9051
#
# Accepted I1:  9052
# Accepted W2:  9052
# Accepted S2:  9052
# Completed 9052
#
# Accepted I0:  9053
# Accepted S2:  9053
# Completed 9053
#
# Accepted I1:  9054
# Accepted W3:  9054
# Completed 9054
#
# Accepted Tau:  9055
# Completed 9055
#
# Accepted W2:  9056
# Completed 9056
#
# Accepted W0:  9057
# Accepted S2:  9057
# Accepted Tau:  9057
# Completed 9057
#
# Accepted W2:  9058
# Accepted W3:  9058
# Completed 9058
#
# Accepted Alpha:  9059
# Accepted I1:  9059
# Accepted W3:  9059
# Accepted W4:  9059
# Completed 9059
#
# Accepted W0:  9060
# Accepted W3:  9060
# Accepted S2:  9060
# Completed 9060
#
# Accepted S2:  9061
# Completed 9061
#
# Accepted W2:  9062
# Completed 9062
#
# Accepted S2:  9063
# Completed 9063
#
# Accepted I3:  9064
# Accepted W0:  9064
# Accepted W4:  9064
# Accepted S2:  9064
# Completed 9064
#
# Accepted I4:  9065
# Accepted W1:  9065
# Accepted W2:  9065
# Accepted W3:  9065
# Completed 9065
#
# Accepted W0:  9066
# Completed 9066
#
# Accepted I1:  9067
# Accepted I4:  9067
# Accepted W2:  9067
# Accepted S2:  9067
# Completed 9067
#
# Accepted I1:  9068
# Accepted W3:  9068
# Accepted W4:  9068
# Accepted S2:  9068
# Completed 9068
#
# Accepted W0:  9069
# Completed 9069
#
# Accepted W0:  9070
# Accepted W2:  9070
# Completed 9070
#
# Accepted I0:  9071
# Accepted T3:  9071
# Accepted W1:  9071
# Accepted S3:  9071
# Accepted Tau:  9071
# Completed 9071
#
# Accepted W0:  9072
# Accepted W3:  9072
# Completed 9072
#
# Accepted W2:  9073
# Accepted S2:  9073
# Completed 9073
#
# Accepted Alpha:  9074
# Accepted I0:  9074
# Accepted I1:  9074
# Accepted W4:  9074
# Accepted S2:  9074
# Accepted S4:  9074
# Accepted Tau:  9074
# Completed 9074
#
# Accepted W3:  9075
# Completed 9075
#
# Accepted W4:  9076
# Accepted S2:  9076
# Completed 9076
#
# Accepted W0:  9077
# Accepted S2:  9077
# Accepted Tau:  9077
# Completed 9077
#
# Accepted W0:  9078
# Accepted S4:  9078
# Completed 9078
#
# Accepted S2:  9079
# Completed 9079
#
# Accepted I2:  9080
# Completed 9080
#
# Accepted S2:  9081
# Completed 9081
#
# Accepted W0:  9082
# Completed 9082
#
# Accepted W4:  9083
# Completed 9083
#
# Accepted W2:  9084
# Accepted W3:  9084
# Completed 9084
#
# Completed 9085
#
# Accepted I3:  9086
# Accepted T1:  9086
# Accepted W2:  9086
# Completed 9086
#
# Accepted W3:  9087
# Accepted W4:  9087
# Completed 9087
#
# Accepted Tau:  9088
# Completed 9088
#
# Accepted W0:  9089
# Accepted W3:  9089
# Completed 9089
#
# Accepted I2:  9090
# Accepted I4:  9090
# Accepted W4:  9090
# Completed 9090
#
# Accepted Alpha:  9091
# Accepted W0:  9091
# Accepted S2:  9091
# Completed 9091
#
# Accepted I3:  9092
# Accepted W2:  9092
# Accepted W3:  9092
# Accepted S2:  9092
# Accepted Tau:  9092
# Completed 9092
#
# Completed 9093
#
# Completed 9094
#
# Accepted S2:  9095
# Completed 9095
#
# Accepted W1:  9096
# Accepted S2:  9096
# Accepted Tau:  9096
# Completed 9096
#
# Accepted W4:  9097
# Accepted S2:  9097
# Accepted S3:  9097
# Completed 9097
#
# Accepted I3:  9098
# Accepted W0:  9098
# Accepted W3:  9098
# Completed 9098
#
# Accepted I2:  9099
# Accepted W0:  9099
# Accepted S2:  9099
# Completed 9099
#
# Accepted W0:  9100
# Accepted W4:  9100
# Accepted S2:  9100
# Completed 9100
#
# Completed 9101
#
# Accepted I0:  9102
# Accepted W0:  9102
# Accepted W2:  9102
# Accepted W3:  9102
# Completed 9102
#
# Accepted S2:  9103
# Completed 9103
#
# Accepted Alpha:  9104
# Accepted W2:  9104
# Accepted W3:  9104
# Accepted W4:  9104
# Accepted S2:  9104
# Completed 9104
#
# Accepted I1:  9105
# Completed 9105
#
# Accepted T3:  9106
# Accepted W1:  9106
# Accepted S2:  9106
# Completed 9106
#
# Accepted I0:  9107
# Accepted W2:  9107
# Completed 9107
#
# Accepted Alpha:  9108
# Accepted I0:  9108
# Completed 9108
#
# Completed 9109
#
# Accepted W2:  9110
# Accepted S4:  9110
# Completed 9110
#
# Accepted I0:  9111
# Accepted W0:  9111
# Accepted Tau:  9111
# Completed 9111
#
# Accepted I4:  9112
# Accepted W2:  9112
# Accepted W4:  9112
# Accepted Tau:  9112
# Completed 9112
#
# Accepted I1:  9113
# Completed 9113
#
# Accepted W1:  9114
# Accepted S2:  9114
# Completed 9114
#
# Accepted I0:  9115
# Accepted W0:  9115
# Accepted S2:  9115
# Completed 9115
#
# Accepted I2:  9116
# Accepted I4:  9116
# Completed 9116
#
# Accepted W0:  9117
# Accepted W2:  9117
# Accepted S2:  9117
# Accepted S4:  9117
# Completed 9117
#
# Accepted I2:  9118
# Accepted W1:  9118
# Accepted W4:  9118
# Accepted S2:  9118
# Completed 9118
#
# Accepted W2:  9119
# Accepted W3:  9119
# Accepted S4:  9119
# Completed 9119
#
# Accepted W0:  9120
# Accepted W1:  9120
# Accepted S2:  9120
# Accepted S4:  9120
# Completed 9120
#
# Accepted W3:  9121
# Accepted W4:  9121
# Accepted S2:  9121
# Accepted Tau:  9121
# Completed 9121
#
# Accepted I3:  9122
# Accepted W0:  9122
# Accepted Tau:  9122
# Completed 9122
#
# Accepted I0:  9123
# Accepted I2:  9123
# Accepted W0:  9123
# Accepted W3:  9123
# Accepted W4:  9123
# Accepted Tau:  9123
# Completed 9123
#
# Accepted W2:  9124
# Completed 9124
#
# Accepted W1:  9125
# Accepted W3:  9125
# Completed 9125
#
# Accepted W0:  9126
# Accepted W3:  9126
# Completed 9126
#
# Accepted W0:  9127
# Accepted W2:  9127
# Accepted S2:  9127
# Accepted S4:  9127
# Completed 9127
#
# Accepted Alpha:  9128
# Accepted I4:  9128
# Completed 9128
#
# Accepted I3:  9129
# Accepted W1:  9129
# Accepted W2:  9129
# Completed 9129
#
# Completed 9130
#
# Accepted I0:  9131
# Accepted W3:  9131
# Accepted W4:  9131
# Accepted S2:  9131
# Completed 9131
#
# Completed 9132
#
# Accepted W0:  9133
# Accepted W4:  9133
# Completed 9133
#
# Accepted S2:  9134
# Completed 9134
#
# Accepted S2:  9135
# Completed 9135
#
# Accepted S2:  9136
# Accepted Tau:  9136
# Completed 9136
#
# Accepted W1:  9137
# Accepted W4:  9137
# Accepted S2:  9137
# Accepted Tau:  9137
# Completed 9137
#
# Accepted I0:  9138
# Accepted I1:  9138
# Accepted S2:  9138
# Completed 9138
#
# Accepted W3:  9139
# Accepted S2:  9139
# Accepted S4:  9139
# Completed 9139
#
# Accepted I4:  9140
# Accepted W2:  9140
# Accepted W3:  9140
# Completed 9140
#
# Accepted I1:  9141
# Accepted W0:  9141
# Completed 9141
#
# Accepted W1:  9142
# Accepted S2:  9142
# Completed 9142
#
# Accepted I0:  9143
# Accepted W0:  9143
# Completed 9143
#
# Accepted I1:  9144
# Accepted W0:  9144
# Accepted W3:  9144
# Completed 9144
#
# Accepted W2:  9145
# Accepted S2:  9145
# Completed 9145
#
# Accepted Alpha:  9146
# Accepted I3:  9146
# Accepted W4:  9146
# Accepted S2:  9146
# Completed 9146
#
# Accepted W0:  9147
# Accepted W1:  9147
# Accepted W2:  9147
# Accepted S2:  9147
# Completed 9147
#
# Accepted W0:  9148
# Accepted S2:  9148
# Completed 9148
#
# Accepted W3:  9149
# Completed 9149
#
# Accepted I3:  9150
# Accepted W0:  9150
# Accepted W2:  9150
# Completed 9150
#
# Accepted I2:  9151
# Accepted T2:  9151
# Accepted W2:  9151
# Accepted S2:  9151
# Completed 9151
#
# Accepted I0:  9152
# Accepted W1:  9152
# Accepted W2:  9152
# Accepted W3:  9152
# Accepted W4:  9152
# Completed 9152
#
# Accepted I1:  9153
# Accepted W4:  9153
# Accepted S2:  9153
# Completed 9153
#
# Accepted I3:  9154
# Accepted S2:  9154
# Completed 9154
#
# Accepted W1:  9155
# Accepted S2:  9155
# Completed 9155
#
# Completed 9156
#
# Accepted W0:  9157
# Accepted S2:  9157
# Completed 9157
#
# Accepted I1:  9158
# Accepted I2:  9158
# Accepted I3:  9158
# Accepted W3:  9158
# Accepted W4:  9158
# Completed 9158
#
# Accepted I1:  9159
# Accepted I2:  9159
# Accepted I4:  9159
# Accepted S2:  9159
# Accepted Tau:  9159
# Completed 9159
#
# Completed 9160
#
# Accepted W0:  9161
# Accepted W1:  9161
# Accepted W2:  9161
# Accepted S2:  9161
# Accepted S4:  9161
# Completed 9161
#
# Accepted I4:  9162
# Completed 9162
#
# Accepted W3:  9163
# Completed 9163
#
# Accepted I1:  9164
# Accepted S2:  9164
# Completed 9164
#
# Accepted W3:  9165
# Accepted S4:  9165
# Completed 9165
#
# Accepted I3:  9166
# Accepted W0:  9166
# Accepted W4:  9166
# Accepted S2:  9166
# Completed 9166
#
# Accepted T1:  9167
# Accepted S2:  9167
# Completed 9167
#
# Accepted I4:  9168
# Completed 9168
#
# Accepted I4:  9169
# Accepted W4:  9169
# Completed 9169
#
# Accepted I4:  9170
# Accepted S4:  9170
# Completed 9170
#
# Accepted S2:  9171
# Completed 9171
#
# Accepted I1:  9172
# Accepted I4:  9172
# Accepted T0:  9172
# Accepted S2:  9172
# Completed 9172
#
# Accepted W2:  9173
# Completed 9173
#
# Accepted S2:  9174
# Completed 9174
#
# Accepted I3:  9175
# Completed 9175
#
# Accepted W2:  9176
# Accepted W4:  9176
# Accepted S4:  9176
# Accepted Tau:  9176
# Completed 9176
#
# Accepted W3:  9177
# Completed 9177
#
# Accepted W4:  9178
# Completed 9178
#
# Accepted W0:  9179
# Accepted W1:  9179
# Accepted W2:  9179
# Completed 9179
#
# Accepted I4:  9180
# Accepted S2:  9180
# Completed 9180
#
# Accepted W4:  9181
# Accepted S2:  9181
# Completed 9181
#
# Accepted I2:  9182
# Completed 9182
#
# Accepted I1:  9183
# Accepted I2:  9183
# Accepted I3:  9183
# Accepted Tau:  9183
# Completed 9183
#
# Accepted I2:  9184
# Accepted W0:  9184
# Completed 9184
#
# Accepted I2:  9185
# Accepted W2:  9185
# Accepted S2:  9185
# Completed 9185
#
# Accepted W1:  9186
# Accepted W2:  9186
# Accepted W4:  9186
# Accepted S2:  9186
# Completed 9186
#
# Accepted I0:  9187
# Accepted W2:  9187
# Accepted S2:  9187
# Completed 9187
#
# Accepted W2:  9188
# Completed 9188
#
# Accepted Alpha:  9189
# Accepted I2:  9189
# Accepted W4:  9189
# Completed 9189
#
# Accepted I0:  9190
# Accepted W1:  9190
# Accepted S2:  9190
# Completed 9190
#
# Accepted I2:  9191
# Accepted I4:  9191
# Accepted W0:  9191
# Accepted W3:  9191
# Accepted W4:  9191
# Accepted S2:  9191
# Completed 9191
#
# Accepted W4:  9192
# Accepted S4:  9192
# Completed 9192
#
# Accepted W0:  9193
# Accepted S2:  9193
# Completed 9193
#
# Accepted W0:  9194
# Accepted S1:  9194
# Accepted S4:  9194
# Accepted Tau:  9194
# Completed 9194
#
# Accepted W0:  9195
# Accepted W1:  9195
# Accepted S2:  9195
# Accepted Tau:  9195
# Completed 9195
#
# Accepted I0:  9196
# Accepted W2:  9196
# Accepted Tau:  9196
# Completed 9196
#
# Accepted W0:  9197
# Accepted W2:  9197
# Accepted S2:  9197
# Completed 9197
#
# Accepted I2:  9198
# Completed 9198
#
# Accepted I2:  9199
# Accepted I4:  9199
# Accepted Tau:  9199
# Completed 9199
#
# Accepted I0:  9200
# Accepted T4:  9200
# Accepted W1:  9200
# Accepted W2:  9200
# Accepted Tau:  9200
# Completed 9200
#
# Accepted I0:  9201
# Accepted W1:  9201
# Accepted W2:  9201
# Completed 9201
#
# Accepted I3:  9202
# Accepted W0:  9202
# Accepted W1:  9202
# Accepted S2:  9202
# Completed 9202
#
# Accepted T3:  9203
# Accepted W0:  9203
# Completed 9203
#
# Accepted W2:  9204
# Accepted S2:  9204
# Completed 9204
#
# Accepted I0:  9205
# Accepted W3:  9205
# Accepted W4:  9205
# Completed 9205
#
# Accepted W4:  9206
# Accepted Tau:  9206
# Completed 9206
#
# Accepted I1:  9207
# Accepted W4:  9207
# Completed 9207
#
# Accepted W4:  9208
# Accepted S2:  9208
# Completed 9208
#
# Accepted I2:  9209
# Accepted I3:  9209
# Accepted I4:  9209
# Accepted W0:  9209
# Accepted S2:  9209
# Completed 9209
#
# Accepted W2:  9210
# Completed 9210
#
# Accepted W3:  9211
# Accepted S2:  9211
# Accepted Tau:  9211
# Completed 9211
#
# Accepted W0:  9212
# Accepted W1:  9212
# Accepted W2:  9212
# Accepted S2:  9212
# Completed 9212
#
# Accepted S2:  9213
# Accepted Tau:  9213
# Completed 9213
#
# Accepted I2:  9214
# Accepted I4:  9214
# Accepted W0:  9214
# Accepted Tau:  9214
# Completed 9214
#
# Accepted W3:  9215
# Accepted Tau:  9215
# Completed 9215
#
# Accepted I3:  9216
# Accepted S2:  9216
# Accepted S4:  9216
# Completed 9216
#
# Accepted W1:  9217
# Accepted W2:  9217
# Accepted S2:  9217
# Completed 9217
#
# Accepted W1:  9218
# Accepted Tau:  9218
# Completed 9218
#
# Accepted W3:  9219
# Accepted W4:  9219
# Accepted S2:  9219
# Completed 9219
#
# Accepted I0:  9220
# Accepted W2:  9220
# Accepted S2:  9220
# Completed 9220
#
# Accepted I2:  9221
# Accepted Tau:  9221
# Completed 9221
#
# Accepted I0:  9222
# Accepted I1:  9222
# Accepted S2:  9222
# Completed 9222
#
# Accepted I0:  9223
# Accepted W2:  9223
# Accepted W4:  9223
# Completed 9223
#
# Accepted I1:  9224
# Accepted S4:  9224
# Completed 9224
#
# Accepted Alpha:  9225
# Accepted I2:  9225
# Accepted I4:  9225
# Accepted W3:  9225
# Accepted S2:  9225
# Accepted S4:  9225
# Completed 9225
#
# Accepted W1:  9226
# Accepted W2:  9226
# Accepted S2:  9226
# Completed 9226
#
# Accepted I1:  9227
# Accepted I4:  9227
# Accepted S2:  9227
# Completed 9227
#
# Accepted W3:  9228
# Accepted S2:  9228
# Completed 9228
#
# Accepted W0:  9229
# Accepted W4:  9229
# Completed 9229
#
# Accepted W0:  9230
# Accepted W4:  9230
# Accepted S2:  9230
# Completed 9230
#
# Accepted Alpha:  9231
# Accepted W0:  9231
# Accepted W4:  9231
# Accepted S2:  9231
# Completed 9231
#
# Accepted I3:  9232
# Accepted I4:  9232
# Completed 9232
#
# Accepted I0:  9233
# Accepted I4:  9233
# Accepted W0:  9233
# Completed 9233
#
# Accepted I0:  9234
# Accepted W0:  9234
# Completed 9234
#
# Accepted S2:  9235
# Completed 9235
#
# Accepted S2:  9236
# Completed 9236
#
# Accepted I3:  9237
# Completed 9237
#
# Accepted Tau:  9238
# Completed 9238
#
# Accepted I1:  9239
# Accepted I3:  9239
# Accepted W0:  9239
# Accepted S2:  9239
# Completed 9239
#
# Accepted W0:  9240
# Accepted W2:  9240
# Completed 9240
#
# Accepted I2:  9241
# Accepted W0:  9241
# Accepted W3:  9241
# Accepted S2:  9241
# Accepted S4:  9241
# Completed 9241
#
# Accepted I4:  9242
# Accepted S2:  9242
# Accepted S4:  9242
# Accepted Tau:  9242
# Completed 9242
#
# Accepted Alpha:  9243
# Completed 9243
#
# Accepted I2:  9244
# Accepted I3:  9244
# Accepted Tau:  9244
# Completed 9244
#
# Accepted Alpha:  9245
# Completed 9245
#
# Accepted I3:  9246
# Accepted W4:  9246
# Accepted S2:  9246
# Completed 9246
#
# Accepted I2:  9247
# Accepted I3:  9247
# Accepted W1:  9247
# Completed 9247
#
# Accepted Alpha:  9248
# Accepted W4:  9248
# Accepted S2:  9248
# Completed 9248
#
# Accepted I4:  9249
# Accepted W4:  9249
# Accepted S2:  9249
# Completed 9249
#
# Accepted I0:  9250
# Accepted I2:  9250
# Accepted W2:  9250
# Accepted S2:  9250
# Completed 9250
#
# Accepted W4:  9251
# Accepted S2:  9251
# Completed 9251
#
# Accepted W2:  9252
# Completed 9252
#
# Accepted S2:  9253
# Completed 9253
#
# Accepted W0:  9254
# Accepted S2:  9254
# Completed 9254
#
# Accepted W1:  9255
# Accepted W3:  9255
# Completed 9255
#
# Accepted I4:  9256
# Completed 9256
#
# Accepted I0:  9257
# Accepted T2:  9257
# Accepted S2:  9257
# Completed 9257
#
# Accepted S2:  9258
# Completed 9258
#
# Accepted Alpha:  9259
# Accepted I0:  9259
# Accepted W1:  9259
# Accepted W2:  9259
# Accepted W3:  9259
# Accepted W4:  9259
# Accepted Tau:  9259
# Completed 9259
#
# Accepted I4:  9260
# Accepted S2:  9260
# Completed 9260
#
# Accepted W1:  9261
# Completed 9261
#
# Accepted I1:  9262
# Accepted W0:  9262
# Accepted Tau:  9262
# Completed 9262
#
# Accepted W2:  9263
# Accepted W3:  9263
# Completed 9263
#
# Accepted I3:  9264
# Accepted I4:  9264
# Completed 9264
#
# Accepted I0:  9265
# Accepted W1:  9265
# Completed 9265
#
# Accepted W3:  9266
# Accepted W4:  9266
# Accepted S2:  9266
# Completed 9266
#
# Completed 9267
#
# Accepted W0:  9268
# Accepted S2:  9268
# Completed 9268
#
# Accepted W1:  9269
# Completed 9269
#
# Accepted W0:  9270
# Accepted S2:  9270
# Accepted Tau:  9270
# Completed 9270
#
# Accepted W3:  9271
# Completed 9271
#
# Accepted I3:  9272
# Accepted W0:  9272
# Accepted W4:  9272
# Accepted S2:  9272
# Completed 9272
#
# Accepted I4:  9273
# Accepted W1:  9273
# Accepted S2:  9273
# Completed 9273
#
# Accepted Alpha:  9274
# Accepted T4:  9274
# Accepted W2:  9274
# Accepted S2:  9274
# Completed 9274
#
# Accepted I3:  9275
# Accepted W0:  9275
# Accepted W1:  9275
# Accepted W3:  9275
# Accepted S2:  9275
# Accepted S3:  9275
# Completed 9275
#
# Accepted W1:  9276
# Accepted S2:  9276
# Completed 9276
#
# Accepted W0:  9277
# Accepted W1:  9277
# Accepted W4:  9277
# Accepted S2:  9277
# Completed 9277
#
# Accepted I2:  9278
# Accepted W0:  9278
# Completed 9278
#
# Accepted I2:  9279
# Accepted W2:  9279
# Accepted W3:  9279
# Completed 9279
#
# Accepted T2:  9280
# Accepted W0:  9280
# Accepted S2:  9280
# Completed 9280
#
# Accepted W2:  9281
# Completed 9281
#
# Accepted Alpha:  9282
# Accepted W0:  9282
# Accepted S2:  9282
# Completed 9282
#
# Accepted I2:  9283
# Accepted S2:  9283
# Completed 9283
#
# Accepted I4:  9284
# Accepted W2:  9284
# Completed 9284
#
# Accepted Alpha:  9285
# Accepted I3:  9285
# Accepted W0:  9285
# Accepted W2:  9285
# Accepted S2:  9285
# Completed 9285
#
# Accepted W1:  9286
# Accepted S2:  9286
# Completed 9286
#
# Completed 9287
#
# Accepted S2:  9288
# Completed 9288
#
# Accepted W0:  9289
# Accepted W4:  9289
# Completed 9289
#
# Accepted T0:  9290
# Accepted W2:  9290
# Completed 9290
#
# Accepted Tau:  9291
# Completed 9291
#
# Accepted W0:  9292
# Accepted W3:  9292
# Accepted S2:  9292
# Accepted S3:  9292
# Accepted Tau:  9292
# Completed 9292
#
# Accepted I1:  9293
# Accepted I2:  9293
# Accepted W2:  9293
# Accepted Tau:  9293
# Completed 9293
#
# Accepted Alpha:  9294
# Accepted W3:  9294
# Accepted W4:  9294
# Accepted S4:  9294
# Completed 9294
#
# Accepted W0:  9295
# Accepted W1:  9295
# Completed 9295
#
# Accepted W2:  9296
# Accepted S2:  9296
# Completed 9296
#
# Accepted I1:  9297
# Accepted T1:  9297
# Accepted W3:  9297
# Accepted S2:  9297
# Accepted Tau:  9297
# Completed 9297
#
# Accepted I2:  9298
# Accepted W3:  9298
# Completed 9298
#
# Completed 9299
#
# Accepted I0:  9300
# Accepted S2:  9300
# Accepted S4:  9300
# Accepted Tau:  9300
# Completed 9300
#
# Accepted I2:  9301
# Accepted W2:  9301
# Completed 9301
#
# Accepted I1:  9302
# Accepted W2:  9302
# Accepted S2:  9302
# Completed 9302
#
# Accepted I2:  9303
# Accepted I3:  9303
# Accepted W0:  9303
# Accepted W1:  9303
# Accepted W4:  9303
# Completed 9303
#
# Accepted W2:  9304
# Accepted Tau:  9304
# Completed 9304
#
# Accepted I0:  9305
# Accepted W0:  9305
# Completed 9305
#
# Accepted W0:  9306
# Accepted W2:  9306
# Accepted S2:  9306
# Completed 9306
#
# Accepted T0:  9307
# Accepted W0:  9307
# Accepted S2:  9307
# Completed 9307
#
# Completed 9308
#
# Completed 9309
#
# Accepted W3:  9310
# Accepted S2:  9310
# Completed 9310
#
# Accepted W0:  9311
# Accepted W4:  9311
# Completed 9311
#
# Accepted Alpha:  9312
# Accepted W2:  9312
# Accepted S2:  9312
# Completed 9312
#
# Accepted I4:  9313
# Accepted W4:  9313
# Completed 9313
#
# Accepted W1:  9314
# Completed 9314
#
# Accepted I1:  9315
# Accepted W0:  9315
# Accepted W2:  9315
# Completed 9315
#
# Accepted I1:  9316
# Accepted W3:  9316
# Accepted W4:  9316
# Accepted S2:  9316
# Completed 9316
#
# Accepted I1:  9317
# Accepted W2:  9317
# Accepted S2:  9317
# Accepted S4:  9317
# Completed 9317
#
# Accepted I2:  9318
# Accepted W0:  9318
# Accepted W2:  9318
# Accepted W4:  9318
# Accepted S2:  9318
# Accepted S4:  9318
# Completed 9318
#
# Accepted T0:  9319
# Accepted W0:  9319
# Completed 9319
#
# Accepted I2:  9320
# Accepted W0:  9320
# Completed 9320
#
# Accepted S2:  9321
# Completed 9321
#
# Accepted Alpha:  9322
# Accepted I3:  9322
# Accepted W0:  9322
# Accepted W2:  9322
# Accepted W4:  9322
# Accepted S2:  9322
# Accepted S4:  9322
# Completed 9322
#
# Accepted W4:  9323
# Completed 9323
#
# Accepted I2:  9324
# Accepted S4:  9324
# Completed 9324
#
# Accepted I3:  9325
# Accepted W3:  9325
# Accepted S2:  9325
# Accepted Tau:  9325
# Completed 9325
#
# Accepted S2:  9326
# Completed 9326
#
# Accepted Alpha:  9327
# Accepted I3:  9327
# Accepted W1:  9327
# Accepted S4:  9327
# Completed 9327
#
# Accepted I3:  9328
# Accepted W1:  9328
# Accepted S2:  9328
# Accepted Tau:  9328
# Completed 9328
#
# Accepted W0:  9329
# Accepted W3:  9329
# Completed 9329
#
# Accepted I0:  9330
# Accepted I4:  9330
# Completed 9330
#
# Accepted W1:  9331
# Accepted W3:  9331
# Completed 9331
#
# Accepted I1:  9332
# Accepted I3:  9332
# Accepted T0:  9332
# Accepted W1:  9332
# Accepted S2:  9332
# Accepted Tau:  9332
# Completed 9332
#
# Accepted I0:  9333
# Completed 9333
#
# Accepted W3:  9334
# Accepted W4:  9334
# Accepted S2:  9334
# Completed 9334
#
# Accepted I3:  9335
# Accepted I4:  9335
# Accepted W0:  9335
# Accepted W1:  9335
# Completed 9335
#
# Accepted I1:  9336
# Accepted W1:  9336
# Accepted W4:  9336
# Accepted S2:  9336
# Accepted Tau:  9336
# Completed 9336
#
# Accepted S2:  9337
# Completed 9337
#
# Accepted I2:  9338
# Accepted S2:  9338
# Completed 9338
#
# Accepted I4:  9339
# Accepted W0:  9339
# Accepted W1:  9339
# Accepted S2:  9339
# Completed 9339
#
# Accepted W3:  9340
# Completed 9340
#
# Accepted Alpha:  9341
# Accepted W4:  9341
# Accepted S2:  9341
# Accepted Tau:  9341
# Completed 9341
#
# Accepted W0:  9342
# Accepted W2:  9342
# Accepted W3:  9342
# Completed 9342
#
# Completed 9343
#
# Accepted S2:  9344
# Completed 9344
#
# Accepted Alpha:  9345
# Completed 9345
#
# Accepted W3:  9346
# Completed 9346
#
# Accepted I2:  9347
# Accepted I3:  9347
# Accepted W1:  9347
# Accepted W2:  9347
# Accepted W3:  9347
# Completed 9347
#
# Accepted I0:  9348
# Completed 9348
#
# Accepted I1:  9349
# Accepted I2:  9349
# Accepted T1:  9349
# Accepted W2:  9349
# Accepted W4:  9349
# Accepted S2:  9349
# Completed 9349
#
# Accepted I1:  9350
# Accepted W0:  9350
# Accepted S2:  9350
# Completed 9350
#
# Accepted S4:  9351
# Completed 9351
#
# Accepted W4:  9352
# Accepted S2:  9352
# Accepted Tau:  9352
# Completed 9352
#
# Accepted W4:  9353
# Accepted S0:  9353
# Completed 9353
#
# Accepted W0:  9354
# Accepted W4:  9354
# Completed 9354
#
# Accepted I0:  9355
# Accepted W2:  9355
# Completed 9355
#
# Accepted W0:  9356
# Accepted S4:  9356
# Completed 9356
#
# Accepted W2:  9357
# Accepted S2:  9357
# Completed 9357
#
# Accepted I0:  9358
# Accepted I3:  9358
# Accepted W4:  9358
# Accepted S2:  9358
# Completed 9358
#
# Accepted I2:  9359
# Completed 9359
#
# Accepted W0:  9360
# Accepted S2:  9360
# Completed 9360
#
# Accepted S2:  9361
# Completed 9361
#
# Accepted Alpha:  9362
# Accepted W0:  9362
# Accepted W1:  9362
# Accepted W4:  9362
# Completed 9362
#
# Accepted S2:  9363
# Accepted Tau:  9363
# Completed 9363
#
# Accepted I0:  9364
# Accepted W2:  9364
# Completed 9364
#
# Accepted W1:  9365
# Accepted S2:  9365
# Completed 9365
#
# Accepted W0:  9366
# Accepted W1:  9366
# Accepted W2:  9366
# Completed 9366
#
# Completed 9367
#
# Accepted T0:  9368
# Accepted T2:  9368
# Accepted W0:  9368
# Accepted S2:  9368
# Completed 9368
#
# Accepted W2:  9369
# Completed 9369
#
# Accepted I1:  9370
# Accepted W0:  9370
# Accepted W2:  9370
# Completed 9370
#
# Accepted I3:  9371
# Accepted W0:  9371
# Accepted Tau:  9371
# Completed 9371
#
# Accepted S2:  9372
# Completed 9372
#
# Accepted I1:  9373
# Accepted W3:  9373
# Completed 9373
#
# Accepted Alpha:  9374
# Accepted Beta:  9374
# Accepted T0:  9374
# Accepted W0:  9374
# Accepted S2:  9374
# Completed 9374
#
# Accepted S2:  9375
# Completed 9375
#
# Accepted Alpha:  9376
# Accepted I3:  9376
# Completed 9376
#
# Completed 9377
#
# Accepted W0:  9378
# Accepted W4:  9378
# Accepted S2:  9378
# Completed 9378
#
# Accepted W2:  9379
# Accepted S2:  9379
# Accepted Tau:  9379
# Completed 9379
#
# Accepted I4:  9380
# Accepted W1:  9380
# Completed 9380
#
# Accepted S4:  9381
# Completed 9381
#
# Accepted T1:  9382
# Accepted W0:  9382
# Accepted S4:  9382
# Completed 9382
#
# Accepted W2:  9383
# Accepted W3:  9383
# Completed 9383
#
# Accepted W1:  9384
# Accepted W2:  9384
# Accepted W3:  9384
# Completed 9384
#
# Accepted T0:  9385
# Accepted W1:  9385
# Accepted W2:  9385
# Completed 9385
#
# Accepted S4:  9386
# Completed 9386
#
# Accepted I4:  9387
# Completed 9387
#
# Accepted W3:  9388
# Accepted W4:  9388
# Accepted S2:  9388
# Completed 9388
#
# Accepted I2:  9389
# Accepted W3:  9389
# Accepted W4:  9389
# Accepted S4:  9389
# Completed 9389
#
# Accepted I3:  9390
# Accepted I4:  9390
# Accepted W0:  9390
# Accepted S2:  9390
# Completed 9390
#
# Accepted I2:  9391
# Accepted Tau:  9391
# Completed 9391
#
# Accepted S2:  9392
# Accepted S4:  9392
# Completed 9392
#
# Accepted W1:  9393
# Accepted W2:  9393
# Completed 9393
#
# Accepted I1:  9394
# Accepted S2:  9394
# Completed 9394
#
# Accepted I4:  9395
# Accepted W1:  9395
# Accepted W2:  9395
# Accepted W3:  9395
# Accepted W4:  9395
# Accepted S2:  9395
# Accepted Tau:  9395
# Completed 9395
#
# Accepted I2:  9396
# Accepted I4:  9396
# Completed 9396
#
# Accepted W2:  9397
# Accepted W3:  9397
# Completed 9397
#
# Accepted S4:  9398
# Completed 9398
#
# Accepted I3:  9399
# Completed 9399
#
# Accepted Alpha:  9400
# Accepted W3:  9400
# Completed 9400
#
# Accepted W1:  9401
# Accepted Tau:  9401
# Completed 9401
#
# Accepted W1:  9402
# Completed 9402
#
# Accepted I1:  9403
# Completed 9403
#
# Accepted I2:  9404
# Accepted I4:  9404
# Accepted W0:  9404
# Accepted W4:  9404
# Accepted S2:  9404
# Accepted Tau:  9404
# Completed 9404
#
# Accepted Alpha:  9405
# Accepted I0:  9405
# Accepted I3:  9405
# Accepted T2:  9405
# Accepted S2:  9405
# Completed 9405
#
# Accepted Alpha:  9406
# Completed 9406
#
# Accepted I2:  9407
# Completed 9407
#
# Accepted I1:  9408
# Accepted W1:  9408
# Accepted S4:  9408
# Completed 9408
#
# Accepted W0:  9409
# Accepted W2:  9409
# Accepted S2:  9409
# Accepted Tau:  9409
# Completed 9409
#
# Completed 9410
#
# Accepted W1:  9411
# Completed 9411
#
# Accepted I1:  9412
# Accepted W0:  9412
# Accepted W1:  9412
# Accepted S2:  9412
# Completed 9412
#
# Accepted W3:  9413
# Accepted S2:  9413
# Completed 9413
#
# Accepted I3:  9414
# Accepted T4:  9414
# Accepted W2:  9414
# Accepted S3:  9414
# Completed 9414
#
# Accepted I0:  9415
# Accepted I2:  9415
# Accepted W3:  9415
# Accepted W4:  9415
# Completed 9415
#
# Accepted S2:  9416
# Completed 9416
#
# Accepted W2:  9417
# Accepted W3:  9417
# Accepted S2:  9417
# Completed 9417
#
# Accepted I0:  9418
# Accepted W2:  9418
# Accepted W3:  9418
# Accepted W4:  9418
# Completed 9418
#
# Accepted I2:  9419
# Accepted W4:  9419
# Accepted S2:  9419
# Completed 9419
#
# Accepted I2:  9420
# Accepted W1:  9420
# Completed 9420
#
# Accepted I3:  9421
# Completed 9421
#
# Accepted S2:  9422
# Completed 9422
#
# Accepted I1:  9423
# Accepted W3:  9423
# Accepted S2:  9423
# Completed 9423
#
# Accepted W0:  9424
# Accepted S2:  9424
# Completed 9424
#
# Accepted S2:  9425
# Completed 9425
#
# Accepted I3:  9426
# Accepted W1:  9426
# Accepted W2:  9426
# Completed 9426
#
# Accepted Alpha:  9427
# Accepted I3:  9427
# Accepted W0:  9427
# Accepted S2:  9427
# Accepted Tau:  9427
# Completed 9427
#
# Accepted I4:  9428
# Accepted W0:  9428
# Accepted W1:  9428
# Accepted W2:  9428
# Accepted W3:  9428
# Accepted S2:  9428
# Completed 9428
#
# Accepted I4:  9429
# Accepted W0:  9429
# Accepted Tau:  9429
# Completed 9429
#
# Accepted W0:  9430
# Completed 9430
#
# Accepted I1:  9431
# Accepted W1:  9431
# Accepted W3:  9431
# Accepted S2:  9431
# Completed 9431
#
# Accepted I3:  9432
# Accepted W0:  9432
# Accepted W1:  9432
# Completed 9432
#
# Accepted I0:  9433
# Accepted I1:  9433
# Accepted I4:  9433
# Completed 9433
#
# Accepted I1:  9434
# Accepted W0:  9434
# Accepted W2:  9434
# Accepted S4:  9434
# Accepted Tau:  9434
# Completed 9434
#
# Accepted W1:  9435
# Accepted S2:  9435
# Completed 9435
#
# Completed 9436
#
# Accepted W3:  9437
# Completed 9437
#
# Accepted W1:  9438
# Accepted S0:  9438
# Completed 9438
#
# Accepted Alpha:  9439
# Accepted I3:  9439
# Accepted W0:  9439
# Accepted S2:  9439
# Completed 9439
#
# Accepted T2:  9440
# Accepted W0:  9440
# Accepted S2:  9440
# Completed 9440
#
# Accepted I1:  9441
# Accepted I3:  9441
# Accepted I4:  9441
# Accepted W1:  9441
# Accepted S2:  9441
# Accepted S4:  9441
# Completed 9441
#
# Accepted S2:  9442
# Accepted Tau:  9442
# Completed 9442
#
# Accepted W0:  9443
# Accepted S2:  9443
# Completed 9443
#
# Accepted W1:  9444
# Accepted W2:  9444
# Accepted W3:  9444
# Completed 9444
#
# Accepted W0:  9445
# Accepted W3:  9445
# Accepted S2:  9445
# Completed 9445
#
# Accepted I4:  9446
# Accepted T2:  9446
# Accepted W3:  9446
# Accepted S0:  9446
# Completed 9446
#
# Accepted W3:  9447
# Accepted S2:  9447
# Completed 9447
#
# Accepted S0:  9448
# Accepted S2:  9448
# Completed 9448
#
# Accepted W4:  9449
# Accepted S2:  9449
# Completed 9449
#
# Accepted W3:  9450
# Accepted Tau:  9450
# Completed 9450
#
# Accepted I2:  9451
# Accepted W2:  9451
# Accepted W3:  9451
# Accepted W4:  9451
# Accepted S2:  9451
# Completed 9451
#
# Accepted W2:  9452
# Accepted S2:  9452
# Completed 9452
#
# Accepted W2:  9453
# Accepted W3:  9453
# Accepted S2:  9453
# Completed 9453
#
# Accepted I4:  9454
# Accepted S4:  9454
# Completed 9454
#
# Accepted W0:  9455
# Accepted W2:  9455
# Accepted W3:  9455
# Accepted S2:  9455
# Completed 9455
#
# Accepted Alpha:  9456
# Completed 9456
#
# Accepted I0:  9457
# Accepted T4:  9457
# Accepted W3:  9457
# Accepted S2:  9457
# Completed 9457
#
# Completed 9458
#
# Completed 9459
#
# Accepted Alpha:  9460
# Accepted W1:  9460
# Completed 9460
#
# Accepted W2:  9461
# Accepted W3:  9461
# Completed 9461
#
# Completed 9462
#
# Accepted I2:  9463
# Accepted W1:  9463
# Completed 9463
#
# Accepted W0:  9464
# Accepted W3:  9464
# Accepted S4:  9464
# Completed 9464
#
# Accepted I0:  9465
# Accepted I1:  9465
# Accepted W2:  9465
# Accepted W3:  9465
# Accepted S2:  9465
# Completed 9465
#
# Accepted W3:  9466
# Accepted S2:  9466
# Accepted Tau:  9466
# Completed 9466
#
# Accepted I1:  9467
# Accepted W1:  9467
# Accepted Tau:  9467
# Completed 9467
#
# Accepted Tau:  9468
# Completed 9468
#
# Accepted W1:  9469
# Completed 9469
#
# Accepted Alpha:  9470
# Accepted W4:  9470
# Completed 9470
#
# Accepted W3:  9471
# Completed 9471
#
# Accepted Alpha:  9472
# Accepted I1:  9472
# Accepted I3:  9472
# Accepted W3:  9472
# Completed 9472
#
# Accepted I4:  9473
# Accepted W3:  9473
# Completed 9473
#
# Accepted I2:  9474
# Accepted I3:  9474
# Accepted W0:  9474
# Accepted W4:  9474
# Accepted S4:  9474
# Completed 9474
#
# Accepted S2:  9475
# Completed 9475
#
# Accepted Alpha:  9476
# Accepted T4:  9476
# Accepted W1:  9476
# Accepted S2:  9476
# Completed 9476
#
# Accepted W2:  9477
# Accepted W4:  9477
# Accepted S2:  9477
# Completed 9477
#
# Accepted T4:  9478
# Accepted W2:  9478
# Accepted S4:  9478
# Completed 9478
#
# Accepted S2:  9479
# Completed 9479
#
# Accepted I0:  9480
# Accepted I1:  9480
# Accepted T0:  9480
# Accepted W3:  9480
# Accepted W4:  9480
# Accepted S2:  9480
# Accepted Tau:  9480
# Completed 9480
#
# Accepted I1:  9481
# Accepted I4:  9481
# Accepted W0:  9481
# Accepted W2:  9481
# Accepted W4:  9481
# Completed 9481
#
# Accepted I0:  9482
# Accepted S2:  9482
# Completed 9482
#
# Accepted S0:  9483
# Completed 9483
#
# Accepted W0:  9484
# Accepted W3:  9484
# Accepted W4:  9484
# Completed 9484
#
# Accepted I4:  9485
# Accepted W0:  9485
# Accepted W2:  9485
# Accepted W3:  9485
# Accepted W4:  9485
# Accepted S2:  9485
# Completed 9485
#
# Accepted I0:  9486
# Accepted I4:  9486
# Accepted W1:  9486
# Accepted W2:  9486
# Completed 9486
#
# Accepted Tau:  9487
# Completed 9487
#
# Accepted W3:  9488
# Accepted W4:  9488
# Accepted S2:  9488
# Accepted S4:  9488
# Completed 9488
#
# Accepted I2:  9489
# Accepted W0:  9489
# Accepted S2:  9489
# Completed 9489
#
# Accepted I3:  9490
# Accepted W1:  9490
# Accepted W2:  9490
# Completed 9490
#
# Accepted W3:  9491
# Accepted S2:  9491
# Completed 9491
#
# Accepted T2:  9492
# Accepted W0:  9492
# Accepted W2:  9492
# Accepted S2:  9492
# Completed 9492
#
# Accepted I0:  9493
# Accepted I2:  9493
# Accepted I4:  9493
# Accepted W2:  9493
# Accepted S2:  9493
# Completed 9493
#
# Accepted S4:  9494
# Completed 9494
#
# Accepted I1:  9495
# Accepted W1:  9495
# Accepted W2:  9495
# Completed 9495
#
# Accepted W0:  9496
# Completed 9496
#
# Accepted W0:  9497
# Accepted W2:  9497
# Accepted W4:  9497
# Completed 9497
#
# Accepted I2:  9498
# Accepted S2:  9498
# Completed 9498
#
# Accepted I4:  9499
# Accepted W0:  9499
# Accepted W1:  9499
# Accepted W2:  9499
# Accepted S2:  9499
# Completed 9499
#
# Accepted W1:  9500
# Accepted S2:  9500
# Completed 9500
#
# Accepted S2:  9501
# Completed 9501
#
# Accepted I3:  9502
# Accepted W0:  9502
# Accepted W2:  9502
# Accepted S2:  9502
# Completed 9502
#
# Accepted I1:  9503
# Accepted W0:  9503
# Accepted W2:  9503
# Completed 9503
#
# Accepted Alpha:  9504
# Accepted W3:  9504
# Completed 9504
#
# Accepted I1:  9505
# Accepted W3:  9505
# Accepted S2:  9505
# Accepted S4:  9505
# Completed 9505
#
# Accepted I2:  9506
# Accepted W0:  9506
# Accepted W3:  9506
# Completed 9506
#
# Accepted I0:  9507
# Accepted W2:  9507
# Completed 9507
#
# Accepted I1:  9508
# Accepted W4:  9508
# Accepted S2:  9508
# Completed 9508
#
# Accepted I2:  9509
# Accepted S2:  9509
# Completed 9509
#
# Completed 9510
#
# Accepted I0:  9511
# Accepted I3:  9511
# Accepted I4:  9511
# Accepted W3:  9511
# Accepted W4:  9511
# Accepted S2:  9511
# Accepted Tau:  9511
# Completed 9511
#
# Accepted I3:  9512
# Accepted W1:  9512
# Completed 9512
#
# Accepted W0:  9513
# Accepted S2:  9513
# Completed 9513
#
# Accepted I2:  9514
# Accepted W3:  9514
# Accepted W4:  9514
# Completed 9514
#
# Accepted W0:  9515
# Accepted Tau:  9515
# Completed 9515
#
# Accepted W2:  9516
# Accepted W4:  9516
# Accepted S2:  9516
# Accepted S4:  9516
# Completed 9516
#
# Accepted I4:  9517
# Accepted W4:  9517
# Accepted S2:  9517
# Completed 9517
#
# Accepted I3:  9518
# Accepted W0:  9518
# Accepted S2:  9518
# Completed 9518
#
# Accepted I1:  9519
# Accepted W2:  9519
# Accepted Tau:  9519
# Completed 9519
#
# Accepted I0:  9520
# Accepted I3:  9520
# Accepted W3:  9520
# Completed 9520
#
# Completed 9521
#
# Accepted W1:  9522
# Completed 9522
#
# Accepted S2:  9523
# Accepted Tau:  9523
# Completed 9523
#
# Accepted W2:  9524
# Accepted S2:  9524
# Completed 9524
#
# Accepted I1:  9525
# Accepted I4:  9525
# Accepted T4:  9525
# Accepted W1:  9525
# Accepted W3:  9525
# Accepted S2:  9525
# Completed 9525
#
# Accepted I3:  9526
# Accepted W0:  9526
# Accepted W2:  9526
# Accepted W3:  9526
# Accepted S2:  9526
# Completed 9526
#
# Accepted I0:  9527
# Accepted I1:  9527
# Accepted S4:  9527
# Accepted Tau:  9527
# Completed 9527
#
# Accepted I1:  9528
# Accepted W0:  9528
# Accepted W3:  9528
# Accepted S2:  9528
# Completed 9528
#
# Accepted W0:  9529
# Accepted W2:  9529
# Completed 9529
#
# Accepted I0:  9530
# Accepted I4:  9530
# Completed 9530
#
# Completed 9531
#
# Accepted I3:  9532
# Completed 9532
#
# Accepted W4:  9533
# Completed 9533
#
# Accepted W4:  9534
# Completed 9534
#
# Accepted W4:  9535
# Accepted S2:  9535
# Accepted Tau:  9535
# Completed 9535
#
# Accepted I3:  9536
# Accepted W1:  9536
# Completed 9536
#
# Completed 9537
#
# Accepted S2:  9538
# Completed 9538
#
# Accepted W0:  9539
# Accepted S2:  9539
# Completed 9539
#
# Accepted I0:  9540
# Completed 9540
#
# Accepted Alpha:  9541
# Accepted W2:  9541
# Accepted S2:  9541
# Completed 9541
#
# Accepted I3:  9542
# Accepted W2:  9542
# Accepted S2:  9542
# Accepted S4:  9542
# Completed 9542
#
# Accepted S2:  9543
# Accepted Tau:  9543
# Completed 9543
#
# Accepted Tau:  9544
# Completed 9544
#
# Accepted S2:  9545
# Accepted Tau:  9545
# Completed 9545
#
# Accepted Tau:  9546
# Completed 9546
#
# Accepted S2:  9547
# Completed 9547
#
# Accepted W2:  9548
# Accepted S2:  9548
# Completed 9548
#
# Accepted T1:  9549
# Completed 9549
#
# Accepted I0:  9550
# Accepted W2:  9550
# Completed 9550
#
# Completed 9551
#
# Accepted W1:  9552
# Accepted S2:  9552
# Completed 9552
#
# Accepted Tau:  9553
# Completed 9553
#
# Accepted I0:  9554
# Accepted Tau:  9554
# Completed 9554
#
# Accepted W0:  9555
# Accepted S2:  9555
# Accepted Tau:  9555
# Completed 9555
#
# Accepted S0:  9556
# Accepted S2:  9556
# Accepted S4:  9556
# Completed 9556
#
# Accepted I0:  9557
# Accepted W4:  9557
# Accepted S2:  9557
# Completed 9557
#
# Accepted W2:  9558
# Accepted W3:  9558
# Completed 9558
#
# Accepted I0:  9559
# Accepted W0:  9559
# Accepted S2:  9559
# Accepted S4:  9559
# Completed 9559
#
# Accepted T1:  9560
# Accepted W4:  9560
# Accepted S2:  9560
# Accepted S4:  9560
# Completed 9560
#
# Accepted W2:  9561
# Completed 9561
#
# Accepted W0:  9562
# Accepted W3:  9562
# Accepted S2:  9562
# Completed 9562
#
# Accepted I0:  9563
# Accepted I1:  9563
# Accepted I4:  9563
# Accepted W4:  9563
# Accepted S2:  9563
# Completed 9563
#
# Accepted I0:  9564
# Accepted S2:  9564
# Completed 9564
#
# Accepted I3:  9565
# Accepted W0:  9565
# Accepted W1:  9565
# Accepted W2:  9565
# Accepted W3:  9565
# Accepted S2:  9565
# Completed 9565
#
# Accepted I0:  9566
# Accepted W0:  9566
# Accepted S4:  9566
# Completed 9566
#
# Accepted Alpha:  9567
# Accepted W2:  9567
# Accepted W4:  9567
# Accepted S2:  9567
# Completed 9567
#
# Accepted Tau:  9568
# Completed 9568
#
# Accepted Alpha:  9569
# Accepted W4:  9569
# Accepted Tau:  9569
# Completed 9569
#
# Accepted I3:  9570
# Accepted W0:  9570
# Accepted S2:  9570
# Accepted Tau:  9570
# Completed 9570
#
# Accepted W2:  9571
# Completed 9571
#
# Accepted Alpha:  9572
# Accepted I0:  9572
# Accepted W3:  9572
# Accepted S2:  9572
# Completed 9572
#
# Accepted I3:  9573
# Accepted T3:  9573
# Completed 9573
#
# Accepted S2:  9574
# Accepted S4:  9574
# Completed 9574
#
# Accepted S2:  9575
# Completed 9575
#
# Accepted W0:  9576
# Completed 9576
#
# Completed 9577
#
# Accepted Alpha:  9578
# Accepted S2:  9578
# Accepted S4:  9578
# Completed 9578
#
# Accepted W3:  9579
# Completed 9579
#
# Accepted I4:  9580
# Accepted W0:  9580
# Accepted S2:  9580
# Accepted S4:  9580
# Completed 9580
#
# Accepted I1:  9581
# Accepted W0:  9581
# Accepted S2:  9581
# Completed 9581
#
# Accepted W0:  9582
# Accepted W4:  9582
# Accepted S2:  9582
# Accepted Tau:  9582
# Completed 9582
#
# Accepted W2:  9583
# Accepted W3:  9583
# Accepted Tau:  9583
# Completed 9583
#
# Accepted S2:  9584
# Completed 9584
#
# Accepted W1:  9585
# Accepted W3:  9585
# Accepted S2:  9585
# Completed 9585
#
# Accepted Alpha:  9586
# Accepted S2:  9586
# Completed 9586
#
# Accepted W0:  9587
# Accepted W4:  9587
# Completed 9587
#
# Accepted I1:  9588
# Accepted S2:  9588
# Completed 9588
#
# Accepted I0:  9589
# Accepted W1:  9589
# Completed 9589
#
# Accepted I0:  9590
# Completed 9590
#
# Accepted W3:  9591
# Accepted S2:  9591
# Accepted S4:  9591
# Completed 9591
#
# Accepted I3:  9592
# Accepted W1:  9592
# Accepted W3:  9592
# Completed 9592
#
# Accepted W0:  9593
# Accepted W4:  9593
# Accepted S2:  9593
# Completed 9593
#
# Accepted I2:  9594
# Accepted W2:  9594
# Accepted W4:  9594
# Accepted S2:  9594
# Completed 9594
#
# Accepted I4:  9595
# Accepted W1:  9595
# Accepted S4:  9595
# Completed 9595
#
# Completed 9596
#
# Accepted I3:  9597
# Accepted W1:  9597
# Accepted S2:  9597
# Completed 9597
#
# Accepted I0:  9598
# Accepted S2:  9598
# Completed 9598
#
# Accepted I4:  9599
# Completed 9599
#
# Accepted I2:  9600
# Accepted W4:  9600
# Accepted S2:  9600
# Completed 9600
#
# Accepted W3:  9601
# Accepted W4:  9601
# Accepted S2:  9601
# Completed 9601
#
# Accepted W2:  9602
# Accepted W3:  9602
# Accepted W4:  9602
# Accepted S2:  9602
# Completed 9602
#
# Accepted W3:  9603
# Accepted S2:  9603
# Completed 9603
#
# Accepted Tau:  9604
# Completed 9604
#
# Accepted I0:  9605
# Accepted I4:  9605
# Completed 9605
#
# Accepted I3:  9606
# Accepted W3:  9606
# Accepted S2:  9606
# Completed 9606
#
# Accepted I2:  9607
# Accepted S2:  9607
# Completed 9607
#
# Accepted W0:  9608
# Completed 9608
#
# Accepted W1:  9609
# Completed 9609
#
# Accepted W0:  9610
# Accepted W3:  9610
# Completed 9610
#
# Accepted W3:  9611
# Accepted S2:  9611
# Completed 9611
#
# Accepted I1:  9612
# Accepted W3:  9612
# Completed 9612
#
# Accepted I4:  9613
# Accepted W3:  9613
# Accepted W4:  9613
# Accepted S2:  9613
# Accepted Tau:  9613
# Completed 9613
#
# Accepted W2:  9614
# Completed 9614
#
# Accepted I1:  9615
# Accepted W3:  9615
# Completed 9615
#
# Accepted W0:  9616
# Accepted W2:  9616
# Accepted S2:  9616
# Accepted Tau:  9616
# Completed 9616
#
# Completed 9617
#
# Accepted I4:  9618
# Accepted W1:  9618
# Accepted W2:  9618
# Accepted W4:  9618
# Accepted S4:  9618
# Completed 9618
#
# Accepted I4:  9619
# Completed 9619
#
# Accepted W1:  9620
# Accepted W2:  9620
# Accepted W4:  9620
# Completed 9620
#
# ...
#
# Accepted I2:  9748
# Accepted W1:  9748
# Accepted S2:  9748
# Accepted Tau:  9748
# Completed 9748
#
# Accepted I1:  9749
# Accepted S4:  9749
# Completed 9749
#
# Completed 9750
#
# Accepted S2:  9751
# Completed 9751
#
# Accepted Alpha:  9752
# Accepted I2:  9752
# Accepted S2:  9752
# Accepted S4:  9752
# Completed 9752
#
# Accepted Beta:  9753
# Accepted I3:  9753
# Accepted S2:  9753
# Completed 9753
#
# Completed 9754
#
# Accepted W2:  9755
# Accepted S2:  9755
# Completed 9755
#
# Accepted I0:  9756
# Accepted W1:  9756
# Accepted W2:  9756
# Accepted S2:  9756
# Accepted S4:  9756
# Accepted Tau:  9756
# Completed 9756
#
# Accepted W4:  9757
# Accepted S2:  9757
# Completed 9757
#
# Accepted Alpha:  9758
# Completed 9758
#
# Completed 9759
#
# Accepted W3:  9760
# Accepted S2:  9760
# Completed 9760
#
# Accepted W3:  9761
# Accepted S2:  9761
# Accepted Tau:  9761
# Completed 9761
#
# Accepted I0:  9762
# Accepted W3:  9762
# Accepted W4:  9762
# Completed 9762
#
# Accepted W1:  9763
# Accepted W2:  9763
# Accepted W4:  9763
# Accepted S2:  9763
# Accepted Tau:  9763
# Completed 9763
#
# Accepted I2:  9764
# Accepted W0:  9764
# Accepted W3:  9764
# Accepted S2:  9764
# Completed 9764
#
# Accepted W4:  9765
# Accepted S2:  9765
# Accepted S4:  9765
# Completed 9765
#
# Accepted W2:  9766
# Accepted W4:  9766
# Completed 9766
#
# Accepted I1:  9767
# Accepted W1:  9767
# Accepted S2:  9767
# Completed 9767
#
# Accepted I2:  9768
# Accepted W3:  9768
# Accepted S2:  9768
# Completed 9768
#
# Accepted W1:  9769
# Accepted Tau:  9769
# Completed 9769
#
# Accepted S2:  9770
# Completed 9770
#
# Accepted S2:  9771
# Completed 9771
#
# Accepted I1:  9772
# Accepted I3:  9772
# Accepted W0:  9772
# Accepted W1:  9772
# Accepted S4:  9772
# Completed 9772
#
# Accepted Alpha:  9773
# Accepted Beta:  9773
# Accepted I1:  9773
# Accepted T1:  9773
# Accepted W2:  9773
# Completed 9773
#
# Accepted I1:  9774
# Accepted S2:  9774
# Completed 9774
#
# Accepted I4:  9775
# Completed 9775
#
# Accepted W2:  9776
# Accepted W3:  9776
# Accepted S2:  9776
# Completed 9776
#
# Accepted I1:  9777
# Accepted I4:  9777
# Accepted W0:  9777
# Completed 9777
#
# Accepted I1:  9778
# Accepted W1:  9778
# Accepted W3:  9778
# Accepted W4:  9778
# Accepted S2:  9778
# Accepted Tau:  9778
# Completed 9778
#
# Accepted I0:  9779
# Accepted W0:  9779
# Accepted W3:  9779
# Completed 9779
#
# Accepted Alpha:  9780
# Accepted I3:  9780
# Accepted S3:  9780
# Accepted Tau:  9780
# Completed 9780
#
# Accepted W1:  9781
# Accepted W3:  9781
# Completed 9781
#
# Accepted S4:  9782
# Accepted Tau:  9782
# Completed 9782
#
# Accepted I1:  9783
# Completed 9783
#
# Accepted I0:  9784
# Accepted W2:  9784
# Accepted S2:  9784
# Completed 9784
#
# Accepted I1:  9785
# Accepted I3:  9785
# Accepted W1:  9785
# Accepted W4:  9785
# Completed 9785
#
# Accepted I4:  9786
# Accepted S2:  9786
# Completed 9786
#
# Accepted W0:  9787
# Accepted W4:  9787
# Accepted S2:  9787
# Completed 9787
#
# Accepted I3:  9788
# Accepted W1:  9788
# Accepted S2:  9788
# Completed 9788
#
# Accepted W0:  9789
# Completed 9789
#
# Accepted W3:  9790
# Accepted S4:  9790
# Completed 9790
#
# Accepted Alpha:  9791
# Accepted I0:  9791
# Accepted I1:  9791
# Accepted I4:  9791
# Accepted W0:  9791
# Accepted S0:  9791
# Completed 9791
#
# Accepted T0:  9792
# Accepted W0:  9792
# Accepted W4:  9792
# Accepted S2:  9792
# Accepted S3:  9792
# Completed 9792
#
# Accepted S2:  9793
# Completed 9793
#
# Accepted W2:  9794
# Accepted W3:  9794
# Completed 9794
#
# Accepted I1:  9795
# Accepted W0:  9795
# Accepted S4:  9795
# Completed 9795
#
# Accepted W4:  9796
# Accepted S2:  9796
# Completed 9796
#
# Accepted Alpha:  9797
# Accepted I2:  9797
# Accepted W4:  9797
# Completed 9797
#
# Accepted I0:  9798
# Accepted W0:  9798
# Accepted W4:  9798
# Completed 9798
#
# Accepted W1:  9799
# Accepted S2:  9799
# Accepted S4:  9799
# Completed 9799
#
# Accepted I4:  9800
# Accepted W3:  9800
# Accepted W4:  9800
# Accepted S2:  9800
# Completed 9800
#
# Accepted I2:  9801
# Accepted W0:  9801
# Completed 9801
#
# Accepted Alpha:  9802
# Accepted I4:  9802
# Accepted W0:  9802
# Accepted S4:  9802
# Accepted Tau:  9802
# Completed 9802
#
# Accepted Alpha:  9803
# Completed 9803
#
# Accepted I4:  9804
# Accepted W3:  9804
# Accepted S2:  9804
# Accepted Tau:  9804
# Completed 9804
#
# Accepted I0:  9805
# Accepted W3:  9805
# Accepted S2:  9805
# Completed 9805
#
# Accepted W0:  9806
# Accepted W4:  9806
# Completed 9806
#
# Accepted S2:  9807
# Completed 9807
#
# Accepted W4:  9808
# Accepted S2:  9808
# Completed 9808
#
# Accepted I0:  9809
# Accepted S2:  9809
# Completed 9809
#
# Accepted I2:  9810
# Accepted W2:  9810
# Accepted S2:  9810
# Completed 9810
#
# Accepted I3:  9811
# Accepted Tau:  9811
# Completed 9811
#
# Accepted I3:  9812
# Accepted S2:  9812
# Completed 9812
#
# Accepted W2:  9813
# Completed 9813
#
# Accepted W0:  9814
# Accepted W4:  9814
# Accepted S2:  9814
# Completed 9814
#
# Accepted I0:  9815
# Accepted W2:  9815
# Completed 9815
#
# Accepted I1:  9816
# Accepted I2:  9816
# Accepted I4:  9816
# Completed 9816
#
# Accepted I0:  9817
# Accepted W0:  9817
# Accepted W3:  9817
# Accepted S2:  9817
# Accepted S4:  9817
# Accepted Tau:  9817
# Completed 9817
#
# Accepted W1:  9818
# Completed 9818
#
# Accepted I2:  9819
# Accepted W2:  9819
# Accepted W4:  9819
# Completed 9819
#
# Accepted I1:  9820
# Accepted I4:  9820
# Accepted W0:  9820
# Accepted Tau:  9820
# Completed 9820
#
# Completed 9821
#
# Accepted W4:  9822
# Accepted S2:  9822
# Completed 9822
#
# Accepted I0:  9823
# Accepted S2:  9823
# Completed 9823
#
# Accepted W1:  9824
# Accepted W3:  9824
# Accepted S2:  9824
# Completed 9824
#
# Accepted W2:  9825
# Accepted S2:  9825
# Completed 9825
#
# Accepted W0:  9826
# Accepted W3:  9826
# Accepted S2:  9826
# Completed 9826
#
# Accepted I2:  9827
# Accepted W4:  9827
# Completed 9827
#
# Accepted W1:  9828
# Accepted S2:  9828
# Completed 9828
#
# Accepted W2:  9829
# Accepted W4:  9829
# Accepted S2:  9829
# Completed 9829
#
# Accepted W4:  9830
# Accepted S4:  9830
# Completed 9830
#
# Accepted Alpha:  9831
# Accepted T0:  9831
# Accepted W4:  9831
# Accepted S2:  9831
# Completed 9831
#
# Accepted Alpha:  9832
# Accepted I0:  9832
# Accepted S2:  9832
# Completed 9832
#
# Accepted I3:  9833
# Accepted I4:  9833
# Accepted W0:  9833
# Accepted W4:  9833
# Completed 9833
#
# Accepted I0:  9834
# Accepted W0:  9834
# Accepted W4:  9834
# Accepted S2:  9834
# Completed 9834
#
# Accepted Alpha:  9835
# Accepted I1:  9835
# Accepted W0:  9835
# Accepted W1:  9835
# Accepted S2:  9835
# Completed 9835
#
# Accepted Alpha:  9836
# Completed 9836
#
# Accepted W4:  9837
# Accepted S2:  9837
# Completed 9837
#
# Accepted I4:  9838
# Accepted S2:  9838
# Completed 9838
#
# Accepted I0:  9839
# Accepted W0:  9839
# Accepted S2:  9839
# Accepted Tau:  9839
# Completed 9839
#
# Accepted Alpha:  9840
# Accepted T3:  9840
# Completed 9840
#
# Accepted I2:  9841
# Completed 9841
#
# Accepted W3:  9842
# Accepted S2:  9842
# Completed 9842
#
# Accepted W1:  9843
# Completed 9843
#
# Accepted W0:  9844
# Accepted W4:  9844
# Completed 9844
#
# Accepted I2:  9845
# Accepted T3:  9845
# Accepted W0:  9845
# Accepted W2:  9845
# Accepted Tau:  9845
# Completed 9845
#
# Completed 9846
#
# Accepted Alpha:  9847
# Completed 9847
#
# Accepted W1:  9848
# Accepted W4:  9848
# Accepted Tau:  9848
# Completed 9848
#
# Accepted I1:  9849
# Accepted T3:  9849
# Accepted W0:  9849
# Completed 9849
#
# Accepted W3:  9850
# Completed 9850
#
# Completed 9851
#
# Accepted I4:  9852
# Accepted W0:  9852
# Accepted W2:  9852
# Accepted W4:  9852
# Accepted Tau:  9852
# Completed 9852
#
# Accepted W4:  9853
# Completed 9853
#
# Accepted I1:  9854
# Accepted W2:  9854
# Accepted W4:  9854
# Accepted S1:  9854
# Accepted S2:  9854
# Completed 9854
#
# Completed 9855
#
# Accepted W3:  9856
# Completed 9856
#
# Accepted W1:  9857
# Accepted W2:  9857
# Accepted W4:  9857
# Accepted S2:  9857
# Completed 9857
#
# Accepted W3:  9858
# Completed 9858
#
# Accepted Alpha:  9859
# Accepted W0:  9859
# Accepted W3:  9859
# Completed 9859
#
# Accepted W0:  9860
# Accepted W4:  9860
# Completed 9860
#
# Accepted W4:  9861
# Completed 9861
#
# Accepted W0:  9862
# Accepted W1:  9862
# Accepted W2:  9862
# Accepted S2:  9862
# Completed 9862
#
# Accepted I0:  9863
# Accepted W1:  9863
# Completed 9863
#
# Accepted W3:  9864
# Completed 9864
#
# Accepted I0:  9865
# Accepted W3:  9865
# Completed 9865
#
# Accepted W2:  9866
# Accepted W3:  9866
# Accepted S4:  9866
# Completed 9866
#
# Accepted I0:  9867
# Completed 9867
#
# Accepted I0:  9868
# Accepted W0:  9868
# Accepted S2:  9868
# Completed 9868
#
# Accepted W1:  9869
# Accepted W4:  9869
# Accepted S0:  9869
# Completed 9869
#
# Accepted I3:  9870
# Accepted W0:  9870
# Accepted W1:  9870
# Accepted W2:  9870
# Accepted S2:  9870
# Completed 9870
#
# Accepted W0:  9871
# Accepted S2:  9871
# Accepted Tau:  9871
# Completed 9871
#
# Accepted I3:  9872
# Accepted W1:  9872
# Accepted S4:  9872
# Completed 9872
#
# Accepted W0:  9873
# Completed 9873
#
# Accepted S2:  9874
# Accepted S4:  9874
# Completed 9874
#
# Accepted I4:  9875
# Accepted S2:  9875
# Accepted Tau:  9875
# Completed 9875
#
# Accepted W1:  9876
# Accepted W3:  9876
# Accepted W4:  9876
# Accepted S2:  9876
# Completed 9876
#
# Accepted I3:  9877
# Accepted S2:  9877
# Accepted Tau:  9877
# Completed 9877
#
# Accepted W0:  9878
# Accepted W3:  9878
# Completed 9878
#
# Accepted T0:  9879
# Accepted W1:  9879
# Completed 9879
#
# Accepted T3:  9880
# Accepted W1:  9880
# Accepted S2:  9880
# Accepted S4:  9880
# Accepted Tau:  9880
# Completed 9880
#
# Accepted S2:  9881
# Completed 9881
#
# Accepted I1:  9882
# Accepted W4:  9882
# Accepted S2:  9882
# Accepted Tau:  9882
# Completed 9882
#
# Accepted W3:  9883
# Accepted S2:  9883
# Accepted S3:  9883
# Accepted Tau:  9883
# Completed 9883
#
# Accepted I2:  9884
# Accepted W3:  9884
# Accepted S2:  9884
# Completed 9884
#
# Accepted S2:  9885
# Completed 9885
#
# Accepted W0:  9886
# Accepted S2:  9886
# Completed 9886
#
# Accepted T3:  9887
# Accepted W1:  9887
# Accepted W3:  9887
# Accepted S2:  9887
# Completed 9887
#
# Accepted S2:  9888
# Completed 9888
#
# Accepted W1:  9889
# Accepted W2:  9889
# Accepted Tau:  9889
# Completed 9889
#
# Accepted S2:  9890
# Completed 9890
#
# Accepted W0:  9891
# Completed 9891
#
# Accepted I3:  9892
# Completed 9892
#
# Accepted S0:  9893
# Completed 9893
#
# Accepted W0:  9894
# Accepted W1:  9894
# Accepted W3:  9894
# Accepted W4:  9894
# Accepted S2:  9894
# Completed 9894
#
# Accepted W4:  9895
# Accepted S4:  9895
# Completed 9895
#
# Accepted I3:  9896
# Accepted W3:  9896
# Accepted W4:  9896
# Accepted S4:  9896
# Accepted Tau:  9896
# Completed 9896
#
# Accepted I2:  9897
# Accepted W0:  9897
# Completed 9897
#
# Accepted I4:  9898
# Accepted W4:  9898
# Completed 9898
#
# Completed 9899
#
# Accepted W1:  9900
# Accepted W2:  9900
# Accepted S2:  9900
# Completed 9900
#
# Accepted W0:  9901
# Accepted Tau:  9901
# Completed 9901
#
# Accepted I2:  9902
# Accepted W4:  9902
# Accepted S2:  9902
# Completed 9902
#
# Accepted I4:  9903
# Accepted W2:  9903
# Accepted W4:  9903
# Completed 9903
#
# Accepted W0:  9904
# Accepted W2:  9904
# Accepted S2:  9904
# Completed 9904
#
# Accepted I2:  9905
# Accepted Tau:  9905
# Completed 9905
#
# Accepted W2:  9906
# Accepted W3:  9906
# Completed 9906
#
# Accepted W0:  9907
# Accepted S2:  9907
# Completed 9907
#
# Accepted W0:  9908
# Accepted W1:  9908
# Accepted Tau:  9908
# Completed 9908
#
# Accepted I1:  9909
# Accepted W0:  9909
# Completed 9909
#
# Accepted S2:  9910
# Completed 9910
#
# Accepted I3:  9911
# Accepted I4:  9911
# Accepted W1:  9911
# Completed 9911
#
# Accepted W3:  9912
# Completed 9912
#
# Accepted S2:  9913
# Completed 9913
#
# Accepted W2:  9914
# Accepted W3:  9914
# Accepted S2:  9914
# Accepted Tau:  9914
# Completed 9914
#
# Accepted W0:  9915
# Accepted S2:  9915
# Completed 9915
#
# Accepted W0:  9916
# Accepted W4:  9916
# Accepted S2:  9916
# Completed 9916
#
# Accepted I3:  9917
# Accepted W4:  9917
# Accepted S2:  9917
# Completed 9917
#
# Accepted I0:  9918
# Accepted I3:  9918
# Completed 9918
#
# Accepted W0:  9919
# Accepted W4:  9919
# Accepted S2:  9919
# Completed 9919
#
# Accepted I2:  9920
# Accepted W2:  9920
# Accepted W4:  9920
# Accepted S4:  9920
# Completed 9920
#
# Accepted I0:  9921
# Accepted I3:  9921
# Accepted Tau:  9921
# Completed 9921
#
# Accepted I2:  9922
# Accepted I3:  9922
# Accepted W3:  9922
# Completed 9922
#
# Accepted W4:  9923
# Accepted S2:  9923
# Completed 9923
#
# Accepted Alpha:  9924
# Accepted S2:  9924
# Completed 9924
#
# Accepted I1:  9925
# Accepted I4:  9925
# Accepted W2:  9925
# Accepted W3:  9925
# Completed 9925
#
# Accepted W4:  9926
# Accepted S2:  9926
# Completed 9926
#
# Accepted I1:  9927
# Accepted T2:  9927
# Accepted W4:  9927
# Completed 9927
#
# Accepted W0:  9928
# Accepted W1:  9928
# Accepted S2:  9928
# Completed 9928
#
# Completed 9929
#
# Accepted I1:  9930
# Accepted I4:  9930
# Accepted S2:  9930
# Completed 9930
#
# Accepted Alpha:  9931
# Accepted I1:  9931
# Accepted W1:  9931
# Accepted S2:  9931
# Completed 9931
#
# Completed 9932
#
# Accepted I2:  9933
# Accepted W0:  9933
# Completed 9933
#
# Accepted W1:  9934
# Accepted W4:  9934
# Completed 9934
#
# Accepted I3:  9935
# Accepted W1:  9935
# Accepted S2:  9935
# Completed 9935
#
# Accepted W0:  9936
# Accepted W1:  9936
# Accepted S2:  9936
# Completed 9936
#
# Accepted Alpha:  9937
# Completed 9937
#
# Accepted Alpha:  9938
# Accepted I0:  9938
# Accepted I4:  9938
# Accepted W4:  9938
# Completed 9938
#
# Accepted W2:  9939
# Completed 9939
#
# Accepted W2:  9940
# Accepted W3:  9940
# Completed 9940
#
# Accepted W0:  9941
# Accepted W3:  9941
# Completed 9941
#
# Accepted W1:  9942
# Accepted W3:  9942
# Accepted W4:  9942
# Completed 9942
#
# Completed 9943
#
# Accepted Alpha:  9944
# Accepted I2:  9944
# Accepted T1:  9944
# Accepted S2:  9944
# Completed 9944
#
# Completed 9945
#
# Accepted I0:  9946
# Accepted S2:  9946
# Completed 9946
#
# Accepted W4:  9947
# Accepted S2:  9947
# Completed 9947
#
# Completed 9948
#
# Accepted W0:  9949
# Accepted W1:  9949
# Accepted S2:  9949
# Completed 9949
#
# Accepted S2:  9950
# Completed 9950
#
# Accepted S4:  9951
# Completed 9951
#
# Accepted Alpha:  9952
# Accepted I0:  9952
# Accepted I2:  9952
# Accepted I4:  9952
# Accepted W2:  9952
# Completed 9952
#
# Accepted T0:  9953
# Accepted W0:  9953
# Accepted W1:  9953
# Accepted W3:  9953
# Completed 9953
#
# Accepted I4:  9954
# Accepted T2:  9954
# Accepted W2:  9954
# Accepted W3:  9954
# Completed 9954
#
# Accepted I2:  9955
# Accepted I3:  9955
# Accepted W3:  9955
# Accepted W4:  9955
# Accepted S4:  9955
# Completed 9955
#
# Accepted I2:  9956
# Accepted W2:  9956
# Completed 9956
#
# Accepted W4:  9957
# Completed 9957
#
# Accepted I2:  9958
# Accepted W0:  9958
# Completed 9958
#
# Accepted W2:  9959
# Accepted W3:  9959
# Completed 9959
#
# Accepted W3:  9960
# Accepted W4:  9960
# Accepted S2:  9960
# Completed 9960
#
# Accepted W0:  9961
# Accepted S2:  9961
# Completed 9961
#
# Accepted W3:  9962
# Accepted W4:  9962
# Completed 9962
#
# Accepted W3:  9963
# Accepted S2:  9963
# Completed 9963
#
# Accepted W4:  9964
# Accepted S2:  9964
# Completed 9964
#
# Accepted Alpha:  9965
# Accepted W2:  9965
# Accepted W3:  9965
# Accepted S2:  9965
# Completed 9965
#
# Accepted I1:  9966
# Accepted W0:  9966
# Accepted W4:  9966
# Completed 9966
#
# Accepted W4:  9967
# Completed 9967
#
# Accepted S2:  9968
# Completed 9968
#
# Accepted W4:  9969
# Completed 9969
#
# Accepted Alpha:  9970
# Accepted I1:  9970
# Accepted I2:  9970
# Completed 9970
#
# Accepted W0:  9971
# Accepted W4:  9971
# Completed 9971
#
# Accepted I4:  9972
# Accepted W0:  9972
# Completed 9972
#
# Accepted I3:  9973
# Accepted S2:  9973
# Completed 9973
#
# Completed 9974
#
# Accepted W2:  9975
# Accepted Tau:  9975
# Completed 9975
#
# Accepted W3:  9976
# Accepted S2:  9976
# Completed 9976
#
# Accepted I0:  9977
# Accepted I2:  9977
# Accepted W0:  9977
# Completed 9977
#
# Accepted I1:  9978
# Accepted W4:  9978
# Completed 9978
#
# Accepted S2:  9979
# Completed 9979
#
# Accepted W2:  9980
# Completed 9980
#
# Accepted Alpha:  9981
# Accepted W3:  9981
# Accepted Tau:  9981
# Completed 9981
#
# Accepted W0:  9982
# Accepted W4:  9982
# Completed 9982
#
# Accepted W0:  9983
# Accepted W1:  9983
# Accepted W4:  9983
# Accepted S2:  9983
# Completed 9983
#
# Accepted I0:  9984
# Completed 9984
#
# Accepted I1:  9985
# Accepted I2:  9985
# Accepted T1:  9985
# Accepted W0:  9985
# Accepted W1:  9985
# Completed 9985
#
# Accepted I2:  9986
# Accepted W3:  9986
# Accepted S2:  9986
# Completed 9986
#
# Accepted W4:  9987
# Accepted S2:  9987
# Completed 9987
#
# Accepted S2:  9988
# Accepted S4:  9988
# Completed 9988
#
# Accepted W1:  9989
# Accepted S2:  9989
# Accepted S4:  9989
# Completed 9989
#
# Accepted I1:  9990
# Accepted I2:  9990
# Accepted W0:  9990
# Accepted W4:  9990
# Accepted S2:  9990
# Completed 9990
#
# Accepted I0:  9991
# Accepted I4:  9991
# Accepted W2:  9991
# Accepted Tau:  9991
# Completed 9991
#
# Accepted W3:  9992
# Accepted S2:  9992
# Accepted Tau:  9992
# Completed 9992
#
# Accepted I2:  9993
# Accepted W0:  9993
# Accepted S2:  9993
# Accepted Tau:  9993
# Completed 9993
#
# Accepted W1:  9994
# Accepted S2:  9994
# Completed 9994
#
# Accepted Alpha:  9995
# Accepted I0:  9995
# Accepted I3:  9995
# Accepted W2:  9995
# Accepted W4:  9995
# Completed 9995
#
# Completed 9996
#
# Accepted T1:  9997
# Completed 9997
#
# Accepted I2:  9998
# Accepted W0:  9998
# Accepted W1:  9998
# Accepted W2:  9998
# Completed 9998
#
# Completed 9999
#
# Computing time was 2 hours 11 minutes and 33 seconds

# %% [markdown]
# # Results

# %%
#@title Printing acceptance probabilities

for (accept, name) in [(alphaAccept, 'alpha'), (betaAccept, 'beta'), (IAccept, 'I'), (TAccept, 'T'), (WAccept, 'W'), (SAccept, 'S'), (tauAccept, 'Tau')]:
    print(f"{name} Acceptance rate: {format(accept/S, '.4f')}")
# Out:
# alpha Acceptance rate: 0.0564
# beta Acceptance rate: 0.0038
# I Acceptance rate: 0.0999
# T Acceptance rate: 0.0105
# W Acceptance rate: 0.2078
# S Acceptance rate: 0.1860
# Tau Acceptance rate: 0.1372

# %% [markdown]
# ## Summary Statistics

# %% [markdown]
# ### Alpha

# %%
#@title True vs Median

print(f"{trueAlpha}, {np.median(alphaArray)}")
# Out:
# 2.508623804656746, 3.490195704822357

# %%
#@title 95% Confidence Interval

stats.t.interval(alpha = 0.95, df = len(alphaArray) - 1,
                  loc = np.mean(alphaArray),
                  scale = stats.sem(alphaArray))
# Out:
# (4.059681358308973, 4.123049275744794)

# %% [markdown]
# ### Beta

# %%
#@title True vs Median

print(f"{trueBeta}, {np.median(betaArray)}")
# Out:
# 0.5927384620724628, 0.6118411646087444

# %%
#@title 95% Confidence Interval

stats.t.interval(alpha = 0.95, df = len(betaArray) - 1,
                  loc = np.mean(betaArray),
                  scale = stats.sem(betaArray))
# Out:
# (0.6107588820943244, 0.6108499754592112)

# %% [markdown]
# ### I

# %%
#@title True vs Median

for i in range(trueN):  
    print(trueI[i], int(np.median(IArray[:, i])))
# Out:
# 7 2
# 2 5
# 2 2
# 5 6
# 6 7

# %%
#@title 95% Confidence Interval

for i in range(trueN):
    print(stats.t.interval(alpha = 0.95, df = len(IArray[:, i]) - 1,
                      loc = np.mean(IArray[:, i]),
                      scale = stats.sem(IArray[:, i])))
# Out:
# (1.9959571291738358, 1.9986428708261643)
# (4.992624533264826, 4.997175466735174)
# (2.008201179666489, 2.017398820333511)
# (5.999903979873638, 6.0002960201263615)
# (6.998523406414346, 7.000276593585653)

# %% [markdown]
# ### T

# %%
#@title True vs Median

for i in range(trueN):  
    print(trueT[i], int(np.median(TArray[:, i])))
# Out:
# 36 78
# 78 88
# 6 6
# 89 23
# 23 36

# %%
#@title 95% Confidence Interval

for i in range(trueN):
    print(stats.t.interval(alpha = 0.95, df = len(TArray[:, i]) - 1,
                      loc = np.mean(TArray[:, i]),
                      scale = stats.sem(TArray[:, i])))
# Out:
# (77.96405344207572, 77.98134655792428)
# (87.67756248225683, 87.71523751774316)
# (5.994334812544634, 6.0174651874553655)
# (22.792852167251677, 22.837547832748324)
# (nan, nan)
# /usr/local/lib/python3.8/dist-packages/scipy/stats/_distn_infrastructure.py:2128: RuntimeWarning: invalid value encountered in multiply
#   lower_bound = _a * scale + loc
# /usr/local/lib/python3.8/dist-packages/scipy/stats/_distn_infrastructure.py:2129: RuntimeWarning: invalid value encountered in multiply
#   upper_bound = _b * scale + loc

# %% [markdown]
# ### W

# %%
#@title True vs Median

for i in range(trueN):  
    print(trueW[i], int(np.median(WArray[:, i])))
# Out:
# 3 2
# 1 5
# 4 2
# 2 3
# 3 2

# %%
#@title 95% Confidence Interval

for i in range(trueN):
    print(stats.t.interval(alpha = 0.95, df = len(WArray[:, i]) - 1,
                      loc = np.mean(WArray[:, i]),
                      scale = stats.sem(WArray[:, i])))
# Out:
# (2.0203578149348873, 2.027242185065113)
# (5.04917489685946, 5.062225103140539)
# (2.0007077035833825, 2.003692296416618)
# (2.9993813572653423, 3.0004186427346573)
# (1.99884566840081, 1.9999543315991901)

# %% [markdown]
# ### S

# %%
#@title True vs Median

for i in range(trueN):  
    print(trueS[i], np.median(SArray[:, i]))
# Out:
# 0.1164415132592775 0.021178282799291282
# 0.116203795156879 0.04388268612724301
# 0.1900238757546006 1.5098099508995642
# 4.574614130966091 0.03570703000958673
# 0.0688701103676334 0.22943919895432902

# %%
#@title 95% Confidence Interval

for i in range(trueN):
    print(stats.t.interval(alpha = 0.95, df = len(SArray[:, i]) - 1,
                      loc = np.mean(SArray[:, i]),
                      scale = stats.sem(SArray[:, i])))
# Out:
# (0.020173438201869977, 0.02044924519726454)
# (0.0390831605609662, 0.04007514723169504)
# (1.4280681087742917, 1.4425052014742168)
# (0.03241560107466197, 0.033106063085114434)
# (0.21563752471508718, 0.21803508287118606)

# %% [markdown]
# ### Tau

# %%
#@title True vs Median

print(f"{trueTau}, {np.median(tauArray)}")
# Out:
# 2.298576049444426, 1.1903928570823024

# %%
#@title 95% Confidence Interval

stats.t.interval(alpha = 0.95, df = len(tauArray) - 1,
                  loc = np.mean(tauArray),
                  scale = stats.sem(tauArray))
# Out:
# (1.1762671725033136, 1.1809867164635395)

# %% [markdown]
# ## Plotting results

# %%
#@title Plotting true mass sample
plotResults(sample, sites, length, "True Mass Sample", "Mass")

# %%
plotResults(sample*OArray, sites, length, "True Mass Sample - Observed", "Mass")

# %%
#@title Plotting true C sample

plotResults(CArray, sites, length, "True Concentration Sample", "Concentration")

# %%
plotResults(CArray*OArray, sites, length, "True Concentration Sample - Observed", "Concentration")

# %%
#@title Plotting true Y Sample

plotResults(Y, sites, length, "True Y Sample", "Y")

# %%
plotResults(Y*OArray, sites, length, "True Y Sample - Observed", "Y")

# %%
#@title Plotting true Y sample - Converted from log
plotResults(np.e**Y, sites, length, "True Y Sample - Converted from Log", "e^Y")

# %%
plotResults((np.e**Y)*OArray, sites, length, "True Y Sample - Converted from Log - Observed", "e^Y")

# %%
#@title Plotting Mass sample determined from parameters
massSample = getSample(sites, length, pmat, np.median(alphaArray), np.median(betaArray), phi[2], 
                       [int(np.median(IArray[:, i])) for i in range(phi[2])], [int(np.median(TArray[:, i])) for i in range(phi[2])], 
                       [int(np.median(WArray[:, i])) for i in range(phi[2])], [np.median(SArray[:, i]) for i in range(phi[2])])

plotResults(massSample, sites, length, "Predicted Mass Sample", "Mass")

# %%
plotResults(massSample*OArray, sites, length, "Predicted Mass Sample - Observed", "Mass")

# %%
#@title Plotting Concentration sample determined from parameters

concSample = convertConcentration(sites, length, massSample, V, delta)
ySample = convertY(concSample, 1/np.sqrt(np.median(tauArray)))

plotResults(concSample, sites, length, "Predicted Concentration Sample", "Concentration")

# %%
plotResults(concSample*OArray, sites, length, "Predicted Concentration Sample - Observed", "Concentration")

# %%
#@title Plotting Y sample determined from parameters

plotResults(ySample, sites, length, "Predicted Y Sample", "Y")

# %%
plotResults(ySample*OArray, sites, length, "Predicted Y Sample - Observed", "Y")

# %%
#@title Plotting Y sample determined from parameters - converted from log
plotResults(np.e**ySample, sites, length, "Predicted Y Sample - Converted from Log", "e^Y")

# %%
#@title Plotting Y sample determined from parameters - converted from log
plotResults((np.e**ySample)*OArray, sites, length, "Predicted Y Sample - Converted from Log - Observed", "e^Y")

# %% [markdown]
# ## Metrics

# %% [markdown]
# ### DIC

# %%
#@title Walk of DIC for full data

plotDIC(DICFullArray, sites, length, "full Data")

# %%
#@title Walk of DIC for observed data

plotDIC(DICObservedArray, sites, length, "observed Data")

# %% [markdown]
# ### Likelihood

# %%
#@title Walk of likelihood for full data

plotLikelihood(likelihoodFullArray, sites, length, "full Data")

# %%
#@title Walk of likelihood for observed data

plotLikelihood(likelihoodObservedArray, sites, length, "observed Data")

# %% [markdown]
# ## Alpha

# %%
#@title Walk

plotWalk(alphaArray, trueAlpha, "Alpha")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihood(alphaArray[1:S], alphaLikelihoodArray, sites, length, trueAlpha, "Alpha")

# %%
#@title Histogram

plotHist(alphaArray, trueAlpha, "Alpha")

# %%
#@title ESS

plotESS(alphaESSArray, "Alpha")

# %%
#@title Walk of accept ratio

plotAcceptRatio(np.e**(alphaRatioArray/(sites*length)), "Alpha")

# %% [markdown]
# ## Beta

# %%
#@title Walk

plotWalk(betaArray, trueBeta, "Beta")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihood(betaArray[1:S], betaLikelihoodArray, sites, length, trueBeta, "Beta")

# %%
#@title Histogram

plotHist(betaArray, trueBeta, "Beta")

# %%
#@title ESS

plotESS(betaESSArray, "Beta")

# %%
#@title Walk of accept ratio

plotAcceptRatio(np.e**(betaRatioArray/(sites*length)), "Beta")

# %% [markdown]
# ## Tau

# %%
#@title Walk

plotWalk(tauArray, trueTau, "Tau")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihood(tauArray[1:S], alphaLikelihoodArray, sites, length, trueTau, "Tau")

# %%
#@title Histogram

plotHist(tauArray, trueTau, "Tau")

# %%
#@title ESS

plotESS(tauESSArray, "Tau")

# %%
#@title Walk of accept ratio

plotAcceptRatio(np.e**(tauRatioArray/(sites*length)), "Tau")

# %% [markdown]
# ## T

# %%
#@title Walk

plotWalkSet(TArray, trueT, phi[2], "T")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihoodSet(TArray[1:S, :], TLikelihoodArray, sites, length, trueT, phi[2], "T")

# %%
#@title Histogram

plotHistSetDiscrete(TArray, trueT, phi[2], "T")

# %%
#@title ESS

plotESSSet(TESSArray, phi[2], "T")

# %%
#@title Walk of accept ratio
plotAcceptRatioSet(np.e**(TRatioArray/(sites*length)), phi[2], "T")

# %% [markdown]
# ## W

# %%
#@title Walk

plotWalkSet(WArray, trueW, phi[2], "W")

# %%
#@title Scatterplot of likelihood

plotScatterLikelihoodSet(WArray[1:S, :], WLikelihoodArray, sites, length, trueW, phi[2], "W")

# %%
#@title Histogram
plotHistSetDiscrete(WArray, trueW, phi[2], "W")

# %%
#@title ESS

plotESSSet(WESSArray, phi[2], "W")

# %%
#@title Walk of accept ratio
plotAcceptRatioSet(np.e**(WRatioArray/(sites*length)), phi[2], "W")

# %% [markdown]
# ## S

# %%
#@title Walk
plotWalkSet(SArray, trueS, phi[2], "S")

# %%
#@title Scatterplot of likelihood
plotScatterLikelihoodSet(SArray[1:S, :], SLikelihoodArray, sites, length, trueS, phi[2], "S")

# %%
#@title Histogram

plotHistSet(SArray, trueS, phi[2], "S")

# %%
#@title ESS

plotESSSet(SESSArray, phi[2], "S")

# %%
#@title Walk of accept ratio
plotAcceptRatioSet(np.e**(SRatioArray/(sites*length)), phi[2], "S")

# %% [markdown]
# ## I

# %%
#@title Walk
plotWalkSet(IArray, trueI, phi[2], "I")

# %%
#@title Scatterplot of likelihood
plotScatterLikelihoodSet(IArray[1:S, :], ILikelihoodArray, sites, length, trueI, phi[2], "I")

# %%
#@title Histogram
plotHistSetDiscrete(IArray, trueI, phi[2], "I")

# %%
#@title ESS

plotESSSet(IESSArray, phi[2], "I")

# %%
#@title Walk of accept ratio
plotAcceptRatioSet(np.e**(IRatioArray/(sites*length)), phi[2], "I")
